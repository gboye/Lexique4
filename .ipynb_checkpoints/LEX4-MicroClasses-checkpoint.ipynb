# %%
import codecs, re
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.transforms as transforms
from IPython.display import display

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("hls")
sns.set_color_codes("muted")
#sns.palplot(sns.color_palette("hls", 8))
#sns.palplot(sns.color_palette("husl", 8))

# %%
fLexFilms4="/Users/gilles/Downloads/Lexique4_min+filtr+cat+separ+corr3.tsv"
fLexFilms4="Lexique4.tsv"

# %%
dtype={i:"unicode" for i in range(6)}
dtype[6]=np.float64

# %% [markdown]
# - pas de header dans le fichier Gauvain => read_csv header=None
# - mais il y en a un dans le fichier GB Lexique4.tsv => read_csv header="infer"

# %%
dfLexFilms4=pd.read_csv(filepath_or_buffer=fLexFilms4,sep="\t",#header=None,
                        skip_blank_lines=True,encoding="utf8",
                       dtype=dtype)
dfLexFilms4.columns="graphie lemme cat infover genre nombre occurrences".split(" ")

# %%
dfLex4=dfLexFilms4.sort_values(["lemme","cat"]).reset_index().drop(columns="index")
dfLex4
# Out:
#           graphie   lemme      cat    infover genre nombre  occurrences
# 0               !       !      ADV        NaN   NaN    NaN         10.0
# 1               $       $      NOM        NaN     m      p      53371.0
# 2               %       %      NOM        NaN     m    NaN      29248.0
# 3               (       (      ADV        NaN   NaN    NaN          3.0
# 4               )       )      ADV        NaN   NaN    NaN          7.0
# 5               +       +      CON        NaN   NaN    NaN       1006.0
# 6               ,       ,      ADV        NaN   NaN    NaN        176.0
# 7             -ce     -ce  ADJ:dem        NaN     m      s         43.0
# 8             -ce     -ce  PRO:dem        NaN   NaN    NaN     244781.0
# 9             -ce     -ce  PRO:dem        NaN   NaN      p        407.0
# 10            -ce     -ce  PRO:dem        NaN     f    NaN        336.0
# 11            -ce     -ce  PRO:dem        NaN     f      p        249.0
# 12          -elle   -elle  PRO:per        NaN     f      p         48.0
# 13          -elle   -elle  PRO:per        NaN     f      s      63953.0
# 14         -elles  -elles  PRO:per        NaN     f      p       6526.0
# 15            -en     -en      PRE        NaN   NaN    NaN         75.0
# 16            -en     -en  PRO:per        NaN   NaN    NaN      23011.0
# 17            -en     -en  PRO:per        NaN   NaN      p         23.0
# 18            -en     -en  PRO:per        NaN     f    NaN         11.0
# 19            -en     -en  PRO:per        NaN     f      p          8.0
# 20            -il     -il  ADJ:num        NaN     m      s          1.0
# 21            -il     -il  PRO:per        NaN     f      p         61.0
# 22            -il     -il  PRO:per        NaN     f      s        125.0
# 23            -il     -il  PRO:per        NaN     m      p        144.0
# 24            -il     -il  PRO:per        NaN     m      s     273680.0
# 25           -ils    -ils  PRO:per        NaN     f      p         47.0
# 26           -ils    -ils  PRO:per        NaN     m      p      42173.0
# 27            -je     -je  PRO:per        NaN   NaN      p         72.0
# 28            -je     -je  PRO:per        NaN   NaN      s     126474.0
# 29            -je     -je  PRO:per        NaN     f      p         47.0
# ...           ...     ...      ...        ...   ...    ...          ...
# 215533       ôter    ôter      VER       inf;   NaN    NaN       1401.0
# 215534       ôter    ôter      VER       inf;   NaN      p          2.0
# 215535      ôtera    ôter      VER  ind:fut:3   NaN      s         71.0
# 215536     ôterai    ôter      VER  ind:fut:1   NaN      s         38.0
# 215537  ôteraient    ôter      VER        NaN   NaN    NaN          3.0
# 215538    ôterais    ôter      VER  cnd:pre:1   NaN      s         11.0
# 215539    ôterait    ôter      VER  cnd:pre:3   NaN      s         18.0
# 215540     ôteras    ôter      VER  ind:fut:2   NaN      s         17.0
# 215541     ôterez    ôter      VER  ind:fut:2   NaN      p         17.0
# 215542    ôteriez    ôter      VER  cnd:pre:2   NaN      p          1.0
# 215543    ôterons    ôter      VER  ind:fut:1   NaN      p          3.0
# 215544    ôteront    ôter      VER  ind:fut:3   NaN      p          8.0
# 215545       ôtes    ôter      VER        NaN   NaN    NaN          1.0
# 215546       ôtes    ôter      VER  ind:pre:2   NaN      s        105.0
# 215547       ôtes    ôter      VER  sub:pre:2   NaN      s          4.0
# 215548       ôtez    ôter      VER  imp:pre:2   NaN      p        570.0
# 215549       ôtez    ôter      VER  ind:pre:2   NaN      p         80.0
# 215550      ôtiez    ôter      VER  ind:imp:2   NaN      p         21.0
# 215551     ôtions    ôter      VER  ind:imp:1   NaN      p          2.0
# 215552      ôtons    ôter      VER  imp:pre:1   NaN      p          9.0
# 215553      ôtons    ôter      VER  ind:pre:1   NaN      p         11.0
# 215554    ôtèrent    ôter      VER  ind:pas:3   NaN      p          8.0
# 215555        ôté    ôter      VER   par:pas:     m      s        642.0
# 215556       ôtée    ôter      VER   par:pas:     f      s         51.0
# 215557      ôtées    ôter      VER   par:pas:     f      p         22.0
# 215558       ôtés    ôter      VER   par:pas:     m      p         20.0
# 215559        ôté     ôté      ADJ        NaN     m      s         15.0
# 215560       ôtée     ôté      ADJ        NaN     f      s          7.0
# 215561      ôtées     ôté      ADJ        NaN     f      p          4.0
# 215562       ôtés     ôté      ADJ        NaN     m      p          6.0
#
# [215563 rows x 7 columns]

# %% [raw]
# dfLex4=dfLex4[dfLex4["cat"].notnull()].sort_values("rangFW").reset_index().drop(columns="index")
# dfLex4.head()

# %%
catV=["VER","AUX"]
dfVerbes4=dfLex4.loc[dfLex4["cat"].isin(catV),:]
dfVerbes4=dfVerbes4.fillna("").groupby("graphie lemme infover genre nombre".split(" ")).sum().reset_index()

# %%
dfVerbes4.loc[:,"rangFWV"]=dfVerbes4.loc[:,"occurrences"].rank(ascending=False)
dfV4=dfVerbes4.sort_values("rangFWV").reset_index().drop(columns="index")
dfV4
# Out:
#               graphie       lemme    infover genre nombre  occurrences  \
# 0                 est        être  ind:pre:3            s    7111273.0
# 1                   a       avoir  ind:pre:3            s    3668058.0
# 2                  ai       avoir  ind:pre:1            s    2407163.0
# 3                  as       avoir  ind:pre:2            s    1021787.0
# 4               était        être  ind:imp:3            s     982148.0
# 5               faire       faire       inf;                  958743.0
# 6                  va       aller  ind:pre:3            s     878202.0
# 7                sais      savoir  ind:pre:1            s     862224.0
# 8                suis      suivre  ind:pre:1            s     834976.0
# 9                  es        être  ind:pre:2            s     697229.0
# 10               avez       avoir  ind:pre:2            p     633157.0
# 11               sont        être  ind:pre:3            p     612443.0
# 12               dire        dire       inf;                  568577.0
# 13               fait       faire   par:pas:     m      s     542528.0
# 14               vais       aller  ind:pre:1            s     540686.0
# 15                dit        dire   par:pas:     m      s     528243.0
# 16                ont       avoir  ind:pre:3            p     473256.0
# 17               suis        être  ind:pre:1            s     461329.0
# 18               veux     vouloir  ind:pre:1            s     449417.0
# 19               être        être       inf;                  436696.0
# 20              avoir       avoir        inf                  423140.0
# 21               êtes        être  ind:pre:2            p     420613.0
# 22               voir        voir       inf;                  411085.0
# 23                été        être   par:pas:     m      s     411016.0
# 24               peut     pouvoir  ind:pre:3            s     409290.0
# 25               peux     pouvoir  ind:pre:1            s     406113.0
# 26               fait       faire  ind:pre:3            s     335599.0
# 27              avait       avoir  ind:imp:3            s     318510.0
# 28              allez       aller  imp:pre:2            p     316306.0
# 29               veux     vouloir  ind:pre:2            s     312536.0
# ...               ...         ...        ...   ...    ...          ...
# 108928  dépêcheraient    dépêcher  cnd:pre:3            p          1.0
# 108929         révère     révérer                                  1.0
# 108930    chiffrerais    chiffrer  cnd:pre:2            s          1.0
# 108931        perfuse    perfuser  imp:pre:2            s          1.0
# 108932      perfusant    perfuser    par:pre                       1.0
# 108933     révéreront     révérer  ind:fut:3            p          1.0
# 108934     révérerons     révérer  ind:fut:1            p          1.0
# 108935           chie       chier  sub:pre:3            s          1.0
# 108936    perforeront    perforer  ind:fut:3            p          1.0
# 108937     révéraient     révérer  ind:imp:3            p          1.0
# 108938        chienne    chienner  ind:pre:1            s          1.0
# 108939        révélés     révéler  ind:imp:3            p          1.0
# 108940       perforez    perforer  ind:pre:2            p          1.0
# 108941     performais   performer  ind:imp:1            s          1.0
# 108942       dépêtres    dépêtrer  ind:pre:2            s          1.0
# 108943         révélé     révéler  ind:imp:3            s          1.0
# 108944         révélé     révéler  ind:imp:3            p          1.0
# 108945        révélât     révéler  sub:imp:3            s          1.0
# 108946  chiffonnaient  chiffonner  ind:imp:3            p          1.0
# 108947    chiffonnant  chiffonner    par:pre                       1.0
# 108948    chiffonnera  chiffonner  ind:fut:3            s          1.0
# 108949     dépêtrerez    dépêtrer  ind:fut:2            p          1.0
# 108950     chiffonnez  chiffonner  imp:pre:2            p          1.0
# 108951      performez   performer  ind:pre:2            p          1.0
# 108952      perforons    perforer  imp:pre:1            p          1.0
# 108953      dépêtrait    dépêtrer  ind:imp:3            s          1.0
# 108954       dépêches    dépêcher  sub:pre:2            p          1.0
# 108955      perfusait    perfuser  ind:imp:3            s          1.0
# 108956        dépêtré    dépêtrer   par:pas:     m      s          1.0
# 108957         gorgez      gorger  imp:pre:2            p          1.0
#
#         rangFWV
# 0           1.0
# 1           2.0
# 2           3.0
# 3           4.0
# 4           5.0
# 5           6.0
# 6           7.0
# 7           8.0
# 8           9.0
# 9          10.0
# 10         11.0
# 11         12.0
# 12         13.0
# 13         14.0
# 14         15.0
# 15         16.0
# 16         17.0
# 17         18.0
# 18         19.0
# 19         20.0
# 20         21.0
# 21         22.0
# 22         23.0
# 23         24.0
# 24         25.0
# 25         26.0
# 26         27.0
# 27         28.0
# 28         29.0
# 29         30.0
# ...         ...
# 108928  96696.0
# 108929  96696.0
# 108930  96696.0
# 108931  96696.0
# 108932  96696.0
# 108933  96696.0
# 108934  96696.0
# 108935  96696.0
# 108936  96696.0
# 108937  96696.0
# 108938  96696.0
# 108939  96696.0
# 108940  96696.0
# 108941  96696.0
# 108942  96696.0
# 108943  96696.0
# 108944  96696.0
# 108945  96696.0
# 108946  96696.0
# 108947  96696.0
# 108948  96696.0
# 108949  96696.0
# 108950  96696.0
# 108951  96696.0
# 108952  96696.0
# 108953  96696.0
# 108954  96696.0
# 108955  96696.0
# 108956  96696.0
# 108957  96696.0
#
# [108958 rows x 7 columns]

# %% [markdown]
# ## Filtrer les scories de Lexique4
# - quelques formes fléchies sont notées avec des lemmes qui ne correspondent pas à un verbe
# - quelques formes ne sont pas identifiées : infover = NaN
# - une forme est indiquée comme impératif 3S
#
# Dans tous les cas, on remplace l'étiquette de Lexique.org par l'étiquette Grace

# %%
dfV4.infover.unique()
# Out:
# array([u'ind:pre:3', u'ind:pre:1', u'ind:pre:2', u'ind:imp:3', u'inf;',
#        u'par:pas:', u'inf', u'imp:pre:2', u'ind:imp:1', u'ind:fut:3',
#        u'sub:pre:3', u'cnd:pre:3', u'cnd:pre:1', u'imp:pre:1', '',
#        u'ind:imp:2', u'cnd:pre:2', u'ind:fut:1', u'ind:fut:2', u'par:pre',
#        u'sub:pre:2', u'ind:pas:3', u'sub:pre:1', u'ind:pas:1',
#        u'ind:pas:2', u'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;',
#        u'imp:pre:2p;ind:pre:2p;par:pas;', u'imp:pre:1p;ind:pre:1p;',
#        u'sub:imp:3', u'ind:pas:3s;', u'sub:imp:1', u'imp:pre:3',
#        u'sub:imp:2'], dtype=object)

# %%
def infover2Case(lRow):
    result=""
    lInfover=lRow["infover"]
    lNombre=lRow["nombre"]
    if isinstance(lInfover,unicode):
        if lInfover in [u'imp:pre:2p;ind:pre:2p;par:pas;',
       u'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;',
       u'imp:pre:1p;ind:pre:1p;']:
            print lRow["graphie"],lRow["lemme"]
        else:
            if lInfover[:3]==u"inf":
                result=u"inf"
            elif lInfover==u"par:p":
                result="pP"
            elif lInfover[:8]==u"par:pas:":
                if lNombre in ["s","p"]:
                    lNombre=lNombre.upper()
                else:
                    print lRow
                lGenre=lRow["genre"]
                if lGenre in ["m","f"]:
                    lGenre=lGenre.upper()
                else:
                    print lRow
                result="pp"+lGenre+lNombre
            else:
                if lNombre in ["s","p"]:
                    lNombre=lNombre.upper()
                    if lInfover[:8]==u"ind:pre:":
                        result="pi"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:imp:":
                        result="ii"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:fut:":
                        result="fi"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:pas:":
                        result="ai"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"imp:pre:":
                        result="pI"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"sub:pre:":
                        result="ps"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"sub:imp:":
                        result="is"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"cnd:pre:":
                        result="pc"+lInfover[8]+lNombre
                else:
                    print lRow               
    return result

print "Problèmes de lemme"
dfV4["case"]=dfV4.apply(infover2Case,axis=1)
# Out:
# Problèmes de lemme
# graphie        maintenant
# lemme           maintenir
# infover           par:pre
# genre
# nombre
# occurrences         29608
# rangFWV               288
# Name: 287, dtype: object
# graphie          étant
# lemme             être
# infover        par:pre
# genre
# nombre
# occurrences      15671
# rangFWV            502
# Name: 501, dtype: object
# graphie        attendant
# lemme           attendre
# infover          par:pre
# genre
# nombre
# occurrences        13202
# rangFWV              590
# Name: 589, dtype: object
# graphie        faisant
# lemme            faire
# infover        par:pre
# genre
# nombre
# occurrences      11986
# rangFWV            644
# Name: 643, dtype: object
# graphie         disant
# lemme             dire
# infover        par:pre
# genre
# nombre
# occurrences      10742
# rangFWV            705
# Name: 704, dtype: object
# graphie          ayant
# lemme            avoir
# infover        par:pre
# genre
# nombre
# occurrences       8576
# rangFWV            841
# Name: 840, dtype: object
# graphie        parlant
# lemme           parler
# infover        par:pre
# genre
# nombre
# occurrences       8423
# rangFWV            849
# Name: 848, dtype: object
# graphie         venant
# lemme            venir
# infover        par:pre
# genre
# nombre
# occurrences       8013
# rangFWV            888
# Name: 887, dtype: object
# graphie        sachant
# lemme           savoir
# infover        par:pre
# genre
# nombre
# occurrences       5220
# rangFWV           1249
# Name: 1248, dtype: object
# graphie        essayant
# lemme           essayer
# infover         par:pre
# genre
# nombre
# occurrences        4617
# rangFWV            1383
# Name: 1382, dtype: object
# graphie        regardant
# lemme           regarder
# infover          par:pre
# genre
# nombre
# occurrences         4562
# rangFWV             1397
# Name: 1396, dtype: object
# graphie         voyant
# lemme             voir
# infover        par:pre
# genre
# nombre
# occurrences       4535
# rangFWV           1404
# Name: 1403, dtype: object
# monte monte
# faîtes faîte
# graphie        passant
# lemme           passer
# infover        par:pre
# genre
# nombre
# occurrences       4321
# rangFWV           1452
# Name: 1451, dtype: object
# graphie        laissant
# lemme           laisser
# infover         par:pre
# genre
# nombre
# occurrences        3784
# rangFWV          1616.5
# Name: 1615, dtype: object
# graphie        pensant
# lemme           penser
# infover        par:pre
# genre
# nombre
# occurrences       3566
# rangFWV           1710
# Name: 1709, dtype: object
# graphie        utilisant
# lemme           utiliser
# infover          par:pre
# genre
# nombre
# occurrences         3454
# rangFWV             1754
# Name: 1753, dtype: object
# graphie        sortant
# lemme           sortir
# infover        par:pre
# genre
# nombre
# occurrences       3378
# rangFWV         1782.5
# Name: 1782, dtype: object
# graphie         allant
# lemme            aller
# infover        par:pre
# genre
# nombre
# occurrences       3002
# rangFWV           1948
# Name: 1947, dtype: object
# graphie        espérant
# lemme           espérer
# infover         par:pre
# genre
# nombre
# occurrences        2937
# rangFWV          1983.5
# Name: 1982, dtype: object
# graphie        courant
# lemme           courir
# infover        par:pre
# genre
# nombre
# occurrences       2907
# rangFWV         1999.5
# Name: 1999, dtype: object
# graphie        prenant
# lemme          prendre
# infover        par:pre
# genre
# nombre
# occurrences       2843
# rangFWV           2031
# Name: 2030, dtype: object
# partons parton
# graphie        rentrant
# lemme           rentrer
# infover         par:pre
# genre
# nombre
# occurrences        2679
# rangFWV          2133.5
# Name: 2133, dtype: object
# graphie        demandant
# lemme           demander
# infover          par:pre
# genre
# nombre
# occurrences         2584
# rangFWV             2184
# Name: 2183, dtype: object
# graphie        arrivant
# lemme           arriver
# infover         par:pre
# genre
# nombre
# occurrences        2563
# rangFWV            2202
# Name: 2201, dtype: object
# graphie         jouant
# lemme            jouer
# infover        par:pre
# genre
# nombre
# occurrences       2511
# rangFWV         2239.5
# Name: 2239, dtype: object
# graphie        travaillant
# lemme           travailler
# infover            par:pre
# genre
# nombre
# occurrences           2508
# rangFWV             2242.5
# Name: 2242, dtype: object
# graphie        donnant
# lemme           donner
# infover        par:pre
# genre
# nombre
# occurrences       2491
# rangFWV           2252
# Name: 2251, dtype: object
# graphie         vivant
# lemme            vivre
# infover        par:pre
# genre
# nombre
# occurrences       2458
# rangFWV           2282
# Name: 2281, dtype: object
# graphie        flippant
# lemme           flipper
# infover         par:pre
# genre
# nombre
# occurrences        2417
# rangFWV            2302
# Name: 2301, dtype: object
# graphie        partant
# lemme           partir
# infover        par:pre
# genre
# nombre
# occurrences       2335
# rangFWV         2361.5
# Name: 2360, dtype: object
# graphie        portant
# lemme           porter
# infover        par:pre
# genre
# nombre
# occurrences       2278
# rangFWV           2398
# Name: 2398, dtype: object
# graphie        semblant
# lemme           sembler
# infover         par:pre
# genre
# nombre
# occurrences        2200
# rangFWV          2444.5
# Name: 2442, dtype: object
# graphie        cherchant
# lemme           chercher
# infover          par:pre
# genre
# nombre
# occurrences         2191
# rangFWV             2454
# Name: 2453, dtype: object
# graphie        mettant
# lemme           mettre
# infover        par:pre
# genre
# nombre
# occurrences       2085
# rangFWV           2539
# Name: 2538, dtype: object
# graphie          tuant
# lemme             tuer
# infover        par:pre
# genre
# nombre
# occurrences       1917
# rangFWV         2726.5
# Name: 2725, dtype: object
# graphie        concernant
# lemme           concerner
# infover           par:pre
# genre
# nombre
# occurrences          1808
# rangFWV              2842
# Name: 2841, dtype: object
# graphie        provenant
# lemme           provenir
# infover          par:pre
# genre
# nombre
# occurrences         1764
# rangFWV           2895.5
# Name: 2894, dtype: object
# graphie        suivant
# lemme           suivre
# infover        par:pre
# genre
# nombre
# occurrences       1606
# rangFWV           3119
# Name: 3119, dtype: object
# graphie         devant
# lemme           devoir
# infover        par:pre
# genre
# nombre
# occurrences       1517
# rangFWV         3235.5
# Name: 3235, dtype: object
# graphie        restant
# lemme           rester
# infover        par:pre
# genre
# nombre
# occurrences       1507
# rangFWV         3247.5
# Name: 3246, dtype: object
# graphie        voulant
# lemme          vouloir
# infover        par:pre
# genre
# nombre
# occurrences       1470
# rangFWV           3299
# Name: 3299, dtype: object
# graphie         tenant
# lemme            tenir
# infover        par:pre
# genre
# nombre
# occurrences       1440
# rangFWV         3341.5
# Name: 3340, dtype: object
# graphie        étonnant
# lemme           étonner
# infover         par:pre
# genre
# nombre
# occurrences        1419
# rangFWV          3370.5
# Name: 3370, dtype: object
# graphie        pouvant
# lemme          pouvoir
# infover        par:pre
# genre
# nombre
# occurrences       1386
# rangFWV         3430.5
# Name: 3429, dtype: object
# graphie        entrant
# lemme           entrer
# infover        par:pre
# genre
# nombre
# occurrences       1312
# rangFWV         3567.5
# Name: 3568, dtype: object
# graphie        mangeant
# lemme            manger
# infover         par:pre
# genre
# nombre
# occurrences        1306
# rangFWV            3583
# Name: 3581, dtype: object
# graphie        montrant
# lemme           montrer
# infover         par:pre
# genre
# nombre
# occurrences        1298
# rangFWV            3595
# Name: 3594, dtype: object
# graphie        marchant
# lemme           marcher
# infover         par:pre
# genre
# nombre
# occurrences        1272
# rangFWV          3641.5
# Name: 3641, dtype: object
# graphie         criant
# lemme            crier
# infover        par:pre
# genre
# nombre
# occurrences       1176
# rangFWV         3836.5
# Name: 3836, dtype: object
# graphie        commençant
# lemme           commencer
# infover           par:pre
# genre
# nombre
# occurrences          1172
# rangFWV              3843
# Name: 3842, dtype: object
# graphie        revenant
# lemme           revenir
# infover         par:pre
# genre
# nombre
# occurrences        1142
# rangFWV            3904
# Name: 3903, dtype: object
# graphie        quittant
# lemme           quitter
# infover         par:pre
# genre
# nombre
# occurrences        1134
# rangFWV          3919.5
# Name: 3918, dtype: object
# graphie        connaissant
# lemme            connaître
# infover            par:pre
# genre
# nombre
# occurrences           1112
# rangFWV               3969
# Name: 3969, dtype: object
# graphie        appartenant
# lemme           appartenir
# infover            par:pre
# genre
# nombre
# occurrences           1085
# rangFWV               4039
# Name: 4040, dtype: object
# graphie         durant
# lemme            durer
# infover        par:pre
# genre
# nombre
# occurrences       1079
# rangFWV         4061.5
# Name: 4062, dtype: object
# graphie        amusant
# lemme           amuser
# infover        par:pre
# genre
# nombre
# occurrences       1043
# rangFWV         4166.5
# Name: 4165, dtype: object
# graphie        permettant
# lemme           permettre
# infover           par:pre
# genre
# nombre
# occurrences          1034
# rangFWV              4197
# Name: 4195, dtype: object
# graphie         volant
# lemme            voler
# infover        par:pre
# genre
# nombre
# occurrences       1019
# rangFWV           4231
# Name: 4231, dtype: object
# graphie        chantant
# lemme           chanter
# infover         par:pre
# genre
# nombre
# occurrences        1012
# rangFWV            4247
# Name: 4246, dtype: object
# graphie         lisant
# lemme             lire
# infover        par:pre
# genre
# nombre
# occurrences        992
# rangFWV           4303
# Name: 4304, dtype: object
# graphie        supposant
# lemme           supposer
# infover          par:pre
# genre
# nombre
# occurrences          989
# rangFWV             4315
# Name: 4315, dtype: object
# graphie        impliquant
# lemme           impliquer
# infover           par:pre
# genre
# nombre
# occurrences           988
# rangFWV              4319
# Name: 4318, dtype: object
# graphie        gardant
# lemme           garder
# infover        par:pre
# genre
# nombre
# occurrences        955
# rangFWV         4412.5
# Name: 4412, dtype: object
# graphie        tombant
# lemme           tomber
# infover        par:pre
# genre
# nombre
# occurrences        937
# rangFWV           4477
# Name: 4475, dtype: object
# graphie        rendant
# lemme           rendre
# infover        par:pre
# genre
# nombre
# occurrences        934
# rangFWV         4482.5
# Name: 4480, dtype: object
# graphie        dormant
# lemme           dormir
# infover        par:pre
# genre
# nombre
# occurrences        933
# rangFWV           4487
# Name: 4485, dtype: object
# graphie        écoutant
# lemme           écouter
# infover         par:pre
# genre
# nombre
# occurrences         907
# rangFWV          4576.5
# Name: 4574, dtype: object
# graphie         tirant
# lemme            tirer
# infover        par:pre
# genre
# nombre
# occurrences        902
# rangFWV           4591
# Name: 4591, dtype: object
# graphie        vendant
# lemme           vendre
# infover        par:pre
# genre
# nombre
# occurrences        899
# rangFWV         4601.5
# Name: 4600, dtype: object
# graphie        incluant
# lemme           inclure
# infover         par:pre
# genre
# nombre
# occurrences         887
# rangFWV          4644.5
# Name: 4644, dtype: object
# graphie        contenant
# lemme           contenir
# infover          par:pre
# genre
# nombre
# occurrences          887
# rangFWV           4644.5
# Name: 4645, dtype: object
# graphie        pleurant
# lemme           pleurer
# infover         par:pre
# genre
# nombre
# occurrences         881
# rangFWV            4661
# Name: 4660, dtype: object
# graphie        considérant
# lemme           considérer
# infover            par:pre
# genre
# nombre
# occurrences            881
# rangFWV               4661
# Name: 4662, dtype: object
# graphie        intéressant
# lemme           intéresser
# infover            par:pre
# genre
# nombre
# occurrences            880
# rangFWV             4665.5
# Name: 4663, dtype: object
# graphie         aidant
# lemme            aider
# infover        par:pre
# genre
# nombre
# occurrences        872
# rangFWV         4692.5
# Name: 4688, dtype: object
# graphie         buvant
# lemme            boire
# infover        par:pre
# genre
# nombre
# occurrences        869
# rangFWV           4708
# Name: 4708, dtype: object
# graphie        croyant
# lemme           croire
# infover        par:pre
# genre
# nombre
# occurrences        855
# rangFWV         4754.5
# Name: 4751, dtype: object
# graphie        hurlant
# lemme           hurler
# infover        par:pre
# genre
# nombre
# occurrences        850
# rangFWV           4778
# Name: 4778, dtype: object
# graphie         menant
# lemme            mener
# infover        par:pre
# genre
# nombre
# occurrences        849
# rangFWV         4783.5
# Name: 4782, dtype: object
# graphie         basant
# lemme            baser
# infover        par:pre
# genre
# nombre
# occurrences        843
# rangFWV         4813.5
# Name: 4814, dtype: object
# graphie        appelant
# lemme           appeler
# infover         par:pre
# genre
# nombre
# occurrences         843
# rangFWV          4813.5
# Name: 4815, dtype: object
# graphie        grandissant
# lemme              grandir
# infover            par:pre
# genre
# nombre
# occurrences            840
# rangFWV             4825.5
# Name: 4823, dtype: object
# graphie        battant
# lemme           battre
# infover        par:pre
# genre
# nombre
# occurrences        838
# rangFWV           4833
# Name: 4831, dtype: object
# graphie        conduisant
# lemme            conduire
# infover           par:pre
# genre
# nombre
# occurrences           831
# rangFWV              4865
# Name: 4864, dtype: object
# graphie        apprenant
# lemme          apprendre
# infover          par:pre
# genre
# nombre
# occurrences          818
# rangFWV           4919.5
# Name: 4919, dtype: object
# graphie        trouvant
# lemme           trouver
# infover         par:pre
# genre
# nombre
# occurrences         808
# rangFWV            4952
# Name: 4951, dtype: object
# graphie        prétendant
# lemme           prétendre
# infover           par:pre
# genre
# nombre
# occurrences           774
# rangFWV              5098
# Name: 5096, dtype: object
# graphie         créant
# lemme            créer
# infover        par:pre
# genre
# nombre
# occurrences        772
# rangFWV         5105.5
# Name: 5104, dtype: object
# graphie        représentant
# lemme           représenter
# infover             par:pre
# genre
# nombre
# occurrences             772
# rangFWV              5105.5
# Name: 5105, dtype: object
# graphie        descendant
# lemme           descendre
# infover           par:pre
# genre
# nombre
# occurrences           761
# rangFWV            5143.5
# Name: 5143, dtype: object
# graphie        cachant
# lemme           cacher
# infover        par:pre
# genre
# nombre
# occurrences        737
# rangFWV           5252
# Name: 5253, dtype: object
# graphie        charmant
# lemme           charmer
# infover         par:pre
# genre
# nombre
# occurrences         732
# rangFWV            5272
# Name: 5270, dtype: object
# graphie        pendant
# lemme           pendre
# infover        par:pre
# genre
# nombre
# occurrences        729
# rangFWV         5289.5
# Name: 5287, dtype: object
# graphie        devenant
# lemme           devenir
# infover         par:pre
# genre
# nombre
# occurrences         729
# rangFWV          5289.5
# Name: 5291, dtype: object
# graphie        traversant
# lemme           traverser
# infover           par:pre
# genre
# nombre
# occurrences           727
# rangFWV            5298.5
# Name: 5297, dtype: object
# graphie        envoyant
# lemme           envoyer
# infover         par:pre
# genre
# nombre
# occurrences         725
# rangFWV          5307.5
# Name: 5305, dtype: object
# graphie        indiquant
# lemme           indiquer
# infover          par:pre
# genre
# nombre
# occurrences          717
# rangFWV             5337
# Name: 5336, dtype: object
# graphie         datant
# lemme            dater
# infover        par:pre
# genre
# nombre
# occurrences        707
# rangFWV           5391
# Name: 5390, dtype: object
# graphie        entendant
# lemme           entendre
# infover          par:pre
# genre
# nombre
# occurrences          686
# rangFWV           5485.5
# Name: 5486, dtype: object
# graphie        gagnant
# lemme           gagner
# infover        par:pre
# genre
# nombre
# occurrences        682
# rangFWV           5508
# Name: 5506, dtype: object
# graphie        montant
# lemme           monter
# infover        par:pre
# genre
# nombre
# occurrences        665
# rangFWV           5584
# Name: 5583, dtype: object
# graphie        dansant
# lemme           danser
# infover        par:pre
# genre
# nombre
# occurrences        632
# rangFWV         5782.5
# Name: 5782, dtype: object
# graphie        correspondant
# lemme           correspondre
# infover              par:pre
# genre
# nombre
# occurrences              628
# rangFWV               5801.5
# Name: 5800, dtype: object
# graphie        mourant
# lemme           mourir
# infover        par:pre
# genre
# nombre
# occurrences        625
# rangFWV           5818
# Name: 5816, dtype: object
# graphie         visant
# lemme            viser
# infover        par:pre
# genre
# nombre
# occurrences        616
# rangFWV           5885
# Name: 5883, dtype: object
# graphie        servant
# lemme           servir
# infover        par:pre
# genre
# nombre
# occurrences        615
# rangFWV           5890
# Name: 5890, dtype: object
# graphie        comptant
# lemme           compter
# infover         par:pre
# genre
# nombre
# occurrences         608
# rangFWV            5939
# Name: 5937, dtype: object
# graphie        tentant
# lemme           tenter
# infover        par:pre
# genre
# nombre
# occurrences        604
# rangFWV           5966
# Name: 5968, dtype: object
# graphie        perdant
# lemme           perdre
# infover        par:pre
# genre
# nombre
# occurrences        585
# rangFWV         6074.5
# Name: 6072, dtype: object
# graphie        menaçant
# lemme           menacer
# infover         par:pre
# genre
# nombre
# occurrences         585
# rangFWV          6074.5
# Name: 6076, dtype: object
# graphie        frappant
# lemme           frapper
# infover         par:pre
# genre
# nombre
# occurrences         577
# rangFWV          6131.5
# Name: 6134, dtype: object
# graphie        ressemblant
# lemme           ressembler
# infover            par:pre
# genre
# nombre
# occurrences            563
# rangFWV             6214.5
# Name: 6213, dtype: object
# graphie        offrant
# lemme           offrir
# infover        par:pre
# genre
# nombre
# occurrences        559
# rangFWV           6244
# Name: 6241, dtype: object
# graphie        reconnaissant
# lemme            reconnaître
# infover              par:pre
# genre
# nombre
# occurrences              557
# rangFWV                 6256
# Name: 6256, dtype: object
# graphie        détruisant
# lemme            détruire
# infover           par:pre
# genre
# nombre
# occurrences           555
# rangFWV            6264.5
# Name: 6262, dtype: object
# graphie        assistant
# lemme           assister
# infover          par:pre
# genre
# nombre
# occurrences          551
# rangFWV           6294.5
# Name: 6293, dtype: object
# graphie        protégeant
# lemme            protéger
# infover           par:pre
# genre
# nombre
# occurrences           549
# rangFWV            6313.5
# Name: 6316, dtype: object
# graphie        agissant
# lemme              agir
# infover         par:pre
# genre
# nombre
# occurrences         546
# rangFWV          6338.5
# Name: 6337, dtype: object
# graphie        ouvrant
# lemme           ouvrir
# infover        par:pre
# genre
# nombre
# occurrences        545
# rangFWV         6345.5
# Name: 6348, dtype: object
# graphie        sauvant
# lemme           sauver
# infover        par:pre
# genre
# nombre
# occurrences        544
# rangFWV           6355
# Name: 6353, dtype: object
# graphie        tournant
# lemme           tourner
# infover         par:pre
# genre
# nombre
# occurrences         541
# rangFWV          6378.5
# Name: 6378, dtype: object
# graphie        dirigeant
# lemme            diriger
# infover          par:pre
# genre
# nombre
# occurrences          540
# rangFWV             6384
# Name: 6385, dtype: object
# graphie        repensant
# lemme           repenser
# infover          par:pre
# genre
# nombre
# occurrences          534
# rangFWV             6431
# Name: 6431, dtype: object
# graphie        marrant
# lemme           marrer
# infover        par:pre
# genre
# nombre
# occurrences        527
# rangFWV         6485.5
# Name: 6487, dtype: object
# graphie         jetant
# lemme            jeter
# infover        par:pre
# genre
# nombre
# occurrences        523
# rangFWV         6511.5
# Name: 6514, dtype: object
# graphie        souriant
# lemme           sourire
# infover         par:pre
# genre
# nombre
# occurrences         521
# rangFWV            6532
# Name: 6528, dtype: object
# graphie        sentant
# lemme           sentir
# infover        par:pre
# genre
# nombre
# occurrences        516
# rangFWV         6570.5
# Name: 6568, dtype: object
# graphie        changeant
# lemme            changer
# infover          par:pre
# genre
# nombre
# occurrences          516
# rangFWV           6570.5
# Name: 6570, dtype: object
# graphie        commandant
# lemme           commander
# infover           par:pre
# genre
# nombre
# occurrences           514
# rangFWV              6582
# Name: 6585, dtype: object
# graphie        achetant
# lemme           acheter
# infover         par:pre
# genre
# nombre
# occurrences         513
# rangFWV          6590.5
# Name: 6588, dtype: object
# graphie         posant
# lemme            poser
# infover        par:pre
# genre
# nombre
# occurrences        502
# rangFWV         6675.5
# Name: 6676, dtype: object
# graphie        poussant
# lemme           pousser
# infover         par:pre
# genre
# nombre
# occurrences         497
# rangFWV            6722
# Name: 6717, dtype: object
# graphie          riant
# lemme             rire
# infover        par:pre
# genre
# nombre
# occurrences        489
# rangFWV           6785
# Name: 6785, dtype: object
# graphie        sautant
# lemme           sauter
# infover        par:pre
# genre
# nombre
# occurrences        477
# rangFWV           6893
# Name: 6889, dtype: object
# graphie        combattant
# lemme           combattre
# infover           par:pre
# genre
# nombre
# occurrences           477
# rangFWV              6893
# Name: 6895, dtype: object
# graphie        ignorant
# lemme           ignorer
# infover         par:pre
# genre
# nombre
# occurrences         475
# rangFWV            6906
# Name: 6906, dtype: object
# graphie        écrivant
# lemme            écrire
# infover         par:pre
# genre
# nombre
# occurrences         472
# rangFWV            6929
# Name: 6932, dtype: object
# graphie        prouvant
# lemme           prouver
# infover         par:pre
# genre
# nombre
# occurrences         471
# rangFWV          6939.5
# Name: 6942, dtype: object
# graphie        surprenant
# lemme          surprendre
# infover           par:pre
# genre
# nombre
# occurrences           466
# rangFWV            6987.5
# Name: 6986, dtype: object
# graphie        causant
# lemme           causer
# infover        par:pre
# genre
# nombre
# occurrences        460
# rangFWV         7033.5
# Name: 7030, dtype: object
# graphie        racontant
# lemme           raconter
# infover          par:pre
# genre
# nombre
# occurrences          459
# rangFWV           7046.5
# Name: 7051, dtype: object
# graphie        coupant
# lemme           couper
# infover        par:pre
# genre
# nombre
# occurrences        451
# rangFWV           7120
# Name: 7116, dtype: object
# graphie        amenant
# lemme           amener
# infover        par:pre
# genre
# nombre
# occurrences        448
# rangFWV         7152.5
# Name: 7156, dtype: object
# graphie        touchant
# lemme           toucher
# infover         par:pre
# genre
# nombre
# occurrences         435
# rangFWV            7281
# Name: 7282, dtype: object
# graphie        précédant
# lemme           précéder
# infover          par:pre
# genre
# nombre
# occurrences          433
# rangFWV           7306.5
# Name: 7311, dtype: object
# graphie        souffrant
# lemme           souffrir
# infover          par:pre
# genre
# nombre
# occurrences          432
# rangFWV             7322
# Name: 7326, dtype: object
# graphie        réveillant
# lemme           réveiller
# infover           par:pre
# genre
# nombre
# occurrences           432
# rangFWV              7322
# Name: 7328, dtype: object
# graphie        rampant
# lemme           ramper
# infover        par:pre
# genre
# nombre
# occurrences        431
# rangFWV           7336
# Name: 7332, dtype: object
# graphie        refusant
# lemme           refuser
# infover         par:pre
# genre
# nombre
# occurrences         431
# rangFWV            7336
# Name: 7338, dtype: object
# graphie        défendant
# lemme           défendre
# infover          par:pre
# genre
# nombre
# occurrences          431
# rangFWV             7336
# Name: 7340, dtype: object
# graphie        roulant
# lemme           rouler
# infover        par:pre
# genre
# nombre
# occurrences        427
# rangFWV         7378.5
# Name: 7375, dtype: object
# graphie        reliant
# lemme           relier
# infover        par:pre
# genre
# nombre
# occurrences        421
# rangFWV         7461.5
# Name: 7458, dtype: object
# graphie        entraînant
# lemme           entraîner
# infover           par:pre
# genre
# nombre
# occurrences           418
# rangFWV              7500
# Name: 7501, dtype: object
# graphie         aimant
# lemme            aimer
# infover        par:pre
# genre
# nombre
# occurrences        411
# rangFWV         7569.5
# Name: 7577, dtype: object
# graphie        transportant
# lemme           transporter
# infover             par:pre
# genre
# nombre
# occurrences             404
# rangFWV              7660.5
# Name: 7658, dtype: object
# graphie        apportant
# lemme           apporter
# infover          par:pre
# genre
# nombre
# occurrences          398
# rangFWV           7735.5
# Name: 7732, dtype: object
# graphie        évitant
# lemme           éviter
# infover        par:pre
# genre
# nombre
# occurrences        398
# rangFWV         7735.5
# Name: 7735, dtype: object
# graphie        remontant
# lemme           remonter
# infover          par:pre
# genre
# nombre
# occurrences          397
# rangFWV             7749
# Name: 7748, dtype: object
# graphie         levant
# lemme            lever
# infover        par:pre
# genre
# nombre
# occurrences        394
# rangFWV           7784
# Name: 7777, dtype: object
# graphie        couchant
# lemme           coucher
# infover         par:pre
# genre
# nombre
# occurrences         392
# rangFWV            7807
# Name: 7808, dtype: object
# graphie        acceptant
# lemme           accepter
# infover          par:pre
# genre
# nombre
# occurrences          391
# rangFWV           7817.5
# Name: 7818, dtype: object
# graphie        traitant
# lemme           traiter
# infover         par:pre
# genre
# nombre
# occurrences         390
# rangFWV          7826.5
# Name: 7821, dtype: object
# graphie         payant
# lemme            payer
# infover        par:pre
# genre
# nombre
# occurrences        390
# rangFWV         7826.5
# Name: 7828, dtype: object
# graphie        expliquant
# lemme           expliquer
# infover           par:pre
# genre
# nombre
# occurrences           382
# rangFWV              7927
# Name: 7924, dtype: object
# graphie        attaquant
# lemme           attaquer
# infover          par:pre
# genre
# nombre
# occurrences          379
# rangFWV           7969.5
# Name: 7973, dtype: object
# graphie        forçant
# lemme           forcer
# infover        par:pre
# genre
# nombre
# occurrences        378
# rangFWV           7979
# Name: 7982, dtype: object
# graphie        oubliant
# lemme           oublier
# infover         par:pre
# genre
# nombre
# occurrences         376
# rangFWV          8002.5
# Name: 8003, dtype: object
# graphie        empêchant
# lemme           empêcher
# infover          par:pre
# genre
# nombre
# occurrences          375
# rangFWV           8017.5
# Name: 8023, dtype: object
# graphie        approchant
# lemme           approcher
# infover           par:pre
# genre
# nombre
# occurrences           374
# rangFWV              8035
# Name: 8026, dtype: object
# graphie         priant
# lemme            prier
# infover        par:pre
# genre
# nombre
# occurrences        374
# rangFWV           8035
# Name: 8028, dtype: object
# graphie        provoquant
# lemme           provoquer
# infover           par:pre
# genre
# nombre
# occurrences           374
# rangFWV              8035
# Name: 8029, dtype: object
# graphie         pelant
# lemme            peler
# infover        par:pre
# genre
# nombre
# occurrences        373
# rangFWV           8051
# Name: 8053, dtype: object
# graphie        accusant
# lemme           accuser
# infover         par:pre
# genre
# nombre
# occurrences         369
# rangFWV          8103.5
# Name: 8108, dtype: object
# graphie        présentant
# lemme           présenter
# infover           par:pre
# genre
# nombre
# occurrences           368
# rangFWV              8117
# Name: 8117, dtype: object
# graphie        vieillissant
# lemme              vieillir
# infover             par:pre
# genre
# nombre
# occurrences             368
# rangFWV                8117
# Name: 8121, dtype: object
# graphie        préparant
# lemme           préparer
# infover          par:pre
# genre
# nombre
# occurrences          366
# rangFWV             8136
# Name: 8132, dtype: object
# graphie        brûlant
# lemme           brûler
# infover        par:pre
# genre
# nombre
# occurrences        366
# rangFWV           8136
# Name: 8136, dtype: object
# graphie        embrassant
# lemme           embrasser
# infover           par:pre
# genre
# nombre
# occurrences           365
# rangFWV              8149
# Name: 8140, dtype: object
# graphie        luttant
# lemme           lutter
# infover        par:pre
# genre
# nombre
# occurrences        364
# rangFWV           8165
# Name: 8166, dtype: object
# graphie         fuyant
# lemme             fuir
# infover        par:pre
# genre
# nombre
# occurrences        362
# rangFWV         8192.5
# Name: 8188, dtype: object
# graphie        fatiguant
# lemme           fatiguer
# infover          par:pre
# genre
# nombre
# occurrences          353
# rangFWV             8315
# Name: 8314, dtype: object
# graphie         rêvant
# lemme            rêver
# infover        par:pre
# genre
# nombre
# occurrences        353
# rangFWV           8315
# Name: 8317, dtype: object
# graphie        étudiant
# lemme           étudier
# infover         par:pre
# genre
# nombre
# occurrences         352
# rangFWV          8330.5
# Name: 8322, dtype: object
# graphie        arrêtant
# lemme           arrêter
# infover         par:pre
# genre
# nombre
# occurrences         352
# rangFWV          8330.5
# Name: 8338, dtype: object
# graphie        restaurant
# lemme           restaurer
# infover           par:pre
# genre
# nombre
# occurrences           350
# rangFWV            8356.5
# Name: 8359, dtype: object
# graphie        enlevant
# lemme           enlever
# infover         par:pre
# genre
# nombre
# occurrences         349
# rangFWV          8370.5
# Name: 8371, dtype: object
# graphie        épousant
# lemme           épouser
# infover         par:pre
# genre
# nombre
# occurrences         345
# rangFWV            8427
# Name: 8434, dtype: object
# graphie        fascinant
# lemme           fasciner
# infover          par:pre
# genre
# nombre
# occurrences          341
# rangFWV           8487.5
# Name: 8482, dtype: object
# graphie        répondant
# lemme           répondre
# infover          par:pre
# genre
# nombre
# occurrences          341
# rangFWV           8487.5
# Name: 8483, dtype: object
# graphie        retournant
# lemme           retourner
# infover           par:pre
# genre
# nombre
# occurrences           340
# rangFWV            8499.5
# Name: 8501, dtype: object
# graphie        découvrant
# lemme           découvrir
# infover           par:pre
# genre
# nombre
# occurrences           339
# rangFWV              8516
# Name: 8509, dtype: object
# graphie        continuant
# lemme           continuer
# infover           par:pre
# genre
# nombre
# occurrences           338
# rangFWV            8532.5
# Name: 8536, dtype: object
# graphie        partageant
# lemme            partager
# infover           par:pre
# genre
# nombre
# occurrences           337
# rangFWV              8542
# Name: 8541, dtype: object
# graphie        abandonnant
# lemme           abandonner
# infover            par:pre
# genre
# nombre
# occurrences            336
# rangFWV             8558.5
# Name: 8563, dtype: object
# graphie        survivant
# lemme           survivre
# infover          par:pre
# genre
# nombre
# occurrences          333
# rangFWV             8615
# Name: 8607, dtype: object
# graphie        observant
# lemme           observer
# infover          par:pre
# genre
# nombre
# occurrences          332
# rangFWV             8634
# Name: 8630, dtype: object
# graphie        appuyant
# lemme           appuyer
# infover         par:pre
# genre
# nombre
# occurrences         331
# rangFWV            8653
# Name: 8652, dtype: object
# graphie        mentant
# lemme           mentir
# infover        par:pre
# genre
# nombre
# occurrences        329
# rangFWV         8684.5
# Name: 8683, dtype: object
# graphie        effrayant
# lemme           effrayer
# infover          par:pre
# genre
# nombre
# occurrences          329
# rangFWV           8684.5
# Name: 8689, dtype: object
# graphie         errant
# lemme            errer
# infover        par:pre
# genre
# nombre
# occurrences        328
# rangFWV           8699
# Name: 8698, dtype: object
# graphie        brillant
# lemme           briller
# infover         par:pre
# genre
# nombre
# occurrences         325
# rangFWV            8745
# Name: 8744, dtype: object
# graphie        voyageant
# lemme            voyager
# infover          par:pre
# genre
# nombre
# occurrences          324
# rangFWV           8766.5
# Name: 8768, dtype: object
# graphie        méchant
# lemme           mécher
# infover        par:pre
# genre
# nombre
# occurrences        323
# rangFWV         8785.5
# Name: 8789, dtype: object
# graphie        fouillant
# lemme           fouiller
# infover          par:pre
# genre
# nombre
# occurrences          321
# rangFWV           8809.5
# Name: 8809, dtype: object
# graphie        annonçant
# lemme           annoncer
# infover          par:pre
# genre
# nombre
# occurrences          315
# rangFWV           8909.5
# Name: 8907, dtype: object
# graphie        flottant
# lemme           flotter
# infover         par:pre
# genre
# nombre
# occurrences         315
# rangFWV          8909.5
# Name: 8910, dtype: object
# graphie        transformant
# lemme           transformer
# infover             par:pre
# genre
# nombre
# occurrences             314
# rangFWV                8926
# Name: 8928, dtype: object
# graphie        traînant
# lemme           traîner
# infover         par:pre
# genre
# nombre
# occurrences         312
# rangFWV          8961.5
# Name: 8967, dtype: object
# graphie        poursuivant
# lemme           poursuivre
# infover            par:pre
# genre
# nombre
# occurrences            307
# rangFWV               9044
# Name: 9041, dtype: object
# graphie        souhaitant
# lemme           souhaiter
# infover           par:pre
# genre
# nombre
# occurrences           301
# rangFWV            9135.5
# Name: 9133, dtype: object
# graphie         pesant
# lemme            peser
# infover        par:pre
# genre
# nombre
# occurrences        300
# rangFWV         9154.5
# Name: 9150, dtype: object
# graphie        assurant
# lemme           assurer
# infover         par:pre
# genre
# nombre
# occurrences         300
# rangFWV          9154.5
# Name: 9153, dtype: object
# graphie        craignant
# lemme           craindre
# infover          par:pre
# genre
# nombre
# occurrences          298
# rangFWV           9184.5
# Name: 9187, dtype: object
# graphie        déplaçant
# lemme           déplacer
# infover          par:pre
# genre
# nombre
# occurrences          297
# rangFWV           9200.5
# Name: 9197, dtype: object
# graphie        admettant
# lemme           admettre
# infover          par:pre
# genre
# nombre
# occurrences          292
# rangFWV           9297.5
# Name: 9288, dtype: object
# graphie        suppliant
# lemme           supplier
# infover          par:pre
# genre
# nombre
# occurrences          285
# rangFWV             9437
# Name: 9423, dtype: object
# graphie        emmenant
# lemme           emmener
# infover         par:pre
# genre
# nombre
# occurrences         284
# rangFWV            9462
# Name: 9470, dtype: object
# graphie        respirant
# lemme           respirer
# infover          par:pre
# genre
# nombre
# occurrences          284
# rangFWV             9462
# Name: 9471, dtype: object
# graphie        choisissant
# lemme              choisir
# infover            par:pre
# genre
# nombre
# occurrences            283
# rangFWV               9483
# Name: 9473, dtype: object
# graphie        comprenant
# lemme          comprendre
# infover           par:pre
# genre
# nombre
# occurrences           281
# rangFWV            9524.5
# Name: 9521, dtype: object
# graphie        nettoyant
# lemme           nettoyer
# infover          par:pre
# genre
# nombre
# occurrences          280
# rangFWV           9542.5
# Name: 9550, dtype: object
# graphie        baisant
# lemme           baiser
# infover        par:pre
# genre
# nombre
# occurrences        278
# rangFWV         9588.5
# Name: 9589, dtype: object
# graphie        rappelant
# lemme           rappeler
# infover          par:pre
# genre
# nombre
# occurrences          278
# rangFWV           9588.5
# Name: 9592, dtype: object
# graphie        imaginant
# lemme           imaginer
# infover          par:pre
# genre
# nombre
# occurrences          274
# rangFWV             9668
# Name: 9675, dtype: object
# graphie        fabriquant
# lemme           fabriquer
# infover           par:pre
# genre
# nombre
# occurrences           273
# rangFWV            9685.5
# Name: 9690, dtype: object
# graphie        dépendant
# lemme           dépendre
# infover          par:pre
# genre
# nombre
# occurrences          269
# rangFWV           9761.5
# Name: 9753, dtype: object
# graphie        couvrant
# lemme           couvrir
# infover         par:pre
# genre
# nombre
# occurrences         269
# rangFWV          9761.5
# Name: 9757, dtype: object
# graphie        promettant
# lemme           promettre
# infover           par:pre
# genre
# nombre
# occurrences           268
# rangFWV            9780.5
# Name: 9781, dtype: object
# graphie        suggérant
# lemme           suggérer
# infover          par:pre
# genre
# nombre
# occurrences          268
# rangFWV           9780.5
# Name: 9783, dtype: object
# graphie        ramenant
# lemme           ramener
# infover         par:pre
# genre
# nombre
# occurrences         268
# rangFWV          9780.5
# Name: 9784, dtype: object
# graphie         tapant
# lemme            taper
# infover        par:pre
# genre
# nombre
# occurrences        267
# rangFWV         9802.5
# Name: 9796, dtype: object
# graphie         fixant
# lemme            fixer
# infover        par:pre
# genre
# nombre
# occurrences        265
# rangFWV           9842
# Name: 9841, dtype: object
# graphie        discutant
# lemme           discuter
# infover          par:pre
# genre
# nombre
# occurrences          264
# rangFWV             9859
# Name: 9856, dtype: object
# graphie        emportant
# lemme           emporter
# infover          par:pre
# genre
# nombre
# occurrences          263
# rangFWV           9878.5
# Name: 9884, dtype: object
# graphie        entourant
# lemme           entourer
# infover          par:pre
# genre
# nombre
# occurrences          262
# rangFWV           9903.5
# Name: 9907, dtype: object
# graphie        profitant
# lemme           profiter
# infover          par:pre
# genre
# nombre
# occurrences          262
# rangFWV           9903.5
# Name: 9914, dtype: object
# graphie        lançant
# lemme           lancer
# infover        par:pre
# genre
# nombre
# occurrences        261
# rangFWV           9927
# Name: 9916, dtype: object
# graphie        ajoutant
# lemme           ajouter
# infover         par:pre
# genre
# nombre
# occurrences         260
# rangFWV          9951.5
# Name: 9951, dtype: object
# graphie        élevant
# lemme           élever
# infover        par:pre
# genre
# nombre
# occurrences        258
# rangFWV          10015
# Name: 10005, dtype: object
# graphie        confiant
# lemme           confier
# infover         par:pre
# genre
# nombre
# occurrences         257
# rangFWV           10038
# Name: 10039, dtype: object
# graphie        révélant
# lemme           révéler
# infover         par:pre
# genre
# nombre
# occurrences         256
# rangFWV           10062
# Name: 10053, dtype: object
# graphie        invitant
# lemme           inviter
# infover         par:pre
# genre
# nombre
# occurrences         256
# rangFWV           10062
# Name: 10057, dtype: object
# graphie        interdisant
# lemme            interdire
# infover            par:pre
# genre
# nombre
# occurrences            254
# rangFWV            10109.5
# Name: 10111, dtype: object
# graphie        rencontrant
# lemme           rencontrer
# infover            par:pre
# genre
# nombre
# occurrences            254
# rangFWV            10109.5
# Name: 10115, dtype: object
# graphie        imitant
# lemme           imiter
# ...
# graphie        cimentant
# lemme           cimenter
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106116, dtype: object
# graphie        cintrant
# lemme           cintrer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 106207, dtype: object
# graphie        claquemurant
# lemme           claquemurer
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 106267, dtype: object
# graphie        départageant
# lemme            départager
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 106281, dtype: object
# graphie        pirouettant
# lemme           pirouetter
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 106290, dtype: object
# graphie        civilisant
# lemme           civiliser
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 106322, dtype: object
# graphie        dépersonnalisant
# lemme           dépersonnaliser
# infover                 par:pre
# genre
# nombre
# occurrences                   1
# rangFWV                   96696
# Name: 106349, dtype: object
# graphie        pinaillant
# lemme           pinailler
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 106372, dtype: object
# graphie        dépeignant
# lemme           dépeigner
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 106392, dtype: object
# graphie        poissant
# lemme           poisser
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 106462, dtype: object
# graphie        démagnétisant
# lemme           démagnétiser
# infover              par:pre
# genre
# nombre
# occurrences                1
# rangFWV                96696
# Name: 106517, dtype: object
# graphie        politisant
# lemme           politiser
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 106526, dtype: object
# graphie        réembauchant
# lemme           réembaucher
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 106531, dtype: object
# graphie        réessayant
# lemme           réessayer
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 106575, dtype: object
# graphie        réemployant
# lemme           réemployer
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 106588, dtype: object
# graphie        déléguant
# lemme           déléguer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106638, dtype: object
# graphie        délogeant
# lemme            déloger
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106671, dtype: object
# graphie        pondérant
# lemme           pondérer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106706, dtype: object
# graphie        colmatant
# lemme           colmater
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106744, dtype: object
# graphie        plastifiant
# lemme           plastifier
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 106882, dtype: object
# graphie        déminant
# lemme           déminer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 106926, dtype: object
# graphie        régentant
# lemme           régenter
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 106948, dtype: object
# graphie        dématérialisant
# lemme           dématérialiser
# infover                par:pre
# genre
# nombre
# occurrences                  1
# rangFWV                  96696
# Name: 107094, dtype: object
# graphie        démerdant
# lemme           démerder
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 107206, dtype: object
# graphie        réfrénant
# lemme           réfréner
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 107231, dtype: object
# graphie         codant
# lemme            coder
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 107253, dtype: object
# graphie        pavoisant
# lemme           pavoiser
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 107282, dtype: object
# graphie        chapeautant
# lemme           chapeauter
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 107350, dtype: object
# graphie        désapprenant
# lemme          désapprendre
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 107361, dtype: object
# graphie        désassemblant
# lemme           désassembler
# infover              par:pre
# genre
# nombre
# occurrences                1
# rangFWV                96696
# Name: 107423, dtype: object
# graphie        pattant
# lemme           patter
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 107429, dtype: object
# graphie        chatoyant
# lemme           chatoyer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 107494, dtype: object
# graphie        désaccordant
# lemme           désaccorder
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 107505, dtype: object
# graphie        pelotonnant
# lemme           pelotonner
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 107529, dtype: object
# graphie        dérégulant
# lemme           déréguler
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 107532, dtype: object
# graphie        saillant
# lemme           saillir
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 107605, dtype: object
# graphie        désaltérant
# lemme           désaltérer
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 107634, dtype: object
# graphie        pellant
# lemme           peller
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 107652, dtype: object
# graphie        partouzant
# lemme           partouzer
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 107700, dtype: object
# graphie        censurant
# lemme           censurer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 107726, dtype: object
# graphie        désensibilisant
# lemme           désensibiliser
# infover                par:pre
# genre
# nombre
# occurrences                  1
# rangFWV                  96696
# Name: 107747, dtype: object
# graphie        cerclant
# lemme           cercler
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 107769, dtype: object
# graphie        sauçant
# lemme           saucer
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 107855, dtype: object
# graphie         celant
# lemme            celer
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 107861, dtype: object
# graphie        cendrant
# lemme           cendrer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 107873, dtype: object
# graphie        désaxant
# lemme           désaxer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 107936, dtype: object
# graphie        challengeant
# lemme            challenger
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 108008, dtype: object
# graphie        désengageant
# lemme            désengager
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 108047, dtype: object
# graphie        désenflant
# lemme           désenfler
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108057, dtype: object
# graphie        saturant
# lemme           saturer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 108066, dtype: object
# graphie        désemparant
# lemme           désemparer
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 108105, dtype: object
# graphie        dépravant
# lemme           dépraver
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108144, dtype: object
# graphie        chouravant
# lemme           chouraver
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108165, dtype: object
# graphie        dépossédant
# lemme           déposséder
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 108186, dtype: object
# graphie        rétroagissant
# lemme              rétroagir
# infover              par:pre
# genre
# nombre
# occurrences                1
# rangFWV                96696
# Name: 108211, dtype: object
# graphie        chloroformant
# lemme           chloroformer
# infover              par:pre
# genre
# nombre
# occurrences                1
# rangFWV                96696
# Name: 108251, dtype: object
# graphie        dépressurisant
# lemme           dépressuriser
# infover               par:pre
# genre
# nombre
# occurrences                 1
# rangFWV                 96696
# Name: 108279, dtype: object
# graphie        choppant
# lemme           chopper
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 108308, dtype: object
# graphie        châtrant
# lemme           châtrer
# infover         par:pre
# genre
# nombre
# occurrences           1
# rangFWV           96696
# Name: 108332, dtype: object
# graphie        déplumant
# lemme           déplumer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108351, dtype: object
# graphie        chronométrant
# lemme           chronométrer
# infover              par:pre
# genre
# nombre
# occurrences                1
# rangFWV                96696
# Name: 108446, dtype: object
# graphie        rétorquant
# lemme           rétorquer
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108469, dtype: object
# graphie        réticulant
# lemme           réticuler
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108474, dtype: object
# graphie        chroniquant
# lemme           chroniquer
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 108478, dtype: object
# graphie        dépolarisant
# lemme           dépolariser
# infover             par:pre
# genre
# nombre
# occurrences               1
# rangFWV               96696
# Name: 108508, dtype: object
# graphie        chevrotant
# lemme           chevroter
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108574, dtype: object
# graphie        réétudiant
# lemme           réétudier
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108588, dtype: object
# graphie        déraillant
# lemme           dérailler
# infover           par:pre
# genre
# nombre
# occurrences             1
# rangFWV             96696
# Name: 108597, dtype: object
# graphie        sablant
# lemme           sabler
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 108643, dtype: object
# graphie        sabordant
# lemme           saborder
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108686, dtype: object
# graphie        permutant
# lemme           permuter
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108763, dtype: object
# graphie        chipotant
# lemme           chipoter
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108836, dtype: object
# graphie        chinant
# lemme           chiner
# infover        par:pre
# genre
# nombre
# occurrences          1
# rangFWV          96696
# Name: 108850, dtype: object
# graphie        rééditant
# lemme           rééditer
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108886, dtype: object
# graphie        perfusant
# lemme           perfuser
# infover          par:pre
# genre
# nombre
# occurrences            1
# rangFWV            96696
# Name: 108932, dtype: object
# graphie        chiffonnant
# lemme           chiffonner
# infover            par:pre
# genre
# nombre
# occurrences              1
# rangFWV              96696
# Name: 108947, dtype: object

# %% [markdown]
# ### aggréger les comptes des formes artificiellement séparées par Lexique4
# - groupby graphie, lemme, case
#  - AUX et VER ensemble pour un même lemme
#  - les infover inf et inf; sont regroupés via la case inf
# - recalcul du rang après regroupements

# %%
dfV4=dfV4[~dfV4["case"].isin(["","pI3S"])]
dfV4=dfV4.groupby("graphie lemme case".split(" "))[["occurrences"]].sum().reset_index()
dfV4["rangFWV"]=dfV4["occurrences"].rank(ascending=False)
dfV4.sort_values("rangFWV").head()
# Out:
#        graphie  lemme  case  occurrences  rangFWV
# 40647      est   être  pi3S    7111273.0      1.0
# 2            a  avoir  pi3S    3668058.0      2.0
# 3187        ai  avoir  pi1S    2407163.0      3.0
# 6406        as  avoir  pi2S    1021787.0      4.0
# 101600   était   être  ii3S     982148.0      5.0

# %% [markdown]
# La fréquence cumulée pour chaque case donne une idée de la présence de la case dans le corpus. Mais cette fréquence est largement influencée par les formes de lexèmes extrèmement fréquents. La troisième personne du singulier du présent indicatif se situe largement au dessus de toutes les autres formes avec 17M. L'étude de la médiane ou du premier quartile donne une image moins biaisée des rapports de distribution entre les cases.

# %%
dfCasesTokens=dfV4[dfV4["case"]!=""].groupby("case")[["occurrences"]].sum().sort_values("occurrences",ascending=False)
dfCasesTokens.head()
# Out:
#       occurrences
# case
# pi3S   17617887.0
# inf    11917396.0
# pi1S    9144293.0
# ppMS    7704344.0
# pi2S    4043374.0

# %%
ax=dfCasesTokens.plot(kind="bar",figsize=(20,5))
#ax.set_yscale('log')

# %%
dfV4[dfV4["case"]!=""].groupby("case")[["occurrences"]].quantile(q=0.5).sort_values("occurrences",ascending=False).plot(kind="bar",figsize=(20,5))

# %%
dfV4[dfV4["case"]!=""].groupby("case")[["occurrences"]].quantile(q=0.75).sort_values("occurrences",ascending=False).plot(kind="bar",figsize=(20,5))

# %%
dfV4["nb"]=1
dfV4.head()
# Out:
#    graphie     lemme  case  occurrences  rangFWV  nb
# 0      -tu     taire  ppMS          8.0  47729.5   1
# 1        =    égaler  pi3S       4218.0   1474.0   1
# 2        a     avoir  pi3S    3668058.0      2.0   1
# 3        a     avoir  ppMS          1.0  91305.5   1
# 4  abaissa  abaisser  ai3S          5.0  55988.5   1

# %% [markdown]
# ### Lexèmes avec surabondance
# Pour les lexèmes sujets à surabondance, il est possible d'avoir plus de 51 formes listées mais une partie des lexèmes de la liste ne font pas partie des surabondants.

# %%
dfSurabondances=dfV4.groupby(["lemme","case"]).agg({"graphie":lambda x: "-".join(x),"nb":"count"}).reset_index()
dfL4Surabondances=dfSurabondances[dfSurabondances["nb"]>1]
dfL4Surabondances.to_csv(path_or_buf="PB-Lex4-Surabondances.csv",sep="\t",encoding="utf8")

# %%
dfL4Surabondances
# Out:
#              lemme  case  nb                        graphie
# 49      abandonner  ii3P   2        abandonnaient-abandonné
# 50      abandonner  ii3S   2          abandonnait-abandonné
# 53      abandonner  pI2P   2          abandonner-abandonnez
# 63      abandonner  pi2P   2          abandonner-abandonnez
# 112        abattre  pi2P   2                abattez-abattre
# 254        aborder  ii3P   2              abordaient-abordé
# 332         aboyer  pi2P   2                  aboyer-aboyez
# 499       absorber  ii3P   2            absorbaient-absorbé
# 531       absoudre  pi2P   2              absolvez-absoudre
# 594         abuser  ii3P   2                abusaient-abusé
# 595         abuser  ii3S   2                  abusait-abusé
# 608         abuser  pi2P   2                  abuser-abusez
# 664       accabler  ii3P   2            accablaient-accablé
# 690      accaparer  ii3S   2            accaparait-accaparé
# 720      accentuer  pi2P   2            accentuer-accentuez
# 742       accepter  ii3P   3  acceptaient-accepté-acceptées
# 743       accepter  ii3S   2              acceptait-accepté
# 747       accepter  pI2P   2              accepter-acceptez
# 757       accepter  pi2P   2              accepter-acceptez
# 923      accomplir  ii3S   2        accomplir-accomplissait
# 965       accorder  ii3S   2              accordait-accordé
# 976       accorder  pi1P   2             accordes-accordons
# 981       accorder  pi3S   2                accorde-accordé
# 1085     accoupler  pi2P   2            accoupler-accouplez
# 1163     accrocher  ii3P   2         accrochaient-accrochés
# 1167     accrocher  pI2P   2            accrocher-accrochez
# 1177     accrocher  pi2P   2            accrocher-accrochez
# 1350       accuser  ii3P   2              accusaient-accusé
# 1355       accuser  pI2P   2                accuser-accusez
# 1364       accuser  pi1S   2                  accuse-accusé
# ...            ...   ...  ..                            ...
# 99032      épuiser  ii3P   2              épuisaient-épuisé
# 99033      épuiser  ii3S   2                épuisait-épuisé
# 99044      épuiser  pi2P   2                épuiser-épuisez
# 99372       étayer  fi3P   2            étaieront-étayeront
# 99382       étayer  pi1S   2                    étaie-étaye
# 99385       étayer  pi3S   2                    étaie-étaye
# 99578       étirer  pI2P   2                  étirer-étirez
# 99646      étonner  pi2P   2                étonner-étonnez
# 99669     étouffer  ii3P   2            étouffaient-étouffé
# 99670     étouffer  ii3S   2              étouffait-étouffé
# 99851      étudier  ii3P   2              étudiaient-étudié
# 99852      étudier  ii3S   2                étudiait-étudié
# 99865      étudier  pi2P   2                étudier-étudiez
# 99898      évacuer  ii3S   2               évacuait-évacués
# 99945       évader  pi2P   2                  évader-évadez
# 99967      évaluer  ii3S   2                évaluait-évalué
# 99970      évaluer  pI2P   2                évaluer-évaluez
# 99979      évaluer  pi2P   2                évaluer-évaluez
# 100088    éveiller  pi2P   2              éveiller-éveillez
# 100129    éventrer  pi2P   2              éventrer-éventrez
# 100196   éviscérer  ii3S   2            éviscérait-éviscéré
# 100337        être  pI1P   2                  sommes-soyons
# 100338        être  pI2P   3                soyez-êtes-être
# 100339        être  pI2S   2                      sois-suis
# 100340        être  pc1P   2                 serais-serions
# 100342        être  pc2P   2                  serais-seriez
# 100348        être  pi2P   3               sommes-êtes-être
# 100349        être  pi2S   2                        es-suis
# 100356        être  ps2S   2                    sois-sommes
# 100357        être  ps3P   2                 soient-étaient
#
# [2045 rows x 4 columns]

# %%
dfL4LexFormesV=dfV4.groupby("lemme")[["occurrences","nb"]].count()
dfL4LexFormesV[dfL4LexFormesV["occurrences"]>51].index.tolist()
# Out:
# [u'aller',
#  u'asseoir',
#  u'avoir',
#  u'devoir',
#  u'donner',
#  u'effrayer',
#  u'envoyer',
#  u'essayer',
#  u'laisser',
#  u'payer',
#  u'penser',
#  u'porter',
#  u'pouvoir',
#  u'savoir',
#  u'trouver',
#  u'\xeatre']

# %% [markdown]
# ### regroupement des formes de lexème pour une même case

# %%
dfL4LexCasesV=dfV4.groupby(["lemme","case"]).sum().reset_index()

# %%
dfCasesTypes=dfL4LexCasesV[dfL4LexCasesV["case"]!=""].groupby("case")[["occurrences"]].count().sort_values("occurrences",ascending=False)
dfCasesTypes.plot(kind="bar",figsize=(20,5))

# %% [markdown]
# # French Plat from Stump & Finkel (2013)

# %% [markdown]
# ## liste des microclasses de paradigmes radicaux

# %%
with codecs.open("Stump12.data","r",encoding="utf8") as fInput:
    stump12=[l.strip() for l in fInput.readlines()]

# %%
lStemIx={}
stemIx=0
for l in stump12[6:]:
    if l.startswith("CONJ"):
        print l
        stemIx+=1
        lStemIx[stemIx]=[]
        lStemIx[stemIx].append(re.split(ur"\s+",l))
    elif l.startswith("LEXEME"):
        break
    else:
        lStemIx[stemIx].append(re.split(ur"\s+",l))
# Out:
# CONJ      Stem1 Stem2 Stem3 Stem4 Stem5 Stem6 Stem7
# CONJ      Stem8 Stem9 Stem10
# CONJ      Stem10a Stem11 Stem12 Stem13
# CONJ      Stem14 Stem15 Stem16 Stem17 Stem18 Stem19

# %%
stem1=pd.DataFrame(lStemIx[1][2:-1]).set_index(0)
stem2=pd.DataFrame(lStemIx[2][2:-1]).set_index(0)
stem3=pd.DataFrame(lStemIx[3][2:-1]).set_index(0)
stem4=pd.DataFrame(lStemIx[4][2:-1]).set_index(0)

# %%
stem1.columns=["stem%02d"%(i+1) for i in range(7)]
stem2.columns=["stem%02d"%(i+1) for i in range(7,10)]
stem3.columns=["stem10a"]+["stem%02d"%(i+1) for i in range(10,13)]
stem4.columns=["stem%02d"%(i+1) for i in range(13,19)]

# %%
stems=pd.concat([stem1,stem2,stem3,stem4],axis=1)
stems#.head(25)
# Out:
#           stem01 stem02 stem03 stem04 stem05 stem06 stem07 stem08 stem09  \
# 0
# ÊTRE        -sɥi     -ɛ   !sɔm    !ɛt   -sɔ̃    -et   -etj    -fy    -fy
# AVOIR         -ɛ     -a    -av    -av    -ɔ̃    -av   -avj     -y     -y
# AIMER          -      -      -      -      -      -     -j     -ɛ     -a
# COLLER       -ɔl    -ɔl    -ol    -ol    -ɔl    -ol   -olj   -olɛ   -ola
# BEURRER      -œʁ    -œʁ    -øʁ    -øʁ    -œʁ    -øʁ   -øʁj   -øʁɛ   -øʁa
# DÉJEUNER       -      -      -      -      -      -     -j     -ɛ     -a
# ÉCROUER        -      -      -      -      -      -     -j     -ɛ     -a
# ÉCHOUER       -u     -u     -w     -w     -u     -w    -uj    -wɛ    -wa
# REFLUER        -      -      -      -      -      -     -j     -ɛ     -a
# REMUER        -y     -y     -ɥ     -ɥ     -y     -ɥ    -yj    -ɥɛ    -ɥa
# LEVER        -ɛv    -ɛv    -əv    -əv    -ɛv    -əv   -əvj   -əvɛ   -əva
# CÉDER        -ɛd    -ɛd    -ed    -ed    -ɛd    -ed   -edj   -edɛ   -eda
# COPIER        -i     -i     -j     -j     -i     -j     -j    -jɛ    -ja
# APPUYER        -      -     -j     -j      -     -j     -j    -jɛ    -ja
# BROYER         -      -     -j     -j      -     -j     -j    -jɛ    -ja
# ENVOYER      -wa    -wa   -waj   -waj    -wa   -waj   -waj  -wajɛ  -waja
# FINIR          -      -     -s     -s     -s     -s    -sj      -      -
# HAÏR          !ɛ     !ɛ     -s     -s     -s     -s    -sj      -      -
# ALLER        !vɛ    !va      -      -   !vɔ̃      -     -j     -ɛ     -a
# TENIR       -jɛ̃   -jɛ̃    -ən    -ən   -jɛn    -ən   -ənj    -ɛ̃    -ɛ̃
# ACQUÉRIR    -jɛʁ   -jɛʁ    -eʁ    -eʁ   -jɛʁ    -eʁ   -eʁj     -i     -i
# SENTIR         -      -     -t     -t     -t     -t    -tj    -ti    -ti
# VÊTIR          -      -     -t     -t     -t     -t    -tj    -ti    -ti
# COUVRIR       -ʁ     -ʁ     -ʁ     -ʁ     -ʁ     -ʁ   -ʁij    -ʁi    -ʁi
# CUEILLIR     -œj    -œj    -øj    -øj    -œj    -øj    -øj   -øji   -øji
# ASSAILLIR      -      -      -      -      -      -      -     -i     -i
# BOUILLIR       -      -     -j     -j     -j     -j     -j    -ji    -ji
# DORMIR         -      -     -m     -m     -m     -m    -mj    -mi    -mi
# COURIR         -      -      -      -      -      -     -j     -y     -y
# MOURIR       -œʁ    -œʁ    -uʁ    -uʁ    -œʁ    -uʁ   -uʁj   -uʁy   -uʁy
# ...          ...    ...    ...    ...    ...    ...    ...    ...    ...
# ASSEOIR2     -je    -je    -ɛj    -ɛj    -ɛj    -ɛj    -ɛj     -i     -i
# SURSEOIR     -wa    -wa   -waj   -waj    -wa   -waj   -waj     -i     -i
# RENDRE         -      -     -d     -d     -d     -d    -dj    -di    -di
# PRENDRE      -ɑ̃    -ɑ̃    -ən    -ən    -ɛn    -ən   -ənj     -i     -i
# BATTRE         -      -     -t     -t     -t     -t    -tj    -ti    -ti
# METTRE        -ɛ     -ɛ    -ɛt    -ɛt    -ɛt    -ɛt   -ɛtj     -i     -i
# PEINDRE      -ɛ̃    -ɛ̃    -ɛɲ    -ɛɲ    -ɛɲ    -ɛɲ    -ɛɲ   -ɛɲi   -ɛɲi
# JOINDRE      -ɛ̃    -ɛ̃    -aɲ    -aɲ    -aɲ    -aɲ    -aɲ   -aɲi   -aɲi
# CRAINDRE     -ɛ̃    -ɛ̃    -ɛɲ    -ɛɲ    -ɛɲ    -ɛɲ    -ɛɲ   -ɛɲi   -ɛɲi
# VAINCRE        -      -     -k     -k     -k     -k    -kj    -ki    -ki
# FAIRE         -ɛ     -ɛ    -əz   !fɛt    -ɔ̃    -əz   -əzj     -i     -i
# PLAIRE        -ɛ     -ɛ    -ɛz    -ɛz    -ɛz    -ɛz   -ɛzj     -y     -y
# CONNAÎTRE     -ɛ     -ɛ    -ɛs    -ɛs    -ɛs    -ɛs   -ɛsj     -y     -y
# NAÎTRE        -ɛ     -ɛ    -ɛs    -ɛs    -ɛs    -ɛs   -ɛsj   -aki   -aki
# REPAÎTRE      -ɛ     -ɛ    -ɛs    -ɛs    -ɛs    -ɛs   -ɛsj     -y     -y
# CROÎTRE      -wa    -wa   -was   -was   -was   -was  -wasj     -y     -y
# CROIRE       -wa    -wa   -waj   -waj    -wa   -waj   -waj     -y     -y
# BOIRE        -wa    -wa    -yv    -yv   -wav    -yv   -yvj     -y     -y
# CONCLURE       -      -      -      -      -      -     -j      -      -
# INCLURE        -      -      -      -      -      -     -j      -      -
# COUDRE         -      -     -z     -z     -z     -z    -zj    -zi    -zi
# MOUDRE         -      -     -l     -l     -l     -l    -lj    -ly    -ly
# SUIVRE         -      -     -v     -v     -v     -v    -vj    -vi    -vi
# VIVRE         -i     -i    -iv    -iv    -iv    -iv   -ivj   -ɛky   -ɛky
# LIRE          -i     -i    -iz    -iz    -iz    -iz   -izj     -y     -y
# DIRE           -      -     -z   !dit     -z     -z    -zj      -      -
# RIRE          -i     -i    -ij    -ij     -i    -ij    -ij     -i     -i
# ÉCRIRE         -      -     -v     -v     -v     -v    -vj    -vi    -vi
# CONFIRE        -      -     -z     -z     -z     -z    -zj      -      -
# CUIRE          -      -     -z     -z     -z     -z    -zj    -zi    -zi
#
#           stem10  stem10a stem11 stem12 stem13 stem14 stem15  stem16 stem17  \
# 0
# ÊTRE         -sə     -səʁ   -swa  -swaj   -swa  -swaj  -swaj    -etʁ    -et
# AVOIR         -o      -oʁ     -ɛ    -ɛj     -ɛ    -ɛj    -ɛj  -avwaʁ    -ɛj
# AIMER         -ə      -əʁ      -     -j      -      -      -      -e      -
# COLLER      -olə    -oləʁ    -ɔl   -olj    -ɔl    -ol    -ol    -ole    -ol
# BEURRER     -œʁə    -œʁəʁ    -œʁ   -øʁj    -œʁ    -øʁ    -øʁ    -øʁe    -øʁ
# DÉJEUNER      -ə      -əʁ      -     -j      -      -      -      -e      -
# ÉCROUER        -       -ʁ      -     -j      -      -      -      -e      -
# ÉCHOUER       -u      -uʁ     -u    -uj     -u     -w     -w     -we     -w
# REFLUER        -       -ʁ      -     -j      -      -      -      -e      -
# REMUER        -y      -yʁ     -y    -yj     -y     -ɥ     -ɥ     -ɥe     -ɥ
# LEVER       -ɛvə    -ɛvəʁ    -ɛv   -əvj    -ɛv    -əv    -əv    -əve    -əv
# CÉDER       -ɛdə    -ɛdəʁ    -ɛd   -edj    -ɛd    -ed    -ed    -ede    -ed
# COPIER        -i      -iʁ     -i     -j     -i     -j     -j     -je     -j
# APPUYER        -       -ʁ      -     -j      -     -j     -j     -je     -j
# BROYER         -       -ʁ      -     -j      -     -j     -j     -je     -j
# ENVOYER       -ɛ      -ɛʁ    -wa   -waj    -wa   -waj   -waj   -waje   -waj
# FINIR          -       -ʁ     -s    -sj      -     -s     -s      -ʁ     -s
# HAÏR           -       -ʁ     -s    -sj     !ɛ     -s     -s      -ʁ     -s
# ALLER         @i      @iʁ    !aj     -j    !va      -      -      -e      -
# TENIR      -jɛ̃d  -jɛ̃dʁi   -jɛn   -ənj   -jɛ̃    -ən    -ən   -əniʁ    -ən
# ACQUÉRIR     -eʁ     -eʁʁ   -jɛʁ   -eʁj   -jɛʁ    -eʁ    -eʁ   -eʁiʁ    -ɛʁ
# SENTIR       -ti     -tiʁ     -t    -tj      -     -t     -t    -tiʁ     -t
# VÊTIR        -ti     -tiʁ     -t    -tj      -     -t     -t    -tiʁ     -t
# COUVRIR      -ʁi     -ʁiʁ     -ʁ   -ʁij     -ʁ     -ʁ     -ʁ    -ʁiʁ     -ʁ
# CUEILLIR    -œjə    -œjəʁ    -œj    -øj    -œj    -øj    -øj   -øjiʁ    -øj
# ASSAILLIR     -i      -iʁ      -      -      -      -      -     -iʁ      -
# BOUILLIR     -ji     -jiʁ     -j     -j      -     -j     -j    -jiʁ     -j
# DORMIR       -mi     -miʁ     -m    -mj      -     -m     -m    -miʁ     -m
# COURIR         -       -ʁ      -     -j      -      -      -     -iʁ      -
# MOURIR       -uʁ     -uʁʁ    -œʁ   -uʁj    -œʁ    -uʁ    -uʁ   -uʁiʁ    -uʁ
# ...          ...      ...    ...    ...    ...    ...    ...     ...    ...
# ASSEOIR2     -je     -jeʁ    -ɛj    -ɛj    -je    -ɛj    -ɛj    -waʁ    -ɛj
# SURSEOIR     -wa     -waʁ    -wa   -waj    -wa   -waj   -waj    -waʁ   -waj
# RENDRE        -d     -dʁi     -d    -dj      -     -d     -d     -dʁ     -d
# PRENDRE     -ɑ̃d   -ɑ̃dʁi    -ɛn   -ənj    -ɑ̃    -ən    -ən   -ɑ̃dʁ    -ən
# BATTRE        -t     -tʁi     -t    -tj      -     -t     -t     -tʁ     -t
# METTRE       -ɛt    -ɛtʁi    -ɛt   -ɛtj     -ɛ    -ɛt    -ɛt    -ɛtʁ    -ɛt
# PEINDRE     -ɛ̃d   -ɛ̃dʁi    -ɛɲ    -ɛɲ    -ɛ̃    -ɛɲ    -ɛɲ   -ɛ̃dʁ    -ɛɲ
# JOINDRE     -ɛ̃d   -ɛ̃dʁi    -aɲ    -aɲ    -ɛ̃    -aɲ    -aɲ   -ɛ̃dʁ    -aɲ
# CRAINDRE    -ɛ̃d   -ɛ̃dʁi    -ɛɲ    -ɛɲ    -ɛ̃    -ɛɲ    -ɛɲ   -ɛ̃dʁ    -ɛɲ
# VAINCRE       -k     -kʁi     -k    -kj      -     -k     -k     -kʁ     -k
# FAIRE         -ə      -əʁ    -as   -asj     -ɛ    -əz   !fɛt     -ɛʁ    -əz
# PLAIRE        -ɛ      -ɛʁ    -ɛz   -ɛzj     -ɛ    -ɛz    -ɛz     -ɛʁ    -ɛz
# CONNAÎTRE    -ɛt    -ɛtʁi    -ɛs   -ɛsj     -ɛ    -ɛs    -ɛs    -ɛtʁ    -ɛs
# NAÎTRE       -ɛt    -ɛtʁi    -ɛs   -ɛsj     -ɛ    -ɛs    -ɛs    -ɛtʁ    -ɛs
# REPAÎTRE     -ɛt    -ɛtʁi    -ɛs   -ɛsj     -ɛ    -ɛs    -ɛs    -ɛtʁ    -ɛs
# CROÎTRE     -wat   -watʁi   -was  -wasj    -wa   -was   -was   -watʁ   -was
# CROIRE       -wa     -waʁ    -wa   -waj    -wa   -waj   -waj    -waʁ   -waj
# BOIRE        -wa     -waʁ   -wav   -yvj    -wa    -yv    -yv    -waʁ    -yv
# CONCLURE       -       -ʁ      -     -j      -      -      -      -ʁ      -
# INCLURE        -       -ʁ      -     -j      -      -      -      -ʁ      -
# COUDRE        -d     -dʁi     -z    -zj      -     -z     -z     -dʁ     -z
# MOUDRE        -d     -dʁi     -l    -lj      -     -l     -l     -dʁ     -l
# SUIVRE        -v     -vʁi     -v    -vj      -     -v     -v     -vʁ     -v
# VIVRE        -iv    -ivʁi    -iv   -ivj     -i    -iv    -iv    -ivʁ    -iv
# LIRE          -i      -iʁ    -iz   -izj     -i    -iz    -iz     -iʁ    -iz
# DIRE           -       -ʁ     -z    -zj      -     -z   !dit      -ʁ     -z
# RIRE          -i      -iʁ     -i    -ij     -i    -ij    -ij     -iʁ     -j
# ÉCRIRE         -       -ʁ     -v    -vj      -     -v     -v      -ʁ     -v
# CONFIRE        -       -ʁ     -z    -zj      -     -z     -z      -ʁ     -z
# CUIRE          -       -ʁ     -z    -zj      -     -z     -z      -ʁ     -z
#
#           stem18 stem19
# 0
# ÊTRE        -ete   -ete
# AVOIR         -y     -y
# AIMER         -e     -e
# COLLER      -ole   -ole
# BEURRER     -øʁe   -øʁe
# DÉJEUNER      -e     -e
# ÉCROUER       -e     -e
# ÉCHOUER      -we    -we
# REFLUER       -e     -e
# REMUER       -ɥe    -ɥe
# LEVER       -əve   -əve
# CÉDER       -ede   -ede
# COPIER       -je    -je
# APPUYER      -je    -je
# BROYER       -je    -je
# ENVOYER    -waje  -waje
# FINIR          -      -
# HAÏR           -      -
# ALLER         -e     -e
# TENIR       -əny   -əny
# ACQUÉRIR      -i    -iz
# SENTIR       -ti    -ti
# VÊTIR        -ty    -ty
# COUVRIR      -ɛʁ   -ɛʁt
# CUEILLIR    -øji   -øji
# ASSAILLIR     -i     -i
# BOUILLIR     -ji    -ji
# DORMIR       -mi    -mi
# COURIR        -y     -y
# MOURIR       -ɔʁ   -ɔʁt
# ...          ...    ...
# ASSEOIR2      -i    -iz
# SURSEOIR      -i    -iz
# RENDRE       -dy    -dy
# PRENDRE       -i    -iz
# BATTRE       -ty    -ty
# METTRE        -i    -iz
# PEINDRE      -ɛ̃   -ɛ̃t
# JOINDRE      -ɛ̃   -ɛ̃t
# CRAINDRE     -ɛ̃   -ɛ̃t
# VAINCRE      -ky    -ky
# FAIRE         -ɛ    -ɛt
# PLAIRE        -y     -y
# CONNAÎTRE     -y     -y
# NAÎTRE        -e     -e
# REPAÎTRE      -y     -y
# CROÎTRE       -y     -y
# CROIRE        -y     -y
# BOIRE         -y     -y
# CONCLURE       -      -
# INCLURE        -     -z
# COUDRE       -zy    -zy
# MOUDRE       -ly    -ly
# SUIVRE       -vi    -vi
# VIVRE       -ɛky   -ɛky
# LIRE          -y     -y
# DIRE           -     -t
# RIRE          -i     -i
# ÉCRIRE         -     -t
# CONFIRE        -     -t
# CUIRE          -     -t
#
# [72 rows x 20 columns]

# %% [markdown]
# ## Liste des microclasses de paradigmes morphosyntaxiques
# - génération des étiquettes de cellules
# - génération des patrons de formes pour les microclasses

# %%
noAffix="inf ppMS ppMP ppFS ppFP pi1S pi2S pi3S pi3P".split(" ")+ \
        "ps1S ps2S ps3S ps3P ai1S ai2S ai3S is3S pI2S".split(" ")
def inflectStem(microclasse,case):
    stem=stems[stems.index==microclasse][selectStem[case]].values[0]
    if case in noAffix:
        result=stem
    elif "1P" in case:
        if "!" not in stem:
            if case=="pc1P":
                result=stem+u"jɔ̃"
            elif case=="fi1P":
                result=stem+u"ʁɔ̃"
            elif case=="ai1P":
                result=stem+u"m"
            else:
                result=stem+u"ɔ̃"
        else:
            result=stem
    elif "2P" in case:
        if "!" not in stem:
            if case=="pc2P":
                result=stem+u"je"
            elif case=="fi2P":
                result=stem+u"ʁe"
            elif case=="ai2P":
                result=stem+u"t"
            else:
                result=stem+u"e"
        else:
            result=stem
    elif case=="ai3P":
        result=stem+u"ʁ"
    elif "fi" in case:
        result=stem+u"ʁ"
        if "1S" in case:
            result=result+u"e"
        elif "S" in case:
            result=result+u"a"
        elif "3P" in case:
            result=result+u"ɔ̃"
    elif "pc" in case:
        result=stem+u"ʁɛ"
    elif "ii" in case:
        result=stem+u"ɛ"
    elif "pP"==case:
        result=stem+u"ɑ̃"
    else:
        result="???"
    return result

# %%
selectStem={
     'ii1P': 'stem07',
     'ii1S': 'stem06',
     'ii2P': 'stem07',
     'ii2S': 'stem06',
     'ii3P': 'stem06',
     'ii3S': 'stem06',
     'ai1P': 'stem09',
     'ai1S': 'stem08',
     'ai2P': 'stem09',
     'ai2S': 'stem09',
     'ai3P': 'stem08',
     'ai3S': 'stem09',
     'is1P': 'stem09',
     'is1S': 'stem09',
     'is2P': 'stem09',
     'is2S': 'stem09',
     'is3P': 'stem09',
     'is3S': 'stem09',
    }

# %%
for c in selectStem:
    print c,inflectStem(u"LEVER",c)
# Out:
# ii1P -əvjɔ̃
# ii1S -əvɛ
# ii3P -əvɛ
# ai3P -əvɛʁ
# is2S ???
# ai3S -əva
# is1S ???
# is1P -əvaɔ̃
# ai2P -əvat
# ii3S -əvɛ
# ai2S -əva
# is3P ???
# is3S -əva
# ii2P -əvje
# ai1P -əvam
# ai1S -əvɛ
# ii2S -əvɛ
# is2P -əvae

# %% [raw]
# stemSlots=["stem%02d"%(i+1) for i in range(7)]+ \
#           ["stem%02d"%(i+1) for i in range(7,10)]+ \
#           ["stem10a"]+["stem%02d"%(i+1) for i in range(10,13)]+ \
#           ["stem%02d"%(i+1) for i in range(13,19)]
# {s:[""] for s in stemSlots}

# %%
stemSpaces={
     'stem01': ['pi1S'],
     'stem02': 'pi2S pi3S'.split(" "),
     'stem03': ['pi1P'],
     'stem04': ['pi2P'],
     'stem05': ['pi3P'],
     'stem06': "ii1S ii2S ii3S ii3P".split(" "),
     'stem07': "ii1P ii2P".split(" "),
     'stem08': "ai1S ai3P".split(" "),
     'stem09': "ai2S ai3S ai1P ai2P".split(" "),
     'stem10': "fi1S fi2S fi3S fi1P fi2P fi3P pc1S pc2S pc3S pc3P".split(" "),
     'stem10a': "pc1P pc2P".split(" "),
     'stem11': "ps1S ps2S ps3S ps3P".split(" "),
     'stem12': "ps1P ps2P".split(" "),
     'stem13': ['pI2S'],
     'stem14': ['pI1P'],
     'stem15': ['pI2P'],
     'stem16': ['inf'],
     'stem17': ['pP'],
     'stem18': "ppMS ppMP".split(" "),
     'stem19': "ppFS ppFP".split(" "),
            }
stemSpaces
# Out:
# {'stem01': ['pi1S'],
#  'stem02': ['pi2S', 'pi3S'],
#  'stem03': ['pi1P'],
#  'stem04': ['pi2P'],
#  'stem05': ['pi3P'],
#  'stem06': ['ii1S', 'ii2S', 'ii3S', 'ii3P'],
#  'stem07': ['ii1P', 'ii2P'],
#  'stem08': ['ai1S', 'ai3P'],
#  'stem09': ['ai2S', 'ai3S', 'ai1P', 'ai2P'],
#  'stem10': ['fi1S',
#   'fi2S',
#   'fi3S',
#   'fi1P',
#   'fi2P',
#   'fi3P',
#   'pc1S',
#   'pc2S',
#   'pc3S',
#   'pc3P'],
#  'stem10a': ['pc1P', 'pc2P'],
#  'stem11': ['ps1S', 'ps2S', 'ps3S', 'ps3P'],
#  'stem12': ['ps1P', 'ps2P'],
#  'stem13': ['pI2S'],
#  'stem14': ['pI1P'],
#  'stem15': ['pI2P'],
#  'stem16': ['inf'],
#  'stem17': ['pP'],
#  'stem18': ['ppMS', 'ppMP'],
#  'stem19': ['ppFS', 'ppFP']}

# %%
selectStem={}
for s,cells in stemSpaces.iteritems():
    for c in cells:
        selectStem[c]=s
selectStem
# Out:
# {'ai1P': 'stem09',
#  'ai1S': 'stem08',
#  'ai2P': 'stem09',
#  'ai2S': 'stem09',
#  'ai3P': 'stem08',
#  'ai3S': 'stem09',
#  'fi1P': 'stem10',
#  'fi1S': 'stem10',
#  'fi2P': 'stem10',
#  'fi2S': 'stem10',
#  'fi3P': 'stem10',
#  'fi3S': 'stem10',
#  'ii1P': 'stem07',
#  'ii1S': 'stem06',
#  'ii2P': 'stem07',
#  'ii2S': 'stem06',
#  'ii3P': 'stem06',
#  'ii3S': 'stem06',
#  'inf': 'stem16',
#  'pI1P': 'stem14',
#  'pI2P': 'stem15',
#  'pI2S': 'stem13',
#  'pP': 'stem17',
#  'pc1P': 'stem10a',
#  'pc1S': 'stem10',
#  'pc2P': 'stem10a',
#  'pc2S': 'stem10',
#  'pc3P': 'stem10',
#  'pc3S': 'stem10',
#  'pi1P': 'stem03',
#  'pi1S': 'stem01',
#  'pi2P': 'stem04',
#  'pi2S': 'stem02',
#  'pi3P': 'stem05',
#  'pi3S': 'stem02',
#  'ppFP': 'stem19',
#  'ppFS': 'stem19',
#  'ppMP': 'stem18',
#  'ppMS': 'stem18',
#  'ps1P': 'stem12',
#  'ps1S': 'stem11',
#  'ps2P': 'stem12',
#  'ps2S': 'stem11',
#  'ps3P': 'stem11',
#  'ps3S': 'stem11'}
