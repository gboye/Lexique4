# %% [markdown]
# # Étude de la distribution des formes verbales dans les paradigmes pour Lexique4
#
# ## Préparation des données
# - lecture du fichier TSV
# - préparation des graphiques Seaborn
# - filtrage des éléments incohérents
# - regroupement des doublons
# - ajout d'une colonne pour les cases du paradigme (infover2Case)
#
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
# - [CF Stump & Finkel](#CF-StumpFinkel)
# - [Heatmap CF](#CF-Mosaic)
# - [Tri CF Fin](#TriCF)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.transforms as transforms
from IPython.display import display,HTML
import pyperclip,re
import EspacesThematiques as ET
from EspacesThematiques import *

repFigs="/Users/gilles/ownCloud/Recherche/Boye/HDR/Memoire/figs/"
# Out:
# S Z N J ê ô â r E H O 6 9 2

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("hls")
sns.set_color_codes("muted")
# sns.palplot(sns.color_palette("hls", 8))
# sns.palplot(sns.color_palette("husl", 8))

# %% [markdown]
# # Importation de Lexique4-Verbes

# %%
dfV=pd.read_csv("Lexique4-Verbes.tsv",sep="\t",encoding="utf8")
# dfV

# %%
# etCols=[c for et in etCells for c in et] #déplacé dans ET
dfCasesTokens=dfV.groupby(["case"])[["occurrences"]].sum().sort_values("occurrences",ascending=False)
tokenCols=dfCasesTokens.index.tolist()
dfCasesTypes=dfV.groupby(["case"])[["occurrences"]].count().sort_values("occurrences",ascending=False)
typeCols=dfCasesTypes.index.tolist()

# %%
exemplaireCases=set(dfV.case.unique())
nbCases=len(exemplaireCases)

# %%
dfVerbesNbCases=dfV[dfV.case!=""].groupby(["lexeme","case"])["occurrences"].count().groupby("lexeme").count().sort_values(ascending=False)
dfVerbesNbCases
# Out:
# lexeme
# avoir            51
# faire            50
# devoir           50
# mettre           49
# savoir           49
# être             48
# prendre          48
# connaître        47
# venir            47
# aller            47
# entendre         47
# voir             47
# pouvoir          47
# dire             47
# devenir          47
# donner           46
# rester           46
# trouver          46
# envoyer          46
# laisser          46
# vouloir          46
# croire           46
# porter           45
# manquer          45
# aimer            45
# apprendre        45
# retirer          45
# parler           45
# passer           45
# demander         45
#                  ..
# engainer          1
# mâchurer          1
# revacciner        1
# mordorer          1
# duplexer          1
# enkyster          1
# mitrer            1
# dopa              1
# entabler          1
# enstérer          1
# boyauter          1
# bouturer          1
# refortifier       1
# boustifailler     1
# doublonner        1
# doucir            1
# mithridatiser     1
# dragonner         1
# droper            1
# enrégimenter      1
# dragéifier        1
# moleter           1
# enrouiller        1
# bouliner          1
# vermiculer        1
# boulanger         1
# vermifuger        1
# enlier            1
# vernisser         1
# volleyer          1
# Name: occurrences, Length: 6548, dtype: int64

# %% [markdown]
# <a id='TriCF'></a>
# # Tri des verbes en classes flexionnelles
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
#     - [Groupe 1](#Groupe1)
#     - [Groupe 2](#Groupe2)
#     - [Groupe 3](#Groupe3)
# - [CF Stump & Finkel](#CF-StumpFinkel)
# - [Heatmap CF](#CF-Heatmap)
# - [Tri CF Fin](#TriCF)

# %% [markdown]
# <a id="Groupe1"></a>
# ### Tri des verbes en -er
# - classes flexionnelles des exceptions
#     - envoyer
#     - aller
# - classes flexionnelles phonologiques
#     - CGer
#     - uyer, oyer
#     - ayer
#
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
#     - [Groupe 1](#Groupe1)
#     - [Groupe 2](#Groupe2)
#     - [Groupe 3](#Groupe3)

# %%
cf={}
triCF="SF"
triCF=""

G1=dfVerbesNbCases[dfVerbesNbCases.index.str[-2:]=="er"].index.tolist()
cf[u"envoyer"]=u"envoyer, renvoyer".split(", ")
G1.remove(u"envoyer")
G1.remove(u"renvoyer")
cf[u"aller"]=[u"aller"]
G1.remove(u"aller")
CGer=[]
for v in G1:
    m=re.search(ur"[bcdfghjklmnpqrstvwxz]ier$",v)
    if m:
        CGer.append(v)
    m=re.search(ur"[bcdfhjklmnprstvwxz]uer$",v)
    if m:
        CGer.append(v)
    else:
        m=re.search(ur"[bcdfghjklmnpqrstvwxz]ouer$",v)
        if m:
            CGer.append(v)
cf[u"écrouer"]=CGer
uyer=[v for v in G1 if v[-4:]==u"uyer"]
oyer=[v for v in G1 if v[-4:]==u"oyer"]
cf[u"appuyer"]=uyer+oyer
notG1=[v for c in cf for v in cf[c]]
notG1
# Out:
# [u'tuer',
#  u'jouer',
#  u'marier',
#  u'continuer',
#  u'oublier',
#  u'appr\xe9cier',
#  u'\xe9tudier',
#  u'confier',
#  u'prier',
#  u'soucier',
#  u'sacrifier',
#  u'd\xe9fier',
#  u'louer',
#  u'v\xe9rifier',
#  u'crier',
#  u'lier',
#  u'\xe9vacuer',
#  u'supplier',
#  u'\xe9chouer',
#  u'publier',
#  u'avouer',
#  u'saluer',
#  u'\xe9valuer',
#  u'remercier',
#  u'habituer',
#  u'renier',
#  u'associer',
#  u'r\xe9concilier',
#  u'fier',
#  u'identifier',
#  u'distribuer',
#  u'n\xe9gocier',
#  u'nier',
#  u'secouer',
#  u'remuer',
#  u'm\xe9fier',
#  u'contribuer',
#  u'vouer',
#  u'\xe9voluer',
#  u'planifier',
#  u'plier',
#  u'parier',
#  u'attribuer',
#  u'r\xe9fugier',
#  u'diminuer',
#  u'chier',
#  u'justifier',
#  u'rejouer',
#  u'exp\xe9dier',
#  u'b\xe9n\xe9ficier',
#  u'humilier',
#  u'constituer',
#  u'modifier',
#  u'photographier',
#  u'situer',
#  u'effectuer',
#  u'qualifier',
#  u'envier',
#  u'replier',
#  u'clouer',
#  u'remarier',
#  u'copier',
#  u'signifier',
#  u'mendier',
#  u'\xe9pier',
#  u'relier',
#  u'ruer',
#  u'purifier',
#  u'manier',
#  u'suer',
#  u'contrarier',
#  u'multiplier',
#  u'reconstituer',
#  u'insinuer',
#  u'licencier',
#  u'nouer',
#  u'rallier',
#  u'd\xe9lier',
#  u'crucifier',
#  u'\xe9crier',
#  u'scier',
#  u'tatouer',
#  u'certifier',
#  u'approprier',
#  u'simplifier',
#  u'trier',
#  u'perp\xe9tuer',
#  u'redistribuer',
#  u'cong\xe9dier',
#  u'd\xe9jouer',
#  u'expier',
#  u'allier',
#  u'entretuer',
#  u'd\xe9dier',
#  u'restituer',
#  u'd\xe9vouer',
#  u'att\xe9nuer',
#  u'r\xe9\xe9valuer',
#  u'initier',
#  u'amplifier',
#  u'prostituer',
#  u'puer',
#  u'trouer',
#  u'rapatrier',
#  u'terrifier',
#  u'statuer',
#  u'rectifier',
#  u'recopier',
#  u'incendier',
#  u'ch\xe2tier',
#  u'intensifier',
#  u'destituer',
#  u'clarifier',
#  u'\xe9ternuer',
#  u'varier',
#  u'diluer',
#  u'falsifier',
#  u'd\xe9vier',
#  u'diff\xe9rencier',
#  u'officier',
#  u'glorifier',
#  u'muer',
#  u'convier',
#  u'unifier',
#  u'renouer',
#  u'rouer',
#  u'privil\xe9gier',
#  u'amadouer',
#  u'gratifier',
#  u'charrier',
#  u'gracier',
#  u'polluer',
#  u'accentuer',
#  u'notifier',
#  u'd\xe9savouer',
#  u'rem\xe9dier',
#  u'skier',
#  u'substituer',
#  u'liqu\xe9fier',
#  u'fortifier',
#  u'r\xe9silier',
#  u'rassasier',
#  u'stup\xe9fier',
#  u'huer',
#  u'entre-tuer',
#  u'asphyxier',
#  u'photocopier',
#  u'\xe9difier',
#  u'injurier',
#  u'influer',
#  u'extasier',
#  u'irradier',
#  u'renflouer',
#  u'obstruer',
#  u'classifier',
#  u'bafouer',
#  u'authentifier',
#  u'rev\xe9rifier',
#  u't\xe9l\xe9graphier',
#  u'd\xe9pr\xe9cier',
#  u'colorier',
#  u'cartographier',
#  u'\xe9vertuer',
#  u'ratifier',
#  u'anesth\xe9sier',
#  u'd\xe9nier',
#  u'r\xe9pertorier',
#  u'd\xe9valuer',
#  u'instituer',
#  u'd\xe9nouer',
#  u'mortifier',
#  u'communier',
#  u'r\xe9exp\xe9dier',
#  u'r\xe9pudier',
#  u'sanctifier',
#  u'ren\xe9gocier',
#  u'affluer',
#  u'personnifier',
#  u'sp\xe9cifier',
#  u'diversifier',
#  u'autopsier',
#  u'd\xe9plier',
#  u'lubrifier',
#  u'sous-louer',
#  u'humidifier',
#  u'disqualifier',
#  u'dissocier',
#  u'amnistier',
#  u'd\xe9crier',
#  u'plagier',
#  u'balbutier',
#  u'tonifier',
#  u'remanier',
#  u'psalmodier',
#  u'inventorier',
#  u'estropier',
#  u'horrifier',
#  u'calomnier',
#  u'chor\xe9graphier',
#  u'exfolier',
#  u'commuer',
#  u'\xe9lectrifier',
#  u'p\xe9trifier',
#  u'allouer',
#  u'bonifier',
#  u'r\xe9tribuer',
#  u'radier',
#  u'momifier',
#  u'sous-\xe9valuer',
#  u'putr\xe9fier',
#  u'atrophier',
#  u'rar\xe9fier',
#  u'r\xe9unifier',
#  u'concilier',
#  u'd\xe9multiplier',
#  u'exproprier',
#  u'expatrier',
#  u'solidifier',
#  u'excommunier',
#  u'rabrouer',
#  u'radiographier',
#  u'mystifier',
#  u'engluer',
#  u'embuer',
#  u'magnifier',
#  u'r\xe9habituer',
#  u'flouer',
#  u'replanifier',
#  u'plastifier',
#  u'spolier',
#  u'ponctuer',
#  u'pallier',
#  u'orthographier',
#  u'ing\xe9nier',
#  u'd\xe9mystifier',
#  u'douer',
#  u'r\xe9approprier',
#  u'd\xe9ifier',
#  u'r\xe9\xe9tudier',
#  u'pacifier',
#  u'parodier',
#  u'nuer',
#  u'strier',
#  u'relouer',
#  u'remplier',
#  u'refluer',
#  u'salarier',
#  u'autographier',
#  u'scarifier',
#  u'vivifier',
#  u'cocufier',
#  u'codifier',
#  u'\xe9crouer',
#  u'requalifier',
#  u'quantifier',
#  u'dactylographier',
#  u'p\xe9pier',
#  u'calcifier',
#  u'd\xe9classifier',
#  u'ramifier',
#  u'ext\xe9nuer',
#  u'vitrifier',
#  u'touer',
#  u'avarier',
#  u'distancier',
#  u'enrouer',
#  u'sur\xe9valuer',
#  u'pontifier',
#  u'fluctuer',
#  u'apparier',
#  u'antijouer',
#  u'fructifier',
#  u'apostasier',
#  u'fluidifier',
#  u'ossifier',
#  u'd\xe9sertifier',
#  u'calligraphier',
#  u'conchier',
#  u'vicier',
#  u'enjouer',
#  u'disgracier',
#  u'conspuer',
#  u'domicilier',
#  u'affilier',
#  u'an\xe9mier',
#  u'd\xe9nuer',
#  u'r\xe9attribuer',
#  u'supplicier',
#  u'b\xeatifier',
#  u'\xe9brouer',
#  u'carier',
#  u'mythifier',
#  u's\xe9rier',
#  u'hypertrophier',
#  u'historier',
#  u'revivifier',
#  u'opacifier',
#  u'gaz\xe9ifier',
#  u'frigorifier',
#  u'graduer',
#  u'd\xe9clouer',
#  u'd\xe9calcifier',
#  u'torr\xe9fier',
#  u'fluer',
#  u'\xe9macier',
#  u'houer',
#  u'republier',
#  u'resituer',
#  u'st\xe9nographier',
#  u'd\xe9shabituer',
#  u'statufier',
#  u'stratifier',
#  u'd\xe9marier',
#  u'rigidifier',
#  u'densifier',
#  u'reclassifier',
#  u'g\xe9lifier',
#  u'chosifier',
#  u'panifier',
#  u'\xe9mulsifier',
#  u'versifier',
#  u'armorier',
#  u'nidifier',
#  u'\xe9berluer',
#  u'discontinuer',
#  u'b\xe9atifier',
#  u'confluer',
#  u'sinuer',
#  u'tum\xe9fier',
#  u'acidifier',
#  u'complexifier',
#  u'polycopier',
#  u'\xe9tanch\xe9ifier',
#  u'subsidier',
#  u'transmuer',
#  u'\xe9luer',
#  u'infatuer',
#  u'cin\xe9matographier',
#  u'pr\xe9judicier',
#  u'circonstancier',
#  u't\xe9l\xe9copier',
#  u'd\xe9nazifier',
#  u'exemplifier',
#  u'\xe9chographier',
#  u'engouer',
#  u'cryptographier',
#  u'surmultiplier',
#  u'r\xe9allouer',
#  u'd\xe9folier',
#  u'renvier',
#  u'diff\xe9rentier',
#  u'l\xe9nifier',
#  u'lithographier',
#  u'm\xe9sallier',
#  u'bossuer',
#  u'analg\xe9sier',
#  u'saponifier',
#  u'd\xe9sobstruer',
#  u'r\xe9ifier',
#  u'r\xe9instituer',
#  u'razzier',
#  u'starifier',
#  u'd\xe9parier',
#  u'd\xe9polluer',
#  u'obvier',
#  u'octavier',
#  u'resaluer',
#  u'individuer',
#  u'tonitruer',
#  u'recalcifier',
#  u'recrucifier',
#  u'd\xe9mythifier',
#  u'stipendier',
#  u'd\xe9planifier',
#  u'radiot\xe9l\xe9graphier',
#  u'd\xe9qualifier',
#  u'd\xe9sembuer',
#  u'antiqualifier',
#  u'd\xe9gluer',
#  u'tarifier',
#  u'recertifier',
#  u'prosodier',
#  u'reclouer',
#  u'remodifier',
#  u'r\xe9\xe9difier',
#  u'surjouer',
#  u'transsubstantier',
#  u'lignifier',
#  u'sursignifier',
#  u'typographier',
#  u'g\xe2tifier',
#  u'contre-v\xe9rifier',
#  u'contrev\xe9rifier',
#  u'nazifier',
#  u'enclouer',
#  u'embouer',
#  u'd\xe9certifier',
#  u'd\xe9codifier',
#  u'escoffier',
#  u'refortifier',
#  u'drag\xe9ifier',
#  u'enlier',
#  u'ennuyer',
#  u'appuyer',
#  u'essuyer',
#  u'd\xe9sennuyer',
#  u'noyer',
#  u'nettoyer',
#  u'employer',
#  u'd\xe9ployer',
#  u'broyer',
#  u'soudoyer',
#  u'apitoyer',
#  u'c\xf4toyer',
#  u'octroyer',
#  u'festoyer',
#  u'aboyer',
#  u'tutoyer',
#  u'foudroyer',
#  u'tournoyer',
#  u'fourvoyer',
#  u'convoyer',
#  u'ployer',
#  u'choyer',
#  u'vouvoyer',
#  u'red\xe9ployer',
#  u'rudoyer',
#  u'larmoyer',
#  u'd\xe9voyer',
#  u'flamboyer',
#  u'rougeoyer',
#  u'louvoyer',
#  u'guerroyer',
#  u'ondoyer',
#  u'verdoyer',
#  u'chatoyer',
#  u'avoyer',
#  u'sous-employer',
#  u'coudoyer',
#  u'atermoyer',
#  u'merdoyer',
#  u'corroyer',
#  u'r\xe9employer',
#  u'jointoyer',
#  u'poudroyer',
#  u'fossoyer',
#  u'voussoyer',
#  u'rejointoyer',
#  u'aller',
#  u'envoyer',
#  u'renvoyer']

# %%
cf[u"aimer"]=[v for v in G1 if v not in notG1]
cf[u"aimer"]
# Out:
# [u'donner',
#  u'rester',
#  u'trouver',
#  u'laisser',
#  u'porter',
#  u'manquer',
#  u'aimer',
#  u'retirer',
#  u'parler',
#  u'passer',
#  u'demander',
#  u'arriver',
#  u'penser',
#  u'rencontrer',
#  u'jeter',
#  u'rentrer',
#  u'regarder',
#  u'appeler',
#  u'acheter',
#  u'gagner',
#  u'poser',
#  u'attirer',
#  u'montrer',
#  u'd\xe9cider',
#  u'sauver',
#  u'toucher',
#  u'tirer',
#  u'payer',
#  u'abandonner',
#  u'rappeler',
#  u'commencer',
#  u'embrasser',
#  u'garder',
#  u'essayer',
#  u'entrer',
#  u'retourner',
#  u'retrouver',
#  u'arr\xeater',
#  u'chercher',
#  u'emmener',
#  u'\xe9couter',
#  u'examiner',
#  u'livrer',
#  u'br\xfbler',
#  u'tomber',
#  u'coucher',
#  u'd\xe9sirer',
#  u'd\xe9tester',
#  u'inqui\xe9ter',
#  u'lever',
#  u'emporter',
#  u'amuser',
#  u'ramener',
#  u'raconter',
#  u'r\xe9cup\xe9rer',
#  u'amener',
#  u'r\xe9veiller',
#  u'accuser',
#  u'attraper',
#  u'surveiller',
#  u'aider',
#  u'refuser',
#  u'accepter',
#  u'approcher',
#  u'annoncer',
#  u'frapper',
#  u'ignorer',
#  u'apporter',
#  u'entra\xeener',
#  u'voler',
#  u'discuter',
#  u'souhaiter',
#  u'serrer',
#  u'\xe9chapper',
#  u'sauter',
#  u'cr\xe9er',
#  u'ressembler',
#  u'virer',
#  u'rouler',
#  u'enfermer',
#  u'engager',
#  u'installer',
#  u'proposer',
#  u'quitter',
#  u'changer',
#  u'chanter',
#  u'tenter',
#  u'mener',
#  u'observer',
#  u'\xe9loigner',
#  u'prot\xe9ger',
#  u'manger',
#  u'pr\xe9parer',
#  u'pr\xe9senter',
#  u'tourner',
#  u'lib\xe9rer',
#  u'pardonner',
#  u'inviter',
#  u'rapporter',
#  u'compter',
#  u'juger',
#  u'r\xeaver',
#  u'd\xe9poser',
#  u'diriger',
#  u'disputer',
#  u'placer',
#  u'occuper',
#  u'pleurer',
#  u'douter',
#  u'supporter',
#  u'sembler',
#  u'd\xe9barrasser',
#  u'int\xe9resser',
#  u'pousser',
#  u'inventer',
#  u'remarquer',
#  u'recommencer',
#  u'rater',
#  u'lancer',
#  u'forcer',
#  u'utiliser',
#  u'fermer',
#  u'expliquer',
#  u'r\xe9parer',
#  u'exister',
#  u'l\xe2cher',
#  u'respirer',
#  u'marcher',
#  u'traiter',
#  u'monter',
#  u'profiter',
#  u'r\xe9aliser',
#  u'partager',
#  u'blesser',
#  u'adresser',
#  u'adorer',
#  u'avancer',
#  u'admirer',
#  u'concentrer',
#  u'contr\xf4ler',
#  u'balancer',
#  u'cacher',
#  u'attaquer',
#  u'accorder',
#  u'\xe9pouser',
#  u'cesser',
#  u'chasser',
#  u'casser',
#  u'couper',
#  u'\xe9changer',
#  u'attacher',
#  u'risquer',
#  u'consid\xe9rer',
#  u'\xe9pargner',
#  u'filer',
#  u'emp\xeacher',
#  u'm\xe9riter',
#  u'enqu\xeater',
#  u'enlever',
#  u'\xe9craser',
#  u'enfoncer',
#  u'esp\xe9rer',
#  u'planter',
#  u'glisser',
#  u'enterrer',
#  u'verser',
#  u'enseigner',
#  u'ajouter',
#  u'opposer',
#  u'tra\xeener',
#  u'traverser',
#  u'travailler',
#  u'comparer',
#  u'transporter',
#  u'calmer',
#  u'transformer',
#  u'arranger',
#  u'menacer',
#  u'arracher',
#  u'charger',
#  u'rejeter',
#  u'regretter',
#  u'rechercher',
#  u'imaginer',
#  u'respecter',
#  u'rassembler',
#  u'tromper',
#  u'interroger',
#  u'briser',
#  u'imposer',
#  u'm\xealer',
#  u'd\xe9m\xe9nager',
#  u'accrocher',
#  u'voyager',
#  u'd\xe9gager',
#  u'crever',
#  u'songer',
#  u'd\xe9clarer',
#  u'prouver',
#  u'divorcer',
#  u'pr\xe9f\xe9rer',
#  u'repousser',
#  u'moquer',
#  u's\xe9parer',
#  u'promener',
#  u'reposer',
#  u'pr\xeater',
#  u'rel\xe2cher',
#  u'\xe9carter',
#  u'accompagner',
#  u'am\xe9liorer',
#  u'habiller',
#  u'approuver',
#  u'insulter',
#  u'allonger',
#  u'consacrer',
#  u'guider',
#  u'pencher',
#  u'sucer',
#  u'f\xe9liciter',
#  u'd\xe9placer',
#  u'fouiller',
#  u'former',
#  u'marquer',
#  u'renoncer',
#  u'cogner',
#  u'torturer',
#  u'soulever',
#  u'\xe9viter',
#  u'capturer',
#  u'commander',
#  u'\xe9lever',
#  u'd\xe9barquer',
#  u'danser',
#  u'd\xe9brouiller',
#  u'traquer',
#  u'rattraper',
#  u'd\xe9chirer',
#  u'jurer',
#  u'sonner',
#  u'augmenter',
#  u'assurer',
#  u'ordonner',
#  u'organiser',
#  u'soigner',
#  u'prononcer',
#  u'adopter',
#  u'effrayer',
#  u'r\xe9clamer',
#  u'd\xe9vorer',
#  u'viser',
#  u'exposer',
#  u'poss\xe9der',
#  u'baisser',
#  u'envisager',
#  u'filmer',
#  u'vider',
#  u'envoler',
#  u'terminer',
#  u'baiser',
#  u'contacter',
#  u'r\xe9v\xe9ler',
#  u'violer',
#  u'effacer',
#  u'laver',
#  u'provoquer',
#  u'assister',
#  u'venger',
#  u'comporter',
#  u'couler',
#  u'annuler',
#  u'plonger',
#  u'veiller',
#  u'd\xe9velopper',
#  u'r\xe9server',
#  u'r\xe9p\xe9ter',
#  u'd\xeener',
#  u'fonder',
#  u'pr\xe9cipiter',
#  u'doubler',
#  u'pomper',
#  u'causer',
#  u'relever',
#  u'encourager',
#  u'embaucher',
#  u'trancher',
#  u'enregistrer',
#  u'nommer',
#  u'embarquer',
#  u'croiser',
#  u'lutter',
#  u'visiter',
#  u'd\xe9crocher',
#  u'oser',
#  u'piquer',
#  u'allumer',
#  u'stopper',
#  u'fumer',
#  u'r\xe9gler',
#  u'd\xe9penser',
#  u'financer',
#  u'buter',
#  u'hurler',
#  u'f\xeater',
#  u'\xe9prouver',
#  u'conserver',
#  u'habiter',
#  u'racheter',
#  u'\xe9touffer',
#  u'voter',
#  u'ficher',
#  u'bloquer',
#  u'd\xe9noncer',
#  u'repr\xe9senter',
#  u'go\xfbter',
#  u'insister',
#  u'foncer',
#  u'estimer',
#  u'creuser',
#  u'signer',
#  u'excuser',
#  u'exiger',
#  u'priver',
#  u'ranger',
#  u'ruiner',
#  u'contenter',
#  u'exploser',
#  u'bouger',
#  u'exprimer',
#  u'balader',
#  u'procurer',
#  u'ramasser',
#  u'persuader',
#  u'barrer',
#  u'refermer',
#  u'avaler',
#  u'pourchasser',
#  u'tailler',
#  u'recommander',
#  u'poignarder',
#  u'tester',
#  u'pointer',
#  u'participer',
#  u'assassiner',
#  u'p\xe9n\xe9trer',
#  u'botter',
#  u'bosser',
#  u'rapprocher',
#  u'reculer',
#  u'bl\xe2mer',
#  u'noter',
#  u'm\xe9priser',
#  u'\xe9clairer',
#  u'emm\xe9nager',
#  u'achever',
#  u'cracher',
#  u'entourer',
#  u'r\xe9sister',
#  u'supprimer',
#  u'errer',
#  u'activer',
#  u'vanter',
#  u'explorer',
#  u'faufiler',
#  u'r\xe9compenser',
#  u'r\xe9colter',
#  u'appliquer',
#  u'd\xe9tourner',
#  u'suicider',
#  u'c\xe9der',
#  u'dessiner',
#  u'distinguer',
#  u'soup\xe7onner',
#  u'dominer',
#  u'demeurer',
#  u'aborder',
#  u'c\xe9l\xe9brer',
#  u'v\xe9n\xe9rer',
#  u'abuser',
#  u'd\xe9guiser',
#  u'semer',
#  u'd\xe9livrer',
#  u'd\xe9ranger',
#  u'd\xe9rober',
#  u'consulter',
#  u'fixer',
#  u'condamner',
#  u'confesser',
#  u'informer',
#  u'confirmer',
#  u'interpr\xe9ter',
#  u'int\xe9grer',
#  u'massacrer',
#  u'implorer',
#  u'isoler',
#  u'remplacer',
#  u'transf\xe9rer',
#  u'tremper',
#  u'\xe9liminer',
#  u'l\xe9cher',
#  u'infliger',
#  u'reprocher',
#  u'conseiller',
#  u'impliquer',
#  u'confronter',
#  u'citer',
#  u'h\xe9siter',
#  u'g\xe9rer',
#  u'affronter',
#  u'grimper',
#  u'f\xe2cher',
#  u'deviner',
#  u'griller',
#  u'mentionner',
#  u'rembourser',
#  u'suspecter',
#  u'remonter',
#  u'afficher',
#  u'purger',
#  u'assumer',
#  u'raser',
#  u'supposer',
#  u'affecter',
#  u'analyser',
#  u'sugg\xe9rer',
#  u'p\xe9ter',
#  u'reparler',
#  u'renverser',
#  u'renseigner',
#  u'surmonter',
#  u'dicter',
#  u'taper',
#  u'fr\xe9quenter',
#  u'escalader',
#  u'exploiter',
#  u'ex\xe9cuter',
#  u'fabriquer',
#  u'facturer',
#  u'forger',
#  u't\xe9moigner',
#  u'frotter',
#  u'commenter',
#  u'garer',
#  u'g\xe2cher',
#  u'g\xeaner',
#  u'pr\xe9occuper',
#  u'indiquer',
#  u'inspirer',
#  u'trembler',
#  u'compl\xe9ter',
#  u'limiter',
#  u'corriger',
#  u'\xe9conomiser',
#  u'diviser',
#  u'draguer',
#  u'dresser',
#  u'd\xe9clencher',
#  u'd\xe9couper',
#  u'cuisiner',
#  u'd\xe9filer',
#  u'd\xe9foncer',
#  u'd\xe9jeuner',
#  u'd\xe9signer',
#  u'd\xe9tacher',
#  u'd\xe9terrer',
#  u'effondrer',
#  u'\xe9clater',
#  u'emb\xeater',
#  u'empoisonner',
#  u'emprunter',
#  u'encha\xeener',
#  u'communiquer',
#  u'h\xe9riter',
#  u'naviguer',
#  u'pi\xe9ger',
#  u'bombarder',
#  u'tracer',
#  u'\xe9nerver',
#  u'boucler',
#  u'pirater',
#  u'obliger',
#  u'peser',
#  u'baigner',
#  u'chevaucher',
#  u'nager',
#  u'm\xe9langer',
#  u'caresser',
#  u'op\xe9rer',
#  u'autoriser',
#  u'projeter',
#  u'proclamer',
#  u'coller',
#  u'coiffer',
#  u'presser',
#  u'masser',
#  u'mater',
#  u'aventurer',
#  u'paniquer',
#  u'tol\xe9rer',
#  u'efforcer',
#  u'perturber',
#  u'percer',
#  u'manifester',
#  u'craquer',
#  u'emparer',
#  u'enfiler',
#  u'engueuler',
#  u'enlacer',
#  u'assommer',
#  u'braver',
#  u'ramper',
#  u'piloter',
#  u'pratiquer',
#  u'droguer',
#  u'durer',
#  u'souffler',
#  u'questionner',
#  u'poster',
#  u'd\xe9coller',
#  u'plaider',
#  u'cultiver',
#  u'signaler',
#  u'raccrocher',
#  u'baser',
#  u'pi\xe9tiner',
#  u'rajouter',
#  u'd\xe9passer',
#  u'critiquer',
#  u'd\xe9p\xeacher',
#  u'pincer',
#  u'coop\xe9rer',
#  u'camper',
#  u'escorter',
#  u'espionner',
#  u'murmurer',
#  u'heurter',
#  u'miser',
#  u'imiter',
#  u'rep\xe9rer',
#  u'confisquer',
#  u'imprimer',
#  u'incliner',
#  u'inculper',
#  u'mesurer',
#  u'intercepter',
#  u'invoquer',
#  u'ma\xeetriser',
#  u'composer',
#  u'larguer',
#  u'lasser',
#  u'liquider',
#  u'localiser',
#  u'loger',
#  u'alerter',
#  u'retarder',
#  u'r\xe9chauffer',
#  u'offenser',
#  u'faciliter',
#  u'remporter',
#  u'contempler',
#  u'contaminer',
#  u'r\xe9citer',
#  u'fiancer',
#  u'flotter',
#  u'arroser',
#  u'riposter',
#  u'regagner',
#  u'affirmer',
#  u'gaspiller',
#  u'retomber',
#  u'\xf4ter',
#  u'abaisser',
#  u'\xe9veiller',
#  u'user',
#  u'\xe9tonner',
#  u'survoler',
#  u'surpasser',
#  u't\xe9l\xe9phoner',
#  u'\xe9vader',
#  u'\xe9puiser',
#  u'piller',
#  u'brancher',
#  u'reconsid\xe9rer',
#  u'd\xe9buter',
#  u'h\xe9berger',
#  u'honorer',
#  u'd\xe9corer',
#  u'sombrer',
#  u'arnaquer',
#  u'animer',
#  u'troubler',
#  u'marrer',
#  u'manipuler',
#  u'programmer',
#  u'balayer',
#  u'progresser',
#  u'souiller',
#  u'soulager',
#  u'd\xe9missionner',
#  u'armer',
#  u'siffler',
#  u'\xe9crouler',
#  u'bander',
#  u'gouverner',
#  u'aviser',
#  u'geler',
#  u'diffuser',
#  u'\xe9clipser',
#  u'r\xe9diger',
#  u'repasser',
#  u'r\xe9galer',
#  u'd\xe9boucher',
#  u'r\xe9conforter',
#  u'recruter',
#  u'disperser',
#  u'r\xe9gner',
#  u'dissimuler',
#  u'fourrer',
#  u'aspirer',
#  u'convoquer',
#  u'injecter',
#  u'd\xe9marrer',
#  u'gratter',
#  u'saboter',
#  u'triompher',
#  u'emmerder',
#  u'd\xe9shabiller',
#  u'choper',
#  u'adapter',
#  u'ridiculiser',
#  u'p\xeacher',
#  u'collaborer',
#  u'envelopper',
#  u'exp\xe9rimenter',
#  u'retravailler',
#  u'rigoler',
#  u'acc\xe9l\xe9rer',
#  u'acc\xe9der',
#  u'd\xe9tecter',
#  u'd\xe9terminer',
#  u'd\xe9valiser',
#  u'd\xe9voiler',
#  u'coincer',
#  u'exercer',
#  u'coffrer',
#  u'endurer',
#  u'capter',
#  u'agenouiller',
#  u'expulser',
#  u'inspecter',
#  u'protester',
#  u'taquiner',
#  u'compenser',
#  u'empirer',
#  u'\xe9trangler',
#  u'encaisser',
#  u'\xe9voquer',
#  u'empiler',
#  u'agiter',
#  u'sceller',
#  u'inverser',
#  u'classer',
#  u'chauffer',
#  u'redresser',
#  u'superviser',
#  u'n\xe9gliger',
#  u'tricher',
#  u'chuchoter',
#  u'chuter',
#  u'intimider',
#  u'influencer',
#  u'g\xe9n\xe9rer',
#  u'combler',
#  u'saigner',
#  u'infiltrer',
#  u'impressionner',
#  u'calculer',
#  u'\xe9garer',
#  u'innocenter',
#  u'importuner',
#  u'saouler',
#  u'tr\xe9bucher',
#  u'consoler',
#  u'interf\xe9rer',
#  u'braquer',
#  u'consommer',
#  u'combiner',
#  u'constater',
#  u'ligoter',
#  u'bouleverser',
#  u'bouffer',
#  u'harceler',
#  u'contourner',
#  u'refiler',
#  u'\xe9merger',
#  u'revendiquer',
#  u'apaiser',
#  u'restaurer',
#  u'pr\xe9ciser',
#  u'aggraver',
#  u'ajuster',
#  u'tarder',
#  u'd\xe9masquer',
#  u'pr\xe9server',
#  u'culpabiliser',
#  u'planquer',
#  u'd\xe9charger',
#  u'pisser',
#  u'appr\xeater',
#  u'pr\xe9lever',
#  u'embarrasser',
#  u'rassurer',
#  u'abriter',
#  u'enflammer',
#  u'tabasser',
#  u'absorber',
#  u'emballer',
#  u'rebeller',
#  u'raisonner',
#  u'accoucher',
#  u'reporter',
#  u'claquer',
#  u'disposer',
#  u'gonfler',
#  u'freiner',
#  u'repenser',
#  u'tisser',
#  u'simuler',
#  u'assembler',
#  u't\xe2cher',
#  u'fusionner',
#  u'redonner',
#  u'formuler',
#  u's\xe9cher',
#  u'succomber',
#  u'duper',
#  u'd\xe9border',
#  u'divulguer',
#  u'courtiser',
#  u'd\xe9river',
#  u'entamer',
#  u'd\xe9rouler',
#  u'd\xe9shonorer',
#  u'collecter',
#  u'g\xe2ter',
#  u'exhiber',
#  u'conter',
#  u'co\xfbter',
#  u'enrouler',
#  u'r\xe9f\xe9rer',
#  u't\xe9l\xe9charger',
#  u'guetter',
#  u'interviewer',
#  u'grignoter',
#  u'empresser',
#  u'trinquer',
#  u'ressusciter',
#  u'fouetter',
#  u'flirter',
#  u'flipper',
#  u'hanter',
#  u'flatter',
#  u'd\xe9courager',
#  u'implanter',
#  u'flanquer',
#  u'd\xe9guster',
#  u'dissuader',
#  u'fatiguer',
#  u'contrer',
#  u'renforcer',
#  u'improviser',
#  u'd\xe9montrer',
#  u'fouler',
#  u'd\xe9nicher',
#  u'contester',
#  u'inonder',
#  u'graver',
#  u'voguer',
#  u'plaquer',
#  u'patrouiller',
#  u'cambrioler',
#  u'patienter',
#  u'brouiller',
#  u'parer',
#  u'redemander',
#  u'raccompagner',
#  u'accumuler',
#  u'proc\xe9der',
#  u'\xe9plucher',
#  u'so\xfbler',
#  u'opter',
#  u'prolonger',
#  u'bousculer',
#  u'bourrer',
#  u'boucher',
#  u'mouiller',
#  u'succ\xe9der',
#  u'prosterner',
#  u'baptiser',
#  u'puiser',
#  u'pr\xeacher',
#  u'm\xe2cher',
#  u'rallumer',
#  u'neutraliser',
#  u'appr\xe9hender',
#  u'ramer',
#  u'amputer',
#  u'absenter',
#  u'relaxer',
#  u'ab\xeemer',
#  u'\xe9quiper',
#  u'piger',
#  u'ratisser',
#  u'alimenter',
#  u'aligner',
#  u'd\xe9monter',
#  u'propager',
#  u'\xe9pauler',
#  u'd\xe9capiter',
#  u'sillonner',
#  u'd\xe9dommager',
#  u'dealer',
#  u'objecter',
#  u'\xe9tirer',
#  u'd\xe9chiffrer',
#  u'plaisanter',
#  u'd\xe9cliner',
#  u'agresser',
#  u'agacer',
#  u'sous-estimer',
#  u'basculer',
#  u'd\xe9composer',
#  u'renouveler',
#  u'devancer',
#  u'gaver',
#  u'figurer',
#  u'postuler',
#  u'r\xe9chapper',
#  u'recracher',
#  u'r\xe9viser',
#  u'assimiler',
#  u'fracasser',
#  u'patiner',
#  u'doucher',
#  u'recr\xe9er',
#  u'couver',
#  u'percuter',
#  u'replonger',
#  u'd\xe9baller',
#  u'parader',
#  u'orienter',
#  u'fusiller',
#  u'auditionner',
#  u'fonctionner',
#  u'd\xe9bloquer',
#  u'arpenter',
#  u'd\xe9gonfler',
#  u'assigner',
#  u'cerner',
#  u'pulv\xe9riser',
#  u'conspirer',
#  u'branler',
#  u'acquitter',
#  u'\xe9laborer',
#  u'ins\xe9rer',
#  u'connecter',
#  u'accommoder',
#  u'briller',
#  u'\xe9duquer',
#  u'd\xe9verser',
#  u'\xe9galer',
#  u'maquiller',
#  u'regrouper',
#  u'baver',
#  u'\xe9gorger',
#  u'rayer',
#  u'rafler',
#  u'maltraiter',
#  u'merder',
#  u'capituler',
#  u'intenter',
#  u'tourmenter',
#  u'engraisser',
#  u'saccager',
#  u'stimuler',
#  u'cibler',
#  u'blaguer',
#  u'exciter',
#  u'transpercer',
#  u'exceller',
#  u'savourer',
#  u'\xe9couler',
#  u'embrouiller',
#  u'choquer',
#  u'border',
#  u'kidnapper',
#  u'comploter',
#  u'empocher',
#  u'tracasser',
#  u'hisser',
#  u'r\xe9pliquer',
#  u'd\xe9pouiller',
#  u'd\xe9go\xfbter',
#  u'fesser',
#  u's\xe9curiser',
#  u'stocker',
#  u's\xe9lectionner',
#  u'sonder',
#  u'filtrer',
#  u'flairer',
#  u'emprisonner',
#  u'flancher',
#  u'faucher',
#  u'verrouiller',
#  u'pr\xe9sumer',
#  u'administrer',
#  u'd\xe9sactiver',
#  u'prosp\xe9rer',
#  u'exag\xe9rer',
#  u'd\xe9sarmer',
#  u'd\xe9serter',
#  u'exterminer',
#  u'extirper',
#  u'esquiver',
#  u'acharner',
#  u's\xe9journer',
#  u'enr\xf4ler',
#  u'accoster',
#  u'acclamer',
#  u'ronger',
#  u'clamer',
#  u'solliciter',
#  u'boxer',
#  u'bousiller',
#  u'suffoquer',
#  u'convoiter',
#  u'scanner',
#  u'croquer',
#  u'mutiler',
#  u'courber',
#  u'couronner',
#  u'm\xe9nager',
#  u'niquer',
#  u'renifler',
#  u'illuminer',
#  u'rem\xe9morer',
#  u'r\xe9nover',
#  u'congeler',
#  u'r\xe9volter',
#  u'tricoter',
#  u'chatouiller',
#  u'collectionner',
#  u'r\xe9sumer',
#  u'relayer',
#  u'transpirer',
#  u'r\xe9signer',
#  u'relancer',
#  u'louper',
#  u'l\xe9guer',
#  u'inciter',
#  u'incarner',
#  u'brosser',
#  u'gronder',
#  u'\xe9corcher',
#  u't\xe2ter',
#  u'\xe9taler',
#  u'planer',
#  u'd\xe9coder',
#  u'd\xe9cha\xeener',
#  u'persister',
#  u'd\xe9brancher',
#  u'redouter',
#  u'dissiper',
#  u'atteler',
#  u'redoubler',
#  u'r\xe9essayer',
#  u'torcher',
#  u'c\xe2liner',
#  u'surnommer',
#  u'tripoter',
#  u'gueuler',
#  u'focaliser',
#  u'relater',
#  u'pister',
#  u'liguer',
#  u'pr\xe9c\xe9der',
#  u'flinguer',
#  u'engendrer',
#  u'raviser',
#  u'labourer',
#  u'jubiler',
#  u'irriter',
#  u'terrer',
#  u'endommager',
#  u'expirer',
#  u'hacher',
#  u'h\xe2ter',
#  u'fr\xf4ler',
#  u'recharger',
#  u'exaucer',
#  ...]

# %% [markdown]
# <a id="Groupe2"></a>
# #### Groupe 2
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
#     - [Groupe 1](#Groupe1)
#     - [Groupe 2](#Groupe2)
#     - [Groupe 3](#Groupe3)
#     - [Non-classés](#Restant)

# %%
cf[u"finir"]=u"abasourdir, abâtardir, abêtir, abolir, abonnir, aboutir, abrutir, accomplir, accourcir, accroupir, adoucir, affadir, affaiblir, affermir, affranchir, agir, agonir, agrandir, aguerrir, ahurir, aigrir, alanguir, alentir, allégir, alourdir, alunir, amaigrir, amatir, amerrir, ameublir, amincir, amoindrir, amollir, amortir, amuïr, anéantir, anoblir, anordir, aplanir, aplatir, appauvrir, appesantir, applaudir, appointir, approfondir, arrondir, assagir, assainir, asservir, assombrir, assortir, assoupir, assouplir, assourdir, assouvir, assujettir, attendrir, atterrir, attiédir, avachir, avertir, aveulir, avilir, bannir, barrir, bâtir, bénir, blanchir, blêmir, blettir, bleuir, blondir, blottir, bondir, bonir, bonnir, bouffir, brandir, bruir, brunir, calmir, candir, catir, chancir, chérir, choisir, clapir, compatir, cônir, convertir, cotir, crépir, crônir, crounir, croupir, débâtir, débleuir, décatir, décrépir, définir, défléchir, défleurir, défraîchir, dégarnir, dégauchir, déglutir, dégourdir, dégrossir, déguerpir, déjaunir, démaigrir, démolir, démunir, dépérir, dépolir, déraidir, dérondir, dérougir, désassortir, désemplir, désengourdir, désenlaidir, désépaissir, désétablir, désinvestir, désobéir, dessaisir, dessertir, désunir, déverdir, dévernir, divertir, doucir, durcir, ébahir, ébaubir, ébaudir, éblouir, écatir, échampir, éclaircir, écrouir, effleurir, élargir, élégir, embellir, emboutir, embrunir, emplir, empuantir, enchérir, endolorir, endurcir, enforcir, enfouir, engloutir, engourdir, enhardir, enlaidir, ennoblir, enorgueillir, enrichir, ensevelir, envahir, envieillir, épaissir, épanouir, époutir, équarrir, esbaudir, estourbir, établir, étourdir, étrécir, évanouir, faiblir, farcir, finir, fléchir, flétrir, fleurir, forcir, fouir, fourbir, fournir, fraîchir, franchir, frémir, froidir, garantir, garnir, gauchir, gémir, glapir, grandir, gravir, grossir, guérir, havir, hennir, honnir, hourdir, impartir, infléchir, interagir, intervertir, invertir, investir, jaillir, jaunir, jouir, languir, lotir, louchir, maigrir, matir, maudire, mégir, meurtrir, mincir, moisir, moitir, mollir, mugir, munir, mûrir, nantir, noircir, nordir, nourrir, obéir, obscurcir, ourdir, pâlir, pâtir, périr, pervertir, pétrir, polir, pourrir, préétablir, prémunir, punir, rabonnir, rabougrir, raccourcir, racornir, radoucir, rafantir, raffermir, rafraîchir, ragaillardir, raidir, rajeunir, ralentir, ramollir, rancir, raplatir, rapointir, rappointir, rassortir, ravilir, ravir, réagir, réassortir, rebâtir, reblanchir, rebondir, rechampir, réchampir, reconvertir, recrépir, redéfinir, redémolir, réfléchir, refleurir, refroidir, regarnir, régir, regrossir, réinvestir, rejaillir, réjouir, rélargir, rembrunir, remplir, renchérir, renformir, répartir, repolir, resalir, resplendir, ressaisir, ressortir, ressurgir, resurgir, rétablir, retentir, rétrécir, rétroagir, réunir, réussir, reverdir, revernir, roidir, rondir, rosir, rôtir, rougir, rouir, roussir, roustir, rugir, saillir, saisir, salir, saurir, serfouir, sertir, sévir, sous-investir, subir, subvertir, superfinir, surenchérir, surfleurir, surgir, surinvestir, surir, tapir, tarir, tartir, ternir, terrir, tiédir, trahir, transir, travestir, unir, vagir, verdir, vernir, vieillir, vioquir, vomir, vrombir".split(", ")+[u"désaisir",u"antiréagir",u"surréagir",u"ragrandir",u"prédéfinir",u"rassir",u"revomir",u"préremplir"]+[u"cramoisir",u"gaudir",u"florir",u"glatir",u"bruire"]
cf[u"haïr"]=[u"haïr"]

# %% [markdown]
# <a id="Groupe3"></a>
# #### Groupe 3
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
#     - [Groupe 1](#Groupe1)
#     - [Groupe 2](#Groupe2)
#     - [Groupe 3](#Groupe3)
#     - [Non-classés](#Restant)

# %%
cf[u"être"]=[u"être"]
cf[u"avoir"]=[u"avoir"]
cf[u"falloir"]=[u"falloir"]
cf[u"asseoir"]=[u"asseoir",u"rasseoir"]
cf[u"pouvoir"]=[u"pouvoir"]
cf[u"mourir"]=[u"mourir"]
cf[u"savoir"]=[u"savoir"]
cf[u"vouloir"]=[u"vouloir"]+[u"revouloir"]
cf[u"seoir"]=[u"seoir"]+[u"messeoir"]
cf[u"surseoir"]=[u"surseoir"]
cf[u"occire"]=[u"occire"]
cf[u"ouïr"]=[u"ouïr"]
cf[u"férir"]=[u"férir"]
cf[u"gésir"]=[u"gésir"]
cf[u"chaloir"]=[u"chaloir"]
cf[u"ardre"]=[u"ardre"]
cf[u"sourdre"]=[u"sourdre"]
cf[u"comparoir"]=[u"comparoir"]
cf[u"chauvir"]=[u"chauvir"]
# cf[u""]=[u""]
cf[u"rendre"]=u"appendre, attendre, condescendre, confondre, contrefoutre, correspondre, corrompre, descendre, distendre, distordre, démordre, dépendre, détendre, détordre, entendre, fendre, fondre, foutre, interrompre, mordre, morfondre, mévendre, parfondre, pendre, perdre, pondre, pourfendre, prétendre, redescendre, refendre, refondre, remordre, rendre, rependre, reperdre, retendre, retondre, retordre, revendre, rompre, répandre, répondre, sous-entendre, sous-tendre, suspendre, tendre, tondre, tordre, vendre, épandre, étendre".split(", ")+[u"défendre",u"refoutre",u"réentendre",u"survendre",u"éperdre"]
cf[u"battre"]=u"abattre, battre, combattre, contrebattre, débattre, embattre, rabattre, rebattre, ébattre".split(", ")
cf[u"mettre"]=u"admettre, commettre, compromettre, démettre, émettre, entremettre, mettre, omettre, permettre, promettre, réadmettre, remettre, retransmettre, soumettre, transmettre".split(", ")+[u"réémettre"]
cf[u"peindre"]=u"dépeindre, peindre, repeindre, treindre, astreindre, étreindre, restreindre, atteindre, ceindre, ceindre, enceindre, empreindre, enfreindre, feindre, geindre, teindre, déteindre, éteindre, reteindre".split(", ")+[u"retreindre",u"rétreindre"]
cf[u"joindre"]=u"adjoindre, conjoindre, disjoindre, enjoindre, joindre, rejoindre, oindre, poindre".split(", ")
cf[u"traire"]=u"abstraire, distraire, extraire, retraire, soustraire, traire, braire".split(", ")+[u"rentraire"]
cf[u"plaire"]=u"plaire, complaire, déplaire, taire".split(", ")
cf[u"craindre"]=u"craindre, contraindre, plaindre".split(", ")
cf[u"vaincre"]=u"convaincre, vaincre".split(", ")
cf[u"croître"]=u"accroître, croître, décroître, recroître".split(", ")
cf[u"croire"]=u"accroire, croire".split(", ")+[u"mécroire"]
cf[u"boire"]=u"boire, emboire".split(", ")+[u"reboire"]
cf[u"clore"]=u"clore, déclore, éclore, enclore, forclore".split(", ")
cf[u"conclure"]=u"conclure, exclure".split(", ")
cf[u"inclure"]=u"inclure, occlure, reclure".split(", ")
cf[u"écrire"]=u"circonscrire, décrire, écrire, inscrire, prescrire, proscrire, récrire, réinscrire, retranscrire, souscrire, transcrire".split(", ")+[u"réécrire"]
cf[u"cuire"]=u"cuire, recuire, conduire, déduire, éconduire, enduire, induire, introduire, produire, reconduire, réduire, réintroduire, reproduire, retraduire, séduire, traduire, construire, détruire, instruire, reconstruire, luire, reluire, entre-nuire, nuire".split(", ")+[u"autodétruire",u"entre-détruire",u"surproduire",u"coproduire",u"déconstruire",u"décuire",u"méconduire"]
cf[u"connaître"]=u"connaître, connaître, méconnaître, reconnaître, paraître, apparaître, comparaître, disparaître, paraître, réapparaître, recomparaître, reparaître, transparaître".split(", ")
cf[u"prendre"]=u"apprendre, comprendre, déprendre, désapprendre, entreprendre, éprendre, méprendre, prendre, réapprendre, reprendre, surprendre".split(", ")+[u"rapprendre"]
cf[u"tenir"]=u"abstenir, appartenir, contenir, détenir, entretenir, maintenir, obtenir, retenir, soutenir, tenir, advenir, circonvenir, contrevenir, convenir, devenir, disconvenir, intervenir, obvenir, parvenir, prévenir, provenir, redevenir, ressouvenir, revenir, souvenir, subvenir, survenir, venir".split(", ")+[u"avenir"]
cf[u"sentir"]=u"consentir, démentir, départir, mentir, partir, pressentir, repartir, repentir, ressentir, ressortir, sentir, sortir".split(", ")
cf[u"acquérir"]=u"acquérir, conquérir, enquérir, quérir, reconquérir, requérir".split(", ")+[u"réacquérir"]
cf[u"vêtir"]=u"vêtir, revêtir, dévêtir".split(", ")
cf[u"couvrir"]=u"couvrir, découvrir, entrouvrir, offrir, ouvrir, recouvrir, rentrouvrir, rouvrir, souffrir".split(", ")+[u"redécouvrir",u"réouvrir"]
cf[u"cueillir"]=u"accueillir, cueillir, recueillir".split(", ")
cf[u"assaillir"]=u"assaillir, saillir, tressaillir".split(", ")
cf[u"faillir"]=u"défaillir, faillir".split(", ")
cf[u"bouillir"]=u"bouillir, débouillir".split(", ")
cf[u"dormir"]=u"dormir, endormir, rendormir".split(", ")+[u"redormir"]
cf[u"courir"]=u"accourir, concourir, courir, discourir, encourir, parcourir, recourir, secourir".split(", ")+[u"reparcourir"]
cf[u"servir"]=u"desservir, resservir, servir".split(", ")
cf[u"fuir"]=u"enfuir, fuir".split(", ")
cf[u"recevoir"]=u"apercevoir, concevoir, décevoir, percevoir, recevoir".split(", ")+[u"entrapercevoir",u"préconcevoir"]
cf[u"voir"]=u"entrevoir, prévoir, revoir, voir".split(", ")
cf[u"pourvoir"]=u"dépourvoir, pourvoir".split(", ")
cf[u"devoir"]=u"devoir, redevoir".split(", ")
cf[u"mouvoir"]=u"mouvoir, promouvoir, émouvoir".split(", ")
cf[u"pleuvoir"]=u"pleuvoir, repleuvoir".split(", ")
cf[u"valoir"]=u"prévaloir, revaloir, valoir, équivaloir".split(", ")
cf[u"choir"]=u"choir, déchoir, échoir".split(", ")
cf[u"faire"]=u"contrefaire, défaire, faire, forfaire, malfaire, méfaire, parfaire, redéfaire, refaire, satisfaire, surfaire".split(", ")+[u"stupéfaire"]
cf[u"naître"]=u"naître, renaître".split(", ")
cf[u"paître"]=u"paître, repaître".split(", ")
cf[u"absoudre"]=u"absoudre, dissoudre, résoudre".split(", ")
cf[u"coudre"]=u"coudre, découdre, recoudre".split(", ")
cf[u"moudre"]=u"moudre, remoudre, émoudre".split(", ")
cf[u"suivre"]=u"ensuivre, poursuivre, suivre".split(", ")
cf[u"vivre"]=u"revivre, survivre, vivre".split(", ")
cf[u"lire"]=u"lire, relire, réélire, élire".split(", ")
cf[u"dire"]=u"contredire, dire, dédire, interdire, médire, prédire, redire".split(", ")
cf[u"rire"]=u"rire, sourire".split(", ")
cf[u"confire"]=u"circoncire, confire, déconfire, frire, suffire".split(", ")

# cf[u""]=u"".split(", ")

# %% [markdown]
# <a id="CF-ListeVerbes"></a>
# ### Liste des verbes par CF
# - liste prête à copier en LaTeX

# %%
descriptions={}
populations={}
for c in cf:
    populations[c]=len(cf[c])
#     print c, len(cf[c])
#     print ur"-----"
#     print ", ".join(cf[c])
#     print ur"====="
#     print
    descriptions[c]=[]
    descriptions[c].append(ur"\item "+c+" (%d)"%len(cf[c]))
    descriptions[c].append(ur"\begin{itemize}")
    descriptions[c].append(ur"\item "+", ".join(cf[c]))
    descriptions[c].append(ur"\end{itemize}")
lines=[]
for c in sorted(populations, key=lambda x:(populations[x]),reverse=True):
    lines.extend(descriptions[c])
pyperclip.copy("\n".join(lines))
# sortedCF

# %% [markdown]
# <a id="CF-StumpFinkel"></a>
# # Stump & Finkel 2013 Classes
#
# - trier les classes pour avoir les mêmes dans le même ordre que Stump & Finkel
#
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
# - [CF Stump & Finkel](#CF-StumpFinkel)
# - [Heatmap CF](#CF-Heatmap)
# - [Tri CF Fin](#TriCF)

# %%
#p236
ordreSF=u"couvrir mourir valoir être acquérir dormir vaincre vivre".split(" ")
ordreSF+=u"vouloir lire faire moudre rendre asseoir mettre croître".split(" ")
ordreSF+=u"plaire joindre peindre tenir prendre recevoir boire".split(" ")
ordreSF+=u"savoir avoir bouillir aller envoyer appuyer".split(" ")
#p237
ordreSF+=u"coudre écrire courir mouvoir pouvoir haïr naître".split(" ")
ordreSF+=u"connaître finir asseoir battre sentir servir suivre".split(" ")
ordreSF+=u"dire pourvoir inclure assaillir voir vêtir aimer".split(" ")
ordreSF+=u"cuire écrouer fuir rire conclure cueillir confire".split(" ")
len(ordreSF)
print " ".join(ordreSF)
# Out:
# couvrir mourir valoir être acquérir dormir vaincre vivre vouloir lire faire moudre rendre asseoir mettre croître plaire joindre peindre tenir prendre recevoir boire savoir avoir bouillir aller envoyer appuyer coudre écrire courir mouvoir pouvoir haïr naître connaître finir asseoir battre sentir servir suivre dire pourvoir inclure assaillir voir vêtir aimer cuire écrouer fuir rire conclure cueillir confire

# %%
cf[u"connaître"]+=cf[u"paître"]
del cf[u"paître"]
cf[u"peindre"]+=cf[u"craindre"]
del cf[u"craindre"]
cf[u"pourvoir"]+=cf[u"croire"]
del cf[u"croire"]
cf[u"recevoir"]+=cf[u"devoir"]
del cf[u"devoir"]
sortedCF=[c for c in sorted(populations, key=lambda x:(populations[x]),reverse=True) if c in cf]

# %%
print "missing SF"
for c in ordreSF:
    if not c in cf:
        print c
print "over CF"
for c in cf:
    if not c in ordreSF:
        print c
# Out:
# missing SF
# over CF
# chaloir
# pleuvoir
# seoir
# ouïr
# clore
# surseoir
# férir
# traire
# ardre
# absoudre
# gésir
# faillir
# occire
# choir
# sourdre
# falloir
# comparoir
# chauvir

# %% [raw]
# lVerbes=pyperclip.paste()
# lVerbes=re.sub(ur";|\n|\(\w\)|–|:", " ",lVerbes).strip()
# result='cf[u""]=u"'+", ".join(sorted(set(re.split("\s+",lVerbes))))+'".split(", ")\n'
# print result
# pyperclip.copy(result)

# %%
cf["faire"]
# Out:
# [u'contrefaire',
#  u'd\xe9faire',
#  u'faire',
#  u'forfaire',
#  u'malfaire',
#  u'm\xe9faire',
#  u'parfaire',
#  u'red\xe9faire',
#  u'refaire',
#  u'satisfaire',
#  u'surfaire',
#  u'stup\xe9faire']

# %% [markdown]
# ### CF entièrement sans accord du participe passé
# - être
# - pouvoir
# - rire
# - faillir
# - falloir

# %%
noPP=u"être pouvoir rire faillir falloir".split(" ")

# %% [markdown]
# <a id="Restant"></a>
# ### Lemmes restants dans Lexique4 sans CF
# adire, appert, assis, connu, courre, disparu, divorcé, dopa, es, florissait, forfais, intima, parait, parfait, pris, raire, ravoir, reconnu, remis, rétaire, serons, sous-alimenté, antivêtir, tara
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
#     - [Groupe 1](#Groupe1)
#     - [Groupe 2](#Groupe2)
#     - [Groupe 3](#Groupe3)
#     - [Non-classés](#Restant)

# %%
groupeVerbes=[v for c in cf for v in cf[c]]
print ", ".join([e for e in dfV[~dfV.lexeme.isin(groupeVerbes)].lexeme.unique().tolist() if isinstance(e,unicode)])
# Out:
# adire, appert, assis, connu, courre, disparu, divorcé, dopa, es, florissait, forfais, intima, parait, parfait, pris, raire, ravoir, reconnu, remis, rétaire, serons, sous-alimenté, antivêtir, tara

# %%
def trierVerbes(cfVerbe):
    verbes=cf[cfVerbe]
    result=dfV[dfV.lexeme.isin(verbes)].groupby("lexeme")["occurrences"].sum().sort_values(ascending=False).index.tolist()
    return result

if triCF:   #choix entre l'ordre StumpFinkel et l'ordre par défaut
    ordreCF=ordreSF
else:
    ordreCF=sortedCF
    
for cfVerbe in ordreCF:
    cf[cfVerbe]=trierVerbes(cfVerbe)

# %%
def getLexemeSet(lexeme):
    return set((dfV[dfV.lexeme.str.encode("utf8")==lexeme.encode("utf8")]).case.unique())

cfSet={}
cfSauts={}
cfDef={}

if triCF:   #choix entre l'ordre StumpFinkel et l'ordre par défaut
    ordreCF=ordreSF
else:
    ordreCF=sortedCF

for cfVerbe in ordreCF:
    exemplaireSet=set()
    exemplaires=cf[cfVerbe]
    iExSauts=[]
    for nL,l in enumerate(exemplaires):
        lCases=getLexemeSet(l)
        exemplaireSetTemp=exemplaireSet.union(lCases)
        if len(exemplaireSetTemp)>len(exemplaireSet):
            iExSauts.append(nL)
            print ",".join(sorted(list(exemplaireCases-exemplaireSetTemp))),nL,"\t%s"%l, len(lCases)
        exemplaireSet=exemplaireSetTemp
        if len(exemplaireSet)==nbCases:
            break
    cfSet[cfVerbe]=",".join(sorted(list(exemplaireCases-exemplaireSet)))
    cfSauts[cfVerbe]=iExSauts
    if cfVerbe in noPP:
        cfDef[cfVerbe]=len(exemplaireCases-exemplaireSet)-3 # les formes accordées du participe passé n'existent pas
    else:
        cfDef[cfVerbe]=len(exemplaireCases-exemplaireSet)
    sExSauts="nExemplaires=["+",".join([str(i) for i in iExSauts])+"]\n#%s : "%cfVerbe+", ".join([exemplaires[i] for i in iExSauts])
    print sExSauts
    print
# Out:
# is1P,is1S,is2P,is2S,is3P,is3S 0 	penser 45
# is1P,is1S,is2P,is2S,is3P 1 	parler 45
# is1P,is2P,is2S,is3P 2 	aimer 45
# is1P,is2S,is3P 8 	donner 46
# is1P,is2S 26 	garder 43
# is1P 79 	lâcher 40
#  186 	accuser 42
# nExemplaires=[0,1,2,8,26,79,186]
# #aimer : penser, parler, aimer, donner, garder, lâcher, accuser
#
# is1P,is1S,is2P,is2S,pc3P,ps1P 0 	tuer 45
# is1P,is1S,is2P,is2S 1 	jouer 44
# is1P,is2P 16 	lier 37
# is1P 116 	délier 28
# nExemplaires=[0,1,16,116]
# #écrouer : tuer, jouer, lier, délier
#
# ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps3P 0 	finir 41
# ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,ps3P 1 	agir 41
# ai1S,ai2S,is1P,is1S,is2P,is2S,ps3P 3 	réussir 41
# ai1S,is1P,is1S,is2P,is2S,ps3P 20 	avertir 39
# is1P,is1S,is2P,is2S,ps3P 31 	ressortir 40
# is1P,is2P,is2S,ps3P 40 	bâtir 39
# is1P,is2P,is2S 42 	définir 37
# nExemplaires=[0,1,3,20,31,40,42]
# #finir : finir, agir, réussir, avertir, ressortir, bâtir, définir
#
# ai2P,ai2S,is1P,is1S,is2P,is2S,is3P 0 	attendre 44
# is1P,is1S,is2P,is2S 1 	entendre 47
# is1P,is1S,is2P 5 	répondre 45
# is1P,is2P 23 	confondre 37
# nExemplaires=[0,1,5,23]
# #rendre : attendre, entendre, répondre, confondre
#
# ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,ps1P,ps1S,ps2P,ps3P 0 	nettoyer 38
# ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,ps1P,ps2P,ps3P 1 	ennuyer 38
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P 3 	noyer 39
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P 4 	employer 38
# ai2P,is1P,is1S,is2P,is2S,is3P,ps1P,ps3P 6 	déployer 34
# nExemplaires=[0,1,3,4,6]
# #appuyer : nettoyer, ennuyer, noyer, employer, déployer
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps2P 0 	conduire 41
# ai2P,is1P,is1S,is2P,is2S,is3P,ps1P 1 	détruire 43
# nExemplaires=[0,1]
# #cuire : conduire, détruire
#
# ai1P,ai2P,is2S,ps1P 0 	venir 47
# ai1P,ai2P,ps1P 1 	revenir 44
# ai1P,ai2P 2 	tenir 44
#  3 	devenir 47
# nExemplaires=[0,1,2,3]
# #tenir : venir, revenir, tenir, devenir
#
# ai1P,ai2P,ai2S,is1P,is2P,is2S,is3P,is3S,pc1P,ps1P,ps2P 0 	craindre 40
# ai2P,ai2S,is1P,is2P,is2S,is3P,is3S,ps1P,ps2P 1 	atteindre 40
# ai2P,ai2S,is1P,is2P,is2S,is3S,ps1P,ps2P 2 	éteindre 40
# ai2P,ai2S,is1P,is2P,is2S,is3S,ps1P 4 	peindre 33
# nExemplaires=[0,1,2,4]
# #peindre : craindre, atteindre, éteindre, peindre
#
# is2P,ps1P 0 	mettre 49
# ps1P 1 	promettre 42
# nExemplaires=[0,1]
# #mettre : mettre, promettre
#
# ai2P,is1P,is2S,ps1P 0 	connaître 47
# nExemplaires=[0]
# #connaître : connaître
#
# ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P 0 	écrire 41
# nExemplaires=[0]
# #écrire : écrire
#
# is1P,is1S,is2P,is2S,is3P,ps3P 0 	partir 45
# is1P,is1S,is2P,is2S 2 	sentir 43
# is2P 8 	repentir 42
# nExemplaires=[0,2,8]
# #sentir : partir, sentir, repentir
#
# is2S 0 	faire 50
# nExemplaires=[0]
# #faire : faire
#
# is1P,is2S,is3P 0 	prendre 48
# nExemplaires=[0]
# #prendre : prendre
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1S 0 	ouvrir 42
# ai2P,is1P,is1S,is2P,is2S,is3P,ps1S 1 	découvrir 42
# ai2P,is1P,is1S,is2P,is2S 2 	offrir 43
# nExemplaires=[0,1,2]
# #couvrir : ouvrir, découvrir, offrir
#
# ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P 0 	courir 42
# ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps3P 2 	secourir 33
# nExemplaires=[0,2]
# #courir : courir, secourir
#
# ai2P,ai2S,is1P,is2P,is2S,is3P,is3S,ps1P,ps2P 0 	battre 42
# ai2P,is1P,is2P,is2S,is3P,ps2P 1 	combattre 42
# nExemplaires=[0,1]
# #battre : battre, combattre
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc3P,ps1P,ps2P 0 	distraire 35
# nExemplaires=[0]
# #traire : distraire
#
# ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P 0 	rejoindre 43
# nExemplaires=[0]
# #joindre : rejoindre
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2P,pc2S,pc3P,ps1P,ps2P,ps3P 0 	conquérir 35
# ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2P,pc2S,ps1P,ps2P,ps3P 1 	requérir 31
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2S,ps1P,ps2P,ps3P 4 	enquérir 17
# nExemplaires=[0,1,4]
# #acquérir : conquérir, requérir, enquérir
#
# ai1P,is1P,is2P,ps1P 0 	dire 47
# nExemplaires=[0]
# #dire : dire
#
# ai2P 0 	devoir 50
# nExemplaires=[0]
# #recevoir : devoir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi2P,pi2S,ps1P,ps2P,ps3P 0 	clore 16
# nExemplaires=[0]
# #clore : clore
#
# ai1P,ai1S,ai2P,ai2S,is1P,is2P,is2S,pc1P,pc2S,ppFP,ppFS,ps1P,ps2P,ps2S,ps3P 0 	suffire 36
# ai1P,ai1S,ai2P,ai2S,is1P,is2P,is2S,pc1P,ppFP,ppFS,ps1P,ps2P,ps2S,ps3P 1 	frire 13
# ai1P,ai1S,ai2P,ai2S,is1P,is2P,is2S,pc1P,ps1P,ps2P,ps2S,ps3P 2 	circoncire 14
# nExemplaires=[0,1,2]
# #confire : suffire, frire, circoncire
#
# ai1P,ai1S,ai2P,ai2S,fi1P,fi1S,fi2P,fi2S,ii1S,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi2P,pi2S,ppFP,ppFS,ppMP,ps1P,ps2P,ps2S,ps3P 0 	croître 19
# ai1P,ai1S,ai2P,ai2S,fi1P,fi1S,fi2S,ii1S,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,pc1P,pc1S,pc2S,pc3P,pi2P,ps1P,ps2P,ps2S,ps3P 1 	accroître 24
# nExemplaires=[0,1]
# #croître : croître, accroître
#
# ai2P,is1P,is2P,is2S,is3P,pc1P,ppFP,ppFS,ppMS,ps1P,ps2P 0 	plaire 40
# ai2P,is1P,is2P,is2S,is3P,pc1P,ppFP,ppFS,ps1P,ps2P 1 	taire 38
# nExemplaires=[0,1]
# #plaire : plaire, taire
#
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P 0 	lire 42
# nExemplaires=[0]
# #lire : lire
#
# is1P,is1S,is2P,is2S,is3P,is3S,ppFP,ppFS,ppMP,ps1P,ps3P 0 	dormir 40
# is1P,is1S,is2S,is3P,is3S,ppFP,ppFS,ps1P,ps3P 1 	endormir 39
# nExemplaires=[0,1]
# #dormir : dormir, endormir
#
# ai1P,ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps2P 0 	valoir 40
# nExemplaires=[0]
# #valoir : valoir
#
# is1P,is1S,is3P,ps1P 0 	voir 47
# nExemplaires=[0]
# #voir : voir
#
# ai2P,is1P,is2P,is3P,ppFP,ppFS,ps1P,ps2P 0 	boire 43
# nExemplaires=[0]
# #boire : boire
#
# ai1P,ai1S,ai2P,ai2S,ai3P,fi1S,ii1P,ii3P,is1P,is1S,is2P,is3S,pI1P,pc1P,pc2P,pc2S,pc3P,pi1P,pi2S,ps1P,ps2P,ps2S,ps3P 0 	vêtir 28
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is3S,pc1P,pc2P,pc2S,pc3P,pi1P,ps1P,ps2P,ps3P 1 	revêtir 29
# ai2P,ai2S,is1P,is2P,is3S,pc1P,pc2P,pc2S,pc3P,pi1P,ps1P,ps2P,ps3P 2 	dévêtir 19
# nExemplaires=[0,1,2]
# #vêtir : vêtir, revêtir, dévêtir
#
# ai1P,ai2P,ai2S,ai3P,ii1P,is1P,is1S,is2P,is2S,is3P,is3S,pc2P,pc3P,ps1P,ps2P,ps3P 0 	coudre 35
# ai1P,ai2P,ai2S,ai3P,ii1P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P 1 	recoudre 34
# nExemplaires=[0,1]
# #coudre : coudre, recoudre
#
# ai1P,ai2P,ai2S,fi2P,fi3P,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pc1P,pc1S,pc2P,pc2S,pc3P,ps1P,ps1S,ps2P,ps3P 0 	promouvoir 30
# ai1P,ai2P,fi2P,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pc1P,pc1S,pc2P,pc2S,pc3P,ps1P,ps1S,ps2P,ps3P 1 	émouvoir 22
# nExemplaires=[0,1]
# #mouvoir : promouvoir, émouvoir
#
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,pI2S,ps1P 0 	vivre 42
# ai2P,is1P,is1S,is2P,is2S,is3P,ps1P 1 	survivre 38
# nExemplaires=[0,1]
# #vivre : vivre, survivre
#
# ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,ps1P 0 	servir 43
# nExemplaires=[0]
# #servir : servir
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	accueillir 36
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps1S,ps2P,ps3P,ps3S 2 	cueillir 35
# nExemplaires=[0,2]
# #cueillir : accueillir, cueillir
#
# ai1P,ai1S,ai2P,fi2P,ii1P,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2S,ppFP,ppFS,ps1P,ps2P,ps3P 0 	inclure 33
# nExemplaires=[0]
# #inclure : inclure
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi3P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	moudre 13
# nExemplaires=[0]
# #moudre : moudre
#
# ai1P,ai2P,ai2S,fi1P,fi2P,fi2S,fi3S,ii1P,ii1S,ii2P,is1P,is1S,is2P,is2S,is3S,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	assaillir 24
# ai1P,ai2P,fi1P,fi2P,fi2S,fi3S,ii1P,ii2P,is1P,is1S,is2P,is2S,is3S,pc1P,pc2P,pc3P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 1 	tressaillir 20
# nExemplaires=[0,1]
# #assaillir : assaillir, tressaillir
#
# ai1P,ai2P,ai2S,ai3P,fi1P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi3P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	choir 14
# ai1P,ai2P,ai2S,ai3P,fi1P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi2P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 1 	déchoir 8
# nExemplaires=[0,1]
# #choir : choir, déchoir
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ppFP,ppFS,ps1P,ps2P,ps3P 0 	résoudre 37
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P 2 	absoudre 23
# nExemplaires=[0,2]
# #absoudre : résoudre, absoudre
#
# ai2P,is1P,is1S,is2P,is2S,is3P,is3S,pi2S,ps1P 0 	suivre 42
# is1P,is1S,is2P,is2S,is3P,ps1P 1 	poursuivre 45
# nExemplaires=[0,1]
# #suivre : suivre, poursuivre
# ai2P,is1P,is2P,is3S,ps1P,ps2P,ps3P 0 	asseoir 44
# nExemplaires=[0]
# #asseoir : asseoir
#
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,pc1P,ps1P,ps3P 0 	convaincre 40
# ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps3P 1 	vaincre 32
# nExemplaires=[0,1]
# #vaincre : convaincre, vaincre
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi1S,pi2P,pi2S,ppFP,ppFS,ppMP,ps1P,ps1S,ps2P,ps2S,ps3P 0 	pleuvoir 11
# nExemplaires=[0]
# #pleuvoir : pleuvoir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,ii1P,ii1S,ii2P,ii2S,ii3P,inf,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pi1P,pi1S,pi2P,pi2S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	seoir 6
# nExemplaires=[0]
# #seoir : seoir
#
# is1P,is2P,is2S,is3P,is3S 0 	envoyer 46
# nExemplaires=[0]
# #envoyer : envoyer
#
# ai1S,ai2S,is1P,is2P,is2S,is3S,ppFP,ppFS,ppMP,ps1P,ps3P 0 	rire 40
# ai1S,is1P,is2P,ppFP,ppFS,ppMP,ps1P,ps3P 1 	sourire 39
# nExemplaires=[0,1]
# #rire : rire, sourire
#
# ai1S,ai2P,ai2S,ai3P,fi1S,fi2P,fi2S,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3S,pI2P,pc2P,pc3P,pc3S,pi1P,pi2P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	bouillir 24
# ai1S,ai2P,ai2S,ai3P,fi1S,fi2P,fi2S,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3S,pI2P,pc2P,pc3P,pc3S,pi1P,pi2P,ps1P,ps2P,ps2S,ps3P 1 	débouillir 3
# nExemplaires=[0,1]
# #bouillir : bouillir, débouillir
#
# ai2P,is1P,is2P,is2S,is3P 0 	croire 46
# nExemplaires=[0]
# #pourvoir : croire
#
# ai1P,ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P 0 	conclure 38
# nExemplaires=[0]
# #conclure : conclure
#
# ai2P,is1P,is1S,is2P,is2S,pc1P,pc2P,ps1P,ps2P,ps3P 0 	naître 41
# ai2P,is1P,is1S,is2P,is2S,pc1P,ps1P,ps2P,ps3P 1 	renaître 35
# nExemplaires=[0,1]
# #naître : naître, renaître
#
# ai2P,is1P,is2P,is3P,ps1P 0 	vouloir 46
# nExemplaires=[0]
# #vouloir : vouloir
#
# ai2P,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc2P,pc3P,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	faillir 17
# ai2P,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3S,pI1P,pI2P,pI2S,pc1P,pc2P,pi1S,pi2S,pi3S,ppFP,ppFS,ppMP,ps1P,ps2P,ps3P 1 	défaillir 19
# nExemplaires=[0,1]
# #faillir : faillir, défaillir
#
# ai1S,ai2P,ai2S,is1P,is2P,pc1P,ps1P,ps2P,ps3P 0 	enfuir 42
# ai1S,ai2P,ai2S,is1P,is2P,pc1P,ps1P,ps3P 1 	fuir 41
# nExemplaires=[0,1]
# #fuir : enfuir, fuir
#
# is1P,is3P,ps1P,ps2P 0 	aller 47
# nExemplaires=[0]
# #aller : aller
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	occire 1
# nExemplaires=[0]
# #occire : occire
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	chaloir 1
# nExemplaires=[0]
# #chaloir : chaloir
#
# ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,ps1P,ps2P,ps3P 0 	haïr 41
# nExemplaires=[0]
# #haïr : haïr
#
# ai1P,ai1S,ai2P,ai2S,ai3P,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi2S,pi3P,ppFP,ppFS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	surseoir 7
# nExemplaires=[0]
# #surseoir : surseoir
#
# ai1P,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi3P,fi3S,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,is3S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,ps1P,ps2P,ps3P 0 	ouïr 21
# nExemplaires=[0]
# #ouïr : ouïr
#
# pI2S,ppFP,ppFS,ppMP 0 	pouvoir 47
# nExemplaires=[0]
# #pouvoir : pouvoir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,fi1P,fi1S,fi2P,fi2S,fi3P,ii1P,ii1S,ii2P,ii2S,ii3P,is1P,is1S,is2P,is2S,is3P,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi1S,pi2P,pi2S,pi3P,ppFP,ppFS,ppMP,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	falloir 8
# nExemplaires=[0]
# #falloir : falloir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	ardre 1
# nExemplaires=[0]
# #ardre : ardre
#
# is1P,is1S,is2P,is2S,is3P,ps1P,ps2P 0 	mourir 44
# nExemplaires=[0]
# #mourir : mourir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	férir 1
# nExemplaires=[0]
# #férir : férir
#
#  0 	avoir 51
# nExemplaires=[0]
# #avoir : avoir
#
# ai2P,is3P 0 	savoir 49
# nExemplaires=[0]
# #savoir : savoir
#
# ppFP,ppFS,ppMP 0 	être 48
# nExemplaires=[0]
# #être : être
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	gésir 14
# nExemplaires=[0]
# #gésir : gésir
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi2S,pi3P,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps3P 0 	sourdre 6
# nExemplaires=[0]
# #sourdre : sourdre
#
# ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S 0 	comparoir 1
# nExemplaires=[0]
# #comparoir : comparoir
#
# nExemplaires=[]
# #chauvir :

# %%
c=u"traire"
print ", ".join([cf[c][i] for i in cfSauts[c]])
# Out:
# distraire

# %%
cfSet[c]
# Out:
# u'ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc3P,ps1P,ps2P'

# %%
for c in sorted(cfDef, key=lambda x: cfDef[x]):
    print c,len([x for x in cfSet[c].split(",") if x!=""]),cfSet[c]
print
print cfSauts
# Out:
# aimer 0
# tenir 0
# avoir 0
# être 3 ppFP,ppFS,ppMP
# écrouer 1 is1P
# pouvoir 4 pI2S,ppFP,ppFS,ppMP
# mettre 1 ps1P
# sentir 1 is2P
# faire 1 is2S
# recevoir 1 ai2P
# rendre 2 is1P,is2P
# savoir 2 ai2P,is3P
# finir 3 is1P,is2P,is2S
# prendre 3 is1P,is2S,is3P
# connaître 4 ai2P,is1P,is2S,ps1P
# dire 4 ai1P,is1P,is2P,ps1P
# voir 4 is1P,is1S,is3P,ps1P
# aller 4 is1P,is3P,ps1P,ps2P
# envoyer 5 is1P,is2P,is2S,is3P,is3S
# rire 8 ai1S,is1P,is2P,ppFP,ppFS,ppMP,ps1P,ps3P
# pourvoir 5 ai2P,is1P,is2P,is2S,is3P
# vouloir 5 ai2P,is1P,is2P,is3P,ps1P
# couvrir 5 ai2P,is1P,is1S,is2P,is2S
# suivre 6 is1P,is1S,is2P,is2S,is3P,ps1P
# battre 6 ai2P,is1P,is2P,is2S,is3P,ps2P
# asseoir 7 ai2P,is1P,is2P,is3S,ps1P,ps2P,ps3P
# cuire 7 ai2P,is1P,is1S,is2P,is2S,is3P,ps1P
# mourir 7 is1P,is1S,is2P,is2S,is3P,ps1P,ps2P
# peindre 7 ai2P,ai2S,is1P,is2P,is2S,is3S,ps1P
# vivre 7 ai2P,is1P,is1S,is2P,is2S,is3P,ps1P
# appuyer 8 ai2P,is1P,is1S,is2P,is2S,is3P,ps1P,ps3P
# boire 8 ai2P,is1P,is2P,is3P,ppFP,ppFS,ps1P,ps2P
# fuir 8 ai1S,ai2P,ai2S,is1P,is2P,pc1P,ps1P,ps3P
# courir 8 ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps3P
# joindre 8 ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P
# servir 8 ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,ps1P
# dormir 9 is1P,is1S,is2S,is3P,is3S,ppFP,ppFS,ps1P,ps3P
# lire 9 ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P
# naître 9 ai2P,is1P,is1S,is2P,is2S,pc1P,ps1P,ps2P,ps3P
# écrire 10 ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps3P
# vaincre 10 ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps3P
# haïr 10 ai1P,ai2P,is1P,is1S,is2P,is2S,is3P,ps1P,ps2P,ps3P
# plaire 10 ai2P,is1P,is2P,is2S,is3P,pc1P,ppFP,ppFS,ps1P,ps2P
# valoir 11 ai1P,ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,ps1P,ps2P
# confire 12 ai1P,ai1S,ai2P,ai2S,is1P,is2P,is2S,pc1P,ps1P,ps2P,ps2S,ps3P
# acquérir 12 ai2P,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2S,ps1P,ps2P,ps3P
# absoudre 12 ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P
# vêtir 13 ai2P,ai2S,is1P,is2P,is3S,pc1P,pc2P,pc2S,pc3P,pi1P,ps1P,ps2P,ps3P
# conclure 13 ai1P,ai1S,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P
# coudre 14 ai1P,ai2P,ai2S,ai3P,ii1P,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps2P,ps3P
# cueillir 14 ai1P,ai2P,ai2S,is1P,is1S,is2P,is2S,is3P,is3S,ps1P,ps1S,ps2P,ps3P,ps3S
# traire 16 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc3P,ps1P,ps2P
# inclure 18 ai1P,ai1S,ai2P,fi2P,ii1P,is1P,is1S,is2P,is2S,is3P,is3S,pc1P,pc2S,ppFP,ppFS,ps1P,ps2P,ps3P
# mouvoir 19 ai1P,ai2P,fi2P,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pc1P,pc1S,pc2P,pc2S,pc3P,ps1P,ps1S,ps2P,ps3P
# faillir 23 ai2P,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3S,pI1P,pI2P,pI2S,pc1P,pc2P,pi1S,pi2S,pi3S,ppFP,ppFS,ppMP,ps1P,ps2P,ps3P
# assaillir 22 ai1P,ai2P,fi1P,fi2P,fi2S,fi3S,ii1P,ii2P,is1P,is1S,is2P,is2S,is3S,pc1P,pc2P,pc3P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# croître 24 ai1P,ai1S,ai2P,ai2S,fi1P,fi1S,fi2S,ii1S,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,pc1P,pc1S,pc2S,pc3P,pi2P,ps1P,ps2P,ps2S,ps3P
# bouillir 25 ai1S,ai2P,ai2S,ai3P,fi1S,fi2P,fi2S,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3S,pI2P,pc2P,pc3P,pc3S,pi1P,pi2P,ps1P,ps2P,ps2S,ps3P
# ouïr 30 ai1P,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi3P,fi3S,ii1P,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,is3S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,ps1P,ps2P,ps3P
# clore 35 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi2P,pi2S,ps1P,ps2P,ps3P
# choir 35 ai1P,ai2P,ai2S,ai3P,fi1P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi2P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# gésir 37 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# moudre 38 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi3P,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# pleuvoir 40 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,ii1P,ii1S,ii2P,ii2S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi1S,pi2P,pi2S,ppFP,ppFS,ppMP,ps1P,ps1S,ps2P,ps2S,ps3P
# falloir 43 ai1P,ai1S,ai2P,ai2S,ai3P,fi1P,fi1S,fi2P,fi2S,fi3P,ii1P,ii1S,ii2P,ii2S,ii3P,is1P,is1S,is2P,is2S,is3P,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pi1P,pi1S,pi2P,pi2S,pi3P,ppFP,ppFS,ppMP,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# surseoir 44 ai1P,ai1S,ai2P,ai2S,ai3P,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi2S,pi3P,ppFP,ppFS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# seoir 45 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,ii1P,ii1S,ii2P,ii2S,ii3P,inf,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pi1P,pi1S,pi2P,pi2S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# sourdre 45 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi2P,pi2S,pi3P,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps3P
# occire 50 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# chaloir 50 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# ardre 50 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# férir 50 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# comparoir 50 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
# chauvir 51 ai1P,ai1S,ai2P,ai2S,ai3P,ai3S,fi1P,fi1S,fi2P,fi2S,fi3P,fi3S,ii1P,ii1S,ii2P,ii2S,ii3P,ii3S,inf,is1P,is1S,is2P,is2S,is3P,is3S,pI1P,pI2P,pI2S,pP,pc1P,pc1S,pc2P,pc2S,pc3P,pc3S,pi1P,pi1S,pi2P,pi2S,pi3P,pi3S,ppFP,ppFS,ppMP,ppMS,ps1P,ps1S,ps2P,ps2S,ps3P,ps3S
#
# {u'appuyer': [0, 1, 3, 4, 6], u'suivre': [0, 1], u'aimer': [0, 1, 2, 8, 26, 79, 186], u'tenir': [0, 1, 2, 3], u'boire': [0], u'asseoir': [0], u'occire': [0], u'envoyer': [0], u'dormir': [0, 1], u'\xe9crire': [0], u'fuir': [0, 1], u'vaincre': [0, 1], u'pleuvoir': [0], u'confire': [0, 1, 2], u'cro\xeetre': [0, 1], u'ha\xefr': [0], u'seoir': [0], u'\xe9crouer': [0, 1, 16, 116], u'v\xeatir': [0, 1, 2], u'chaloir': [0], u'surseoir': [0], u'pouvoir': [0], u'ardre': [0], u'clore': [0], u'cuire': [0, 1], u'rendre': [0, 1, 5, 23], u'mourir': [0], u'plaire': [0, 1], u'peindre': [0, 1, 2, 4], u'f\xe9rir': [0], u'acqu\xe9rir': [0, 1, 4], u'avoir': [0], u'traire': [0], u'lire': [0], u'mettre': [0, 1], u'courir': [0, 2], u'coudre': [0, 1], u'mouvoir': [0, 1], u'conna\xeetre': [0], u'vivre': [0, 1], u'battre': [0, 1], u'sentir': [0, 2, 8], u'rire': [0, 1], u'finir': [0, 1, 3, 20, 31, 40, 42], u'inclure': [0], u'valoir': [0], u'savoir': [0], u'moudre': [0], u'ou\xefr': [0], u'assaillir': [0, 1], u'dire': [0], u'joindre': [0], u'absoudre': [0, 2], u'voir': [0], u'pourvoir': [0], u'\xeatre': [0], u'prendre': [0], u'g\xe9sir': [0], u'conclure': [0], u'faire': [0], u'na\xeetre': [0, 1], u'vouloir': [0], u'couvrir': [0, 1, 2], u'choir': [0, 1], u'sourdre': [0], u'falloir': [0], u'faillir': [0, 1], u'comparoir': [0], u'aller': [0], u'chauvir': [], u'bouillir': [0, 1], u'servir': [0], u'cueillir': [0, 2], u'recevoir': [0]}

# %%
personnes=[p+n for n in "SP" for p in "123" ]
cases=[t+p for t in "pi ii fi pc ps ai is".split(" ") for p in personnes]
cases+="pI2S pI1P pI2P inf pP".split(" ")
cases+=["pp"+g+n for g in "MF" for n in "SP"]

# %%
def colorerXTicks(gAX,fSize=12,rot=45):
    xlabels=gAX.get_xticklabels()
    for xlabel in xlabels:
        xtext=xlabel.get_text()
        xlabel.set_backgroundcolor(cellColors[xtext])
        xlabel.set_family(["Linux Libertine O","monospace"])
        xlabel.set_size(fSize)
        xlabel.set_rotation(rot)

# %% [markdown]
# <a id="CF-Lexemes"></a>
# #### Couverture d'une classe flexionnelle par les lexèmes

# %%
vbParadigmes=[]
cfVerbe="rendre"
cfCouverture="Min"

if cfCouverture=="Min":
    cfVerbes=[cf[cfVerbe][i] for i in cfSauts[cfVerbe]]
elif cfCouverture=="Tot":
    cfVerbes=cf[cfVerbe]

for v in cfVerbes:
#     print v
    cKnown={}
    cKnown[u"lexème"]=v
    knownCases=getLexemeSet(v)
    for mC in knownCases:
        cKnown[mC]=len(knownCases)+25
    vbParadigmes.append(cKnown)
# vbParadigmes

# %%
df=pd.DataFrame(vbParadigmes)
inCases=df.columns
outCases=list(set(cases)-set(inCases))
# df=df.reindex(columns=inCases+outCases)
df=pd.concat([df,pd.DataFrame(columns=outCases)],sort=False)
df=df[[u"lexème"]+cases].fillna(0).set_index(u"lexème")
df.index.names=["CF-"+cfVerbe]
h=len(df.index)
print h
# Out:
# 4

# %%
_, ax = plt.subplots(figsize=(30,h/float(2)))
ax=sns.heatmap(
                df,
#                 annot=True,
                ax=ax,
                cmap='Greens',
                cbar=False,
              )
colorerXTicks(ax,fSize=24,rot=90)
ylabels=ax.get_yticklabels()
ax.set_yticklabels(ylabels,size=24,
                   variant="small-caps",family=["Linux Libertine O","monospace"],
#                    rot=0,
                  )
ylabel=ax.get_ylabel()
ax.set_ylabel(ylabel,size=24,
                   variant="small-caps",family=["Linux Libertine O","monospace"],
#                    rot=0,
                  )
fig = plt.gcf()
etMap={
    3:cellColors["pi1S"],
    5:cellColors["pi1P"],
    6:cellColors["pi3P"],
    12:cellColors["ii1S"],
    24:cellColors["fi1S"],
    27:cellColors["ps1S"],
    29:cellColors["ps1P"],
    30:cellColors["ps3P"],
    42:cellColors["ai1S"],
    43:cellColors["pI2S"],
    45:cellColors["pI1P"],
    46:cellColors["inf"],
    47:cellColors["pP"],
    51:cellColors["ppMS"],
}
prevCol=0
rect={}
for l in [3,5,6,12,24,27,29,30,42,43,45,46,47,51]:
#     line=plt.Line2D((l,l),(0,h),color="k",alpha=0.5,linestyle=":")
#     fig.gca().add_artist(line)
    rect=plt.Rectangle((prevCol,0),l-prevCol,h,alpha=0.1,color=etMap[l])
    fig.gca().add_artist(rect)
    prevCol=l
for l in range(4,h,5):
    line=plt.Line2D((0,51),(l,l),color="k",alpha=0.5,linestyle="--")
    fig.gca().add_artist(line)

for l in [n for n,v in enumerate(df.index.tolist()) if v in noPP]:
    rect=plt.Rectangle((48,l),51,1,alpha=1,color="k")
    fig.gca().add_artist(rect)

for case in [mC for mC in cfSet[cfVerbe].split(",") if mC!=""]:
    l=cases.index(case)
    print case,l
    rect=plt.Rectangle((l,0),1,h,alpha=1,color="red")
    fig.gca().add_artist(rect)
    
    
display(HTML('<a id="CF-Heatmap-Verbes"></a>')) #bookmark for internal links

plt.savefig(repFigs+u'Lex4β-Heatmap-CF-%s-Couverture%s.pdf'%(cfVerbe,cfCouverture), dpi=300, bbox_inches="tight")
# Out:
# is1P 39
# is2P 40
# <a id="CF-Heatmap-Verbes"></a>

# %% [markdown]
# Liens :
# - [Couverture d'une classe par ses verbes](#CF-Lexemes)

# %% [markdown]
# <a id="CF-Cases"></a>
# #### Couverture des cases pour les classes flexionnelles dans Lexique4β
#
# Dans *cfParadigme*, les cases contiennent :
# - 0 si la case est couverte pour la case flexionnelle
# - n si n cases sont inconnues pour la classe flexionnelle
#
# Les lexèmes peuvent être triés par population de leurs paradigmes ou dans l'ordre défini par Stump & Finkel (2013) :
# - triCF
#     - "SF"
#     - ""
#
# Le tri est inclus dans le nom du fichier Heatmap exporté.
#
# Les cases et les colonnes correspondantes sont colorées d'après l'espace thématique du français :
# - cellColors définit la couleur de chaque case
# - cellColors est importé de *EspacesThematiques.py*
# - etMap donne les couleurs des colonnes
#
# Toutes les 5 classes, on trace une ligne horizontale pour permettre de mieux repérer les correspondances.
#
# La police choisie est celle du document LaTeX : *Linux Libertine O*

# %%
cfParadigme=[]

if triCF:   #choix entre l'ordre StumpFinkel et l'ordre par défaut
    ordreCF=ordreSF
else:
    ordreCF=sorted(cfDef, key=lambda x: cfDef[x])

for c in ordreCF:
    print c
    cMissing={}
    cMissing["cf"]=c
    missingCases=[mC for mC in cfSet[c].split(",") if mC!=""]
    for mC in missingCases:
        cMissing[mC]=len(missingCases)+25
    cfParadigme.append(cMissing)
# Out:
# aimer
# tenir
# avoir
# être
# écrouer
# pouvoir
# mettre
# sentir
# faire
# recevoir
# rendre
# savoir
# finir
# prendre
# connaître
# dire
# voir
# aller
# envoyer
# rire
# pourvoir
# vouloir
# couvrir
# suivre
# battre
# asseoir
# cuire
# mourir
# peindre
# vivre
# appuyer
# boire
# fuir
# courir
# joindre
# servir
# dormir
# lire
# naître
# écrire
# vaincre
# haïr
# plaire
# valoir
# confire
# acquérir
# absoudre
# vêtir
# conclure
# coudre
# cueillir
# traire
# inclure
# mouvoir
# faillir
# assaillir
# croître
# bouillir
# ouïr
# clore
# choir
# gésir
# moudre
# pleuvoir
# falloir
# surseoir
# seoir
# sourdre
# occire
# chaloir
# ardre
# férir
# comparoir
# chauvir

# %%
df=pd.DataFrame(cfParadigme)
inCases=df.columns
outCases=list(set(cases)-set(inCases))
# df=df.reindex(columns=inCases+outCases)
df=pd.concat([df,pd.DataFrame(columns=outCases)],sort=False)
df=df[["cf"]+cases].fillna(0).set_index("cf")
h=len(df.index)

# %%
_, ax = plt.subplots(figsize=(30,35))
ax=sns.heatmap(
                df,
#                 annot=True,
                ax=ax,
                cmap='OrRd',
                cbar=False,
              )
colorerXTicks(ax,fSize=24,rot=90)
ylabels=ax.get_yticklabels()
ax.set_yticklabels(ylabels,size=24,variant="small-caps",family=["Linux Libertine O","monospace"])
fig = plt.gcf()
etMap={
    3:cellColors["pi1S"],
    5:cellColors["pi1P"],
    6:cellColors["pi3P"],
    12:cellColors["ii1S"],
    24:cellColors["fi1S"],
    27:cellColors["ps1S"],
    29:cellColors["ps1P"],
    30:cellColors["ps3P"],
    42:cellColors["ai1S"],
    43:cellColors["pI2S"],
    45:cellColors["pI1P"],
    46:cellColors["inf"],
    47:cellColors["pP"],
    51:cellColors["ppMS"],
}
prevCol=0
rect={}
for l in [3,5,6,12,24,27,29,30,42,43,45,46,47,51]:
#     line=plt.Line2D((l,l),(0,h),color="k",alpha=0.5,linestyle=":")
#     fig.gca().add_artist(line)
    rect=plt.Rectangle((prevCol,0),l-prevCol,h,alpha=0.1,color=etMap[l])
    fig.gca().add_artist(rect)
    prevCol=l
for l in range(4,h,5):
    line=plt.Line2D((0,51),(l,l),color="k",alpha=0.5,linestyle="--")
    fig.gca().add_artist(line)

for l in [n for n,v in enumerate(df.index.tolist()) if v in noPP]:
    rect=plt.Rectangle((48,l),51,1,alpha=1,color="k")
    fig.gca().add_artist(rect)

    
display(HTML('<a id="CF-Heatmap"></a>')) #bookmark for internal links

plt.savefig(repFigs+u'Lex4β-Heatmap-ClassesFlexionnelles%s-Couverture.pdf'%triCF, dpi=300, bbox_inches="tight")
# Out:
# <a id="CF-Heatmap"></a>

# %% [markdown]
# <a id='CF-Heatmap'></a>
# # CF Heatmap
# Un tableau de la couverture maximale des classes flexionnelles
# <br/>
# <br/>
# <br/>
# <br/>
# <br/>
# Liens :
# - [Tri CF Début](#TriCF)
# - [CF Stump & Finkel](#CF-StumpFinkel)
# - [Heatmap CF](#CF-Heatmap)
# - [Tri CF Fin](#TriCF)
