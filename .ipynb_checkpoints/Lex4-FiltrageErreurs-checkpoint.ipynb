# %%
import pandas as pd
import numpy as np
from IPython.display import display
debug=0

# %%
rep="/Users/gilles/Downloads/"
fLexFilms4=rep+"Lexique4_min+filtr+cat+separ+corr4.tsv"
df=pd.read_csv(filepath_or_buffer=fLexFilms4,sep="\t",header=None,skip_blank_lines=True,encoding="utf8")
df.columns="graphie lemme cat infover genre nombre occurrences".split(" ")
print len(df)
df.head()
# Out:
# 225133
#         graphie        lemme  cat    infover genre nombre  occurrences
# 0      fossiles      fossile  ADJ        NaN   NaN      p         41.0
# 1        clopes       cloper  VER  sub:pre:2   NaN      s          1.0
# 2       ardeurs       ardeur  NOM        NaN     f      p        143.0
# 3  translations  translation  NOM        NaN   NaN    NaN          3.0
# 4    antidrogue   antidrogue  ADJ        NaN     m      s         36.0

# %% [raw]
# df["graphie"]=df["graphie"].astype("unicode")
# df["graphie"] = df["graphie"].apply(lambda x: x.encode('utf-8').strip())
# df.info()

# %% [markdown]
# # Incohérences globales
# - Duplicates
#  - on regoupe les duplicates
# - Graphies et Lemmes nuls
#  - on commence par éliminer les élements dont la graphie ou le lemme est nul.

# %% [markdown]
# ### Duplicates
# On utilise *groupby* pour cumuler les occurrences. Comme la méthode *groupby* exclue les éléments contenant des NaN, on fait un remplacement avant et après le regroupement.
# 1. on remplace les NaN par des "NaN" pour les inclure dans les groupes
# 1. on cumule les occurrences
# 1. on remplace les "NaN" par les NaN d'origine

# %%
df=df.fillna("NaN").groupby("graphie lemme cat infover genre nombre".split()).sum().reset_index()
df=df.replace(ur"^NaN$",np.nan,regex=True)
print len(df)
# Out:
# 218831

# %% [markdown]
# ### Graphies et Lemmes nuls

# %%
condNoLemme=(df.lemme.isnull())
condNoGraphie=(df.graphie.isnull())
nulGraphieLemme=df[condNoLemme|condNoGraphie]
print len(nulGraphieLemme)
display(nulGraphieLemme)
df.drop(nulGraphieLemme.index,inplace=True)
print len(df)
# Out:
# 37
#           graphie lemme  cat   infover genre nombre  occurrences
# 0              \t   NaN  NaN       NaN   NaN      1          NaN
# 5               '   NaN  ADV       NaN   NaN    NaN         28.0
# 10              -   NaN  ADV       NaN   NaN    NaN         28.0
# 118           NaN   NaN  ADV       NaN   NaN    NaN       4728.0
# 7215        alpha   NaN  ADJ       NaN     m      s          1.0
# 14330       assis   NaN  VER  par:pas:     m      p          1.0
# 21155         ben   NaN  ADJ       NaN     m      s          1.0
# 30705      capote   NaN  ADJ       NaN     m      s          1.0
# 31744   cartouche   NaN  ADJ       NaN     m      s          1.0
# 40143       comme   NaN  ADJ       NaN     m      s          1.0
# 45264      contre   NaN  ADJ       NaN     m      s          1.0
# 52557          de   NaN  ADJ       NaN     m      s          2.0
# 56872        doit   NaN  ADJ       NaN     m      s          1.0
# 68953      désiré   NaN  ADJ       NaN     m      s          1.0
# 79625          et   NaN  ADJ       NaN     m      s          1.0
# ...           ...   ...  ...       ...   ...    ...          ...
# 130548          n   NaN  ADJ       NaN     m      s          1.0
# 130585       nage   NaN  ADJ       NaN     m      s          1.0
# 143916      photo   NaN  ADJ       NaN     m      s          1.0
# 149812       pour   NaN  ADJ       NaN     m      s         12.0
# 161539        ray   NaN  ADJ       NaN     m      s          1.0
# 180658       sans   NaN  ADJ       NaN     m      s          4.0
# 183071       sens   NaN  ADJ       NaN     m      s          1.0
# 183072       sens   NaN  NOM       NaN     m    NaN          1.0
# 196224         te   NaN  ADJ       NaN     m      s          1.0
# 202776      trois   NaN  ADJ       NaN     m      s          1.0
# 203638      trône   NaN  ADJ       NaN     m      s          1.0
# 207560       vers   NaN  ADJ       NaN     m      s          1.0
# 209352      voici   NaN  ADJ       NaN     m      s          2.0
# 209411      voilà   NaN  ADJ       NaN     m      s          2.0
# 217130      était   NaN  ADJ       NaN     m      s          1.0
#
# [37 rows x 7 columns]
# 218794

# %%
def bilanDF(lDF,title="cas",lines=False):
    print "%s : %d"%(title,len(lDF))
    if lines:
        with pd.option_context('display.max_rows', None, 'display.max_columns', None):  # more options can be specified also
            display(lDF.sort_values("occurrences",ascending=False))
    else:
        display(lDF.sort_values("occurrences",ascending=False).head())
    return

# %% [markdown]
# # Contrôles de cohérence pour le genre et le nombre des substantifs
# Dans la première version reçue, il y avait eu un problème de découpage de l'étiquette des participes présent par:pre qui avait donné la répartition suivante :
# - infover = par:p
# - genre = e
# - nombre = r
#
# La première série de test visait à faire la liste des problèmes de valeurs hors norme pour le genre et le nombre.
#
# La deuxième série fait la liste des pluriels qui ne se terminent ni par s, ni par x, ni par z. Ce type de pluriel est atypique mais il est normal pour certains noms composés et les pluriels empruntés.

# %%
# Default value of display.max_rows is 10 i.e. at max 10 rows will be printed.
# Set it None to display all rows in the dataframe
pdMaxRows=pd.options.display.max_rows
pd.set_option('display.max_rows', 30)

# %% [markdown]
# ## Genre & Nombre
# Pour les adjectifs et les noms, on cherche toutes les formes qui ont
# - un genre explicite en dehors de m, f
# - un nombre explicite en dehors de s, p

# %% [markdown]
# ### Genre

# %%
condGenre=(df["cat"].isin(["NOM","ADJ"]))&(df["genre"].notnull())&(~df["genre"].isin(["f","m"]))
bilanDF(df[condGenre],"Substantifs hors m/f")
# Out:
# Substantifs hors m/f : 0
# Empty DataFrame
# Columns: [graphie, lemme, cat, infover, genre, nombre, occurrences]
# Index: []

# %% [markdown]
# ### Nombre

# %%
condNombre=(df["cat"].isin(["NOM","ADJ"]))&(df["nombre"].notnull())&(~df["nombre"].isin(["s","p"]))
bilanDF(df[condNombre],"Substantifs hors s/p")
# Out:
# Substantifs hors s/p : 0
# Empty DataFrame
# Columns: [graphie, lemme, cat, infover, genre, nombre, occurrences]
# Index: []

# %% [markdown]
# Il y avait seulement un problème avec *gluant* et *attrayant*, qui ont été classés comme ADJ, parce que l'étiquette par:pre a été mal traitée. Il y avait un problème plus général avec les participes présents qui avaient aussi un infover par:p avec le genre e et le nombre r, probablement suite à la même erreur.

# %% [markdown]
# # Cohérence des formes de substantifs
# - Pour les noms sans nombre, on peut comparer le lemme avec la forme de l'élément pour rétablir les éventuels singuliers et pluriels.
# - Pour les adjectifs, on peut faire la même chose en incluant le genre

# %% [markdown]
# ### Extractions (Forme, Lemme)
# Pour gérer les structures incohérentes, on extrait les structures partageant la même paire (forme, lemme) pour éventuellement mapper la mauvaise structure vers la bonne.

# %%
def getFormeLemme(forme,lemme):
    return df[(df.graphie==forme)&(df.lemme==lemme)]

# %%
condFormeNotLemme=df.graphie!=df.lemme
condN=df.cat=="NOM"
condA=df.cat=="ADJ"
condNA=df["cat"].isin(["NOM","ADJ"])
condNoNombreN=condN&(df.nombre.isnull())
condNoNombreA=condA&(df.nombre.isnull())
condNoNombreNA=condNA&(df["nombre"].isnull())
condGenreNombre=(df.genre.notnull())&(df.nombre.notnull())

# %%
bilanDF(df[condNoNombreN&condFormeNotLemme],"Noms nombre NaN")
# Out:
# Noms nombre NaN : 997
#        graphie  lemme  cat infover genre nombre  occurrences
# 6566    aliens  alien  NOM     NaN   NaN    NaN       2210.0
# 197296  textos  texto  NOM     NaN   NaN    NaN       1300.0
# 130550       n     ne  NOM     NaN     m    NaN       1208.0
# 193052  sushis  sushi  NOM     NaN   NaN    NaN        791.0
# 183989   shots   shot  NOM     NaN   NaN    NaN        542.0

# %%
def cumulerElements(localCond,localChoix,localTest):
    nbGraphieLemme=0
    nbChoixGraphieLemme=0
    formesChoix=[]
    indexDrops=[]
    localDF=df[localCond]
    for index,row in localDF.iterrows():
        mauvaisesOccurrences=row.occurrences
        graphie=row.graphie
        lemme=row.lemme
        if localTest=="lemme+s":
            lemmeTest=(graphie==lemme+"s")
        elif localTest=="lemme":
            lemmeTest=(graphie==lemme)
        if lemmeTest:
            print graphie,lemme,mauvaisesOccurrences
            dfGraphieLemme=getFormeLemme(row.graphie,row.lemme)
            dfChoix=dfGraphieLemme[localChoix]
            if len(dfChoix)==1:
                occurrencesChoix=dfChoix.occurrences.values[0]
                ixChoix=dfChoix.index[0]
                if debug: print ixChoix,occurrencesChoix,occurrencesChoix+mauvaisesOccurrences
                df.loc[df.index==ixChoix,"occurrences"]=occurrencesChoix+mauvaisesOccurrences
                if debug: print df.occurrences.iloc[ixChoix]
                indexDrops.append(index)
                if debug: display(df[df.graphie==graphie])
            else:
#                 display(dfChoix)
                nbChoixGraphieLemme+=1
                formesChoix.append(graphie)
            nbGraphieLemme+=1
    df.drop(indexDrops,inplace=True)
    print len(df)
    print nbChoixGraphieLemme,nbGraphieLemme
    print ", ".join(formesChoix)

# %%
cumulerElements(condNoNombreN&condFormeNotLemme,condN&condGenreNombre,"lemme+s")
# Out:
# ables able 2.0
# abstinents abstinent 5.0
# aces
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# ace 4.0
# acres acre 20.0
# acteurs acteur 1.0
# actinomètres actinomètre 1.0
# actions action 3.0
# addicts addict 26.0
# adiposes adipose 1.0
# affaires affaire 4.0
# africains africain 4.0
# agences agence 1.0
# ages age 1.0
# aidants aidant 12.0
# aides aide 3.0
# aires aire 3.0
# algériens algérien 1.0
# aliens alien 2210.0
# allemands allemand 7.0
# altermondialistes altermondialiste 4.0
# amusements amusement 1.0
# américains américain 22.0
# analystes analyste 1.0
# anciens ancien 35.0
# ancêtres ancêtre 1.0
# angles angle 5.0
# antivols antivol 1.0
# après-midis après-midi 1.0
# armes arme 2.0
# armées armée 1.0
# arrondis arrondi 1.0
# arts art 13.0
# associés associé 10.0
# athéniens athénien 1.0
# attitudes attitude 1.0
# auto-stoppeurs auto-stoppeur 5.0
# autoportraits autoportrait 1.0
# aventures aventure 1.0
# aveuglettes aveuglette 1.0
# aînés aîné 1.0
# baby-sitters baby-sitter 2.0
# bahts baht 1.0
# bains bain 2.0
# baiseurs baiseur 1.0
# baisses baisse 1.0
# balivernes baliverne 1.0
# bals bal 1.0
# banjos banjo 1.0
# banques banque 1.0
# bardas barda 1.0
# barns barn 8.0
# barracudas barracuda 2.0
# barrels barrel 5.0
# barres barre 4.0
# bars bar 2.0
# baskets basket 8.0
# batailles bataille 1.0
# battants battant 1.0
# beagles beagle 1.0
# best-sellers best-seller 1.0
# billions billion 1.0
# bios bio 61.0
# biostatistiques biostatistique 1.0
# bisous bisou 1.0
# bites bite 11.0
# bits bit 16.0
# blablas blabla 20.0
# blagues blague 1.0
# blancs blanc 15.0
# blazers blazer 7.0
# blizzards blizzard 1.0
# blogs blog 239.0
# bloomers bloomer 1.0
# blooms bloom 1.0
# bluffs bluff 19.0
# bogues bogue 4.0
# bolides bolide 1.0
# bombes bombe 2.0
# bonds bond 1.0
# bons bon 2.0
# boosters booster 1.0
# bops bop 1.0
# bottages bottage 2.0
# boucaniers boucanier 1.0
# boucles boucle 2.0
# boules boule 7.0
# bourgognes bourgogne 1.0
# boursoufflures boursoufflure 1.0
# boys boy 188.0
# brames brame 1.0
# branches branche 1.0
# braves brave 1.0
# breakfasts breakfast 3.0
# breaks break 7.0
# bricks brick 1.0
# brides bride 2.0
# brésiliens brésilien 1.0
# brûlés brûlé 8.0
# buildings building 2.0
# bulles bulle 4.0
# burqas burqa 4.0
# buttes butte 2.0
# cabs cab 13.0
# cairns cairn 4.0
# cakes cake 14.0
# call-girls call-girl 2.0
# calories calorie 1.0
# camarades camarade 2.0
# cames came 2.0
# camping-cars camping-car 2.0
# caméras caméra 1.0
# canadiens canadien 2.0
# canes cane 4.0
# canons canon 7.0
# capotes capote 1.0
# cardigans cardigan 1.0
# caris cari 9.0
# cartes carte 1.0
# cascadeurs cascadeur 1.0
# casses casse 1.0
# castings casting 1.0
# causes cause 1.0
# cendres cendre 2.0
# centres centre 1.0
# cents cent 1.0
# chambres chambre 1.0
# champions champion 1.0
# chances chance 1.0
# changes change 3.0
# charges charge 1.0
# charters charter 2.0
# chatouilles chatouille 1.0
# chewing-gums chewing-gum 1.0
# chiffres chiffre 6.0
# chines chine 1.0
# chiropracteurs chiropracteur 1.0
# chorégraphies chorégraphie 1.0
# christs christ 1.0
# chrétiens chrétien 1.0
# chéris chéri 1.0
# cigarettes cigarette 1.0
# clams clam 2.0
# clearings clearing 1.0
# clodos clodo 1.0
# clones clone 1.0
# clowns clown 2.0
# clubs club 2.0
# clôtures clôture 1.0
# cobras cobra 2.0
# collections collection 5.0
# colocataires colocataire 2.0
# colts colt 4.0
# columbariums columbarium 1.0
# colverts colvert 2.0
# combats combat 1.0
# commandos commando 1.0
# commissions commission 1.0
# communications communication 4.0
# compos compo 1.0
# comptines comptine 1.0
# concepts concept 2.0
# condominiums condominium 5.0
# confessions confession 5.0
# congas conga 1.0
# conservateurs conservateur 1.0
# contracteurs contracteur 5.0
# contre-mesures contre-mesure 1.0
# contre-torpilleurs contre-torpilleur 1.0
# contusions contusion 3.0
# corners corner 33.0
# corrections correction 13.0
# coréens coréen 1.0
# costumes costume 14.0
# costumiers costumier 1.0
# cottages cottage 4.0
# couleurs couleur 1.0
# couples couple 4.0
# couronnes couronne 39.0
# courses course 1.0
# cous cou 2.0
# cow-boys cow-boy 3.0
# crackers cracker 32.0
# cracs crac 7.0
# crawls crawl 1.0
# crickets cricket 3.0
# crimes crime 5.0
# crocodiles crocodile 1.0
# croquettes croquette 18.0
# crosses crosse 2.0
# crouilles crouille 1.0
# créateurs créateur 1.0
# crêpes crêpe 1.0
# cubains cubain 2.0
# cubes cube 2.0
# culottes culotte 2.0
# cures cure 1.0
# cycles cycle 4.0
# célestins célestin 1.0
# dalmatiens dalmatien 5.0
# damages damage 6.0
# dames dame 2.0
# designs design 11.0
# destructeurs destructeur 1.0
# devins devin 7.0
# devons devon 4.0
# diamants diamant 1.0
# disciples disciple 5.0
# divins divin 1.0
# divisions division 1.0
# dockers docker 2.0
# docks dock 5.0
# docteurs docteur 1.0
# donnes donne 3.0
# dragons dragon 5.0
# dribbleurs dribbleur 3.0
# drinks drink 2.0
# drives drive 1.0
# drogues drogue 3.0
# drops drop 2.0
# droïdes droïde 474.0
# drumlins drumlin 2.0
# duos duo 6.0
# dynes dyne 1.0
# dyslexiques dyslexique 1.0
# déconnades déconnade 2.0
# décors décor 29.0
# décris décri 1.0
# défilés défilé 1.0
# délinquants délinquant 3.0
# délires délire 1.0
# démos démo 105.0
# déménagements déménagement 1.0
# dépravés dépravé 1.0
# ectoplasmes ectoplasme 10.0
# elfes elfe 1.0
# embrasses embrasse 1.0
# empires empire 2.0
# encans encan 2.0
# enchanteurs enchanteur 1.0
# enchaînés enchaîné 5.0
# enchères enchère 1.0
# entreprises entreprise 25.0
# erreurs erreur 1.0
# escortes escorte 1.0
# espagnols espagnol 3.0
# espars espar 2.0
# estes este 19.0
# européens européen 1.0
# euros euro 1.0
# expectations expectation 4.0
# exports export 11.0
# extra-terrestres extra-terrestre 2.0
# extravagants extravagant 1.0
# extérieurs extérieur 1.0
# fajitas fajita 85.0
# fans fan 3.0
# fantasmes fantasme 4.0
# fantômes fantôme 7.0
# farts fart 1.0
# feelings feeling 2.0
# fermes ferme 1.0
# fermiers fermier 1.0
# ferrailles ferraille 3.0
# fesses fesse 4.0
# feuilles feuille 3.0
# figures figure 4.0
# files file 13.0
# filles fille 1.0
# films film 17.0
# finances finance 4.0
# fixes fixe 1.0
# fjords fjord 3.0
# flics flic 1.0
# flocs floc 1.0
# folates folate 1.0
# folks folk 4.0
# fontes fonte 1.0
# footballers footballer 12.0
# foots foot 1.0
# forces force 10.0
# forges forge 1.0
# fors for 2.0
# fortunes fortune 1.0
# fourrures fourrure 1.0
# foutaises foutaise 1.0
# frimes frime 1.0
# frites frite 2.0
# frontières frontière 31.0
# fruits fruit 3.0
# fréquences fréquence 1.0
# gaines gaine 82.0
# gals gal 1.0
# gangs gang 3.0
# garde-chiourmes garde-chiourme 7.0
# gardes-côtes gardes-côte 1.0
# gardons gardon 1.0
# gares gare 1.0
# garous garou 2.0
# gaufres gaufre 2.0
# genouillères genouillère 1.0
# germains germain 2.0
# girls girl 124.0
# glaces glace 2.0
# globes globe 5.0
# glutens gluten 1.0
# gouines gouine 3.0
# goys goy 30.0
# graffitis graffiti 1.0
# graines graine 1.0
# graisses graisse 1.0
# grand-mères grand-mère 1.0
# grecs grec 1.0
# greens green 1.0
# grills grill 1.0
# grils gril 1.0
# grinches grinche 1.0
# grooms groom 1.0
# grèves grève 3.0
# guides guide 2.0
# gujaratis gujarati 1.0
# gyms gym 1.0
# hackers hacker 1.0
# haddocks haddock 1.0
# hadjis hadji 10.0
# haines haine 2.0
# halos halo 1.0
# hamburgers hamburger 1.0
# hardcores hardcore 4.0
# haut-parleurs haut-parleur 11.0
# herbes herbe 2.0
# highlanders highlander 1.0
# hits hit 5.0
# holdings holding 56.0
# hologrammes hologramme 1.0
# hombres hombre 2.0
# homes home 4.0
# hommes homme 2.0
# horizons horizon 4.0
# hormones hormone 1.0
# hot-dogs hot-dog 7.0
# houes houe 2.0
# hubs hub 3.0
# hunters hunter 5.0
# hyacinthes hyacinthe 1.0
# images image 7.0
# impalas impala 1.0
# implants implant 1.0
# imports import 19.0
# industries industrie 14.0
# infectiologues infectiologue 1.0
# infos info 2.0
# instruments instrument 2.0
# insurgents insurgent 2.0
# intentions intention 1.0
# inventeurs inventeur 1.0
# inventions invention 1.0
# investigations investigation 6.0
# invités invité 1.0
# irakiens irakien 2.0
# isomères isomère 1.0
# italiens italien 2.0
# jackets jacket 9.0
# jackpots jackpot 1.0
# jacks jack 2.0
# jaguars jaguar 1.0
# janissaires janissaire 1.0
# jans jan 2.0
# jerks jerk 3.0
# jets jet 1.0
# joailliers joaillier 1.0
# jockeys jockey 1.0
# jokers joker 1.0
# joues joue 1.0
# jouets jouet 1.0
# joueurs joueur 1.0
# juifs juif 20.0
# kanas kana 1.0
# kicks kick 3.0
# kilotonnes kilotonne 1.0
# kings king 27.0
# kits kit 1.0
# kiwis kiwi 1.0
# laboratoires laboratoire 1.0
# laisses laisse 3.0
# laitages laitage 1.0
# lancers lancer 2.0
# lançons lançon 1.0
# lardons lardon 1.0
# lasagnes lasagne 2.0
# laveurs laveur 3.0
# lemmings lemming 2.0
# lempiras lempira 1.0
# libellules libellule 1.0
# libyens libyen 1.0
# likes like 52.0
# listes liste 1.0
# lives live 96.0
# livres livre 4.0
# lofts loft 1.0
# lolos lolo 1.0
# looks look 4.0
# lumières lumière 3.0
# lurons luron 1.0
# lycanthropes lycanthrope 1.0
# lyrics lyric 2.0
# légumes légume 1.0
# macerons maceron 1.0
# machines machine 7.0
# macros macro 5.0
# macs mac 6.0
# madrassas madrassa 3.0
# mafiosos mafioso 6.0
# magazines magazine 1.0
# malis mali 1.0
# manières manière 3.0
# mansions mansion 9.0
# manucures manucure 1.0
# maquettes maquette 1.0
# maquillages maquillage 2.0
# marinas marina 1.0
# mariés marié 6.0
# marques marque 7.0
# mascaras mascara 1.0
# masers maser 1.0
# masques masque 8.0
# masses masse 6.0
# mayes maye 8.0
# meilleurs meilleur 1.0
# mementos memento 2.0
# mennonites mennonite 2.0
# menthols menthol 1.0
# messages message 1.0
# mexicains mexicain 6.0
# milléniums millénium 3.0
# mimosas mimosa 1.0
# mines mine 4.0
# mini-jupes mini-jupe 1.0
# minutes minute 5.0
# mites mite 2.0
# moises moise 1.0
# mondes monde 2.0
# monitors monitor 1.0
# monologues monologue 1.0
# monos mono 42.0
# montes monte 14.0
# mores more 1.0
# motos moto 1.0
# moufles moufle 1.0
# moustiques moustique 1.0
# muffins muffin 6.0
# munitions munition 1.0
# munsters munster 1.0
# murmures murmure 2.0
# muscles muscle 3.0
# muses muse 2.0
# musiciens musicien 1.0
# mustangs mustang 4.0
# musts must 9.0
# myrtilles myrtille 2.0
# mères mère 1.0
# méchants méchant 1.0
# médecins médecin 2.0
# mégacycles mégacycle 1.0
# mégatonnes mégatonne 1.0
# mémérages mémérage 1.0
# nains nain 1.0
# nanoparticules nanoparticule 12.0
# nanotechnologies nanotechnologie 1.0
# nations nation 1.0
# navels navel 2.0
# neufs neuf 2.0
# nichons nichon 6.0
# nickels nickel 2.0
# ninjas ninja 538.0
# noces noce 2.0
# noceurs noceur 3.0
# noirs noir 9.0
# notes note 12.0
# notions notion 1.0
# novas nova 1.0
# nuits nuit 2.0
# nénés néné 1.0
# néos néo 2.0
# obsessions obsession 1.0
# obstacles obstacle 1.0
# omelettes omelette 1.0
# opens open 2.0
# opticiens opticien 1.0
# options option 1.0
# outrepassements outrepassement 1.0
# ovnis ovni 61.0
# ovoproduits ovoproduit 1.0
# oxfords oxford 1.0
# pains pain 2.0
# palaces palace 1.0
# palestiniens palestinien 4.0
# pals pal 1.0
# pandas panda 3.0
# pandits pandit 1.0
# pantalons pantalon 2.0
# panzers panzer 1.0
# papayes papaye 2.0
# papis papi 1.0
# parcs parc 2.0
# parents parent 1.0
# parisiens parisien 1.0
# partenaires partenaire 2.0
# partis parti 1.0
# partisans partisan 1.0
# passages passage 1.0
# passes passe 2.0
# passions passion 2.0
# peines peine 1.0
# pellicules pellicule 1.0
# pensions pension 1.0
# pets pet 2.0
# phtalates phtalate 1.0
# phénomènes phénomène 1.0
# pierrettes pierrette 1.0
# pigeons pigeon 1.0
# pilots pilot 9.0
# pingouins pingouin 1.0
# pipes pipe 1.0
# pique-assiettes pique-assiette 2.0
# piranhas piranha 1.0
# pistons piston 5.0
# pizzas pizza 1.0
# places place 7.0
# plains plain 17.0
# plantons planton 1.0
# plastics plastic 6.0
# plats plat 3.0
# play-backs play-back 1.0
# plonges plonge 3.0
# plots plot 2.0
# plugins plugin 2.0
# pneus pneu 1.0
# policiers policier 1.0
# poneys poney 4.0
# pontes ponte 1.0
# popotins popotin 1.0
# portes porte 2.0
# portoricains portoricain 1.0
# portraits portrait 1.0
# postes poste 1.0
# postiches postiche 1.0
# posts post 78.0
# potions potion 1.0
# prestations prestation 1.0
# prions prion 2.0
# prioritaires prioritaire 1.0
# privilégiés privilégié 1.0
# problèmes problème 1.0
# producteurs producteur 13.0
# productions production 26.0
# programmes programme 1.0
# pros pro 1.0
# protecteurs protecteur 1.0
# prunes prune 1.0
# prussiens prussien 1.0
# psychiatres psychiatre 1.0
# psychopathes psychopathe 1.0
# publications publication 1.0
# publics public 1.0
# puces puce 1.0
# puddings pudding 2.0
# pumas puma 2.0
# pustules pustule 1.0
# péchés péché 11.0
# pétages pétage 6.0
# quantums quantum 5.0
# quinones quinone 8.0
# racers racer 1.0
# races race 3.0
# racks rack 2.0
# raconteurs raconteur 2.0
# raiders raider 17.0
# rails rail 1.0
# raines raine 1.0
# ramasses ramasse 1.0
# ranchers rancher 4.0
# rappeurs rappeur 1.0
# raps rap 27.0
# ratons raton 1.0
# rats rat 5.0
# raveurs raveur 2.0
# records record 64.0
# reichsmarks reichsmark 3.0
# relations relation 11.0
# relectures relecture 1.0
# remonte-pentes remonte-pente 1.0
# rems rem 20.0
# rencarts rencart 107.0
# replacements replacement 3.0
# reports report 2.0
# ressources ressource 3.0
# restes reste 1.0
# retrievers retriever 4.0
# retrouvailles retrouvaille 1.0
# revivals revival 2.0
# rides ride 2.0
# rifles rifle 10.0
# rimes rime 7.0
# rings ring 1.0
# risques risque 1.0
# rites rite 2.0
# robins robin 10.0
# robots robot 5.0
# roches roche 1.0
# rockers rocker 9.0
# rockets rocket 12.0
# rocks rock 15.0
# rollers roller 25.0
# roques roque 2.0
# roses rose 3.0
# rouflaquettes rouflaquette 1.0
# roulettes roulette 1.0
# rounds round 1.0
# roupies roupie 1.0
# routes route 1.0
# royaumes royaume 72.0
# rubans ruban 1.0
# rues rue 1.0
# règles règle 2.0
# républicains républicain 15.0
# résistants résistant 1.0
# rêves rêve 1.0
# sabords sabord 1.0
# saints saint 4.0
# salons salon 1.0
# sauces sauce 1.0
# sauteurs sauteur 1.0
# savants savant 1.0
# schizos schizo 15.0
# scratchs scratch 14.0
# selfies selfie 137.0
# sertes serte 3.0
# services service 40.0
# sessions session 1.0
# sexes sexe 1.0
# shirts shirt 19.0
# shoots shoot 1.0
# shorts short 3.0
# shots shot 542.0
# shows show 1.0
# sierras sierra 1.0
# sigmas sigma 2.0
# simas sima 1.0
# singes singe 15.0
# sirs sir 1.0
# skateboards skateboard 3.0
# skates skate 6.0
# sketchs sketch 2.0
# smartphones smartphone 77.0
# smileys smiley 1.0
# snacks snack 8.0
# sodas soda 1.0
# soeurs soeur 19.0
# soirées soirée 1.0
# solutions solution 15.0
# sommes somme 2.0
# sons son 2.0
# sopranos soprano 2.0
# sorties sortie 1.0
# souffre-douleurs souffre-douleur 3.0
# soupes soupe 1.0
# sous-fifres sous-fifre 1.0
# sous-marins sous-marin 8.0
# sous-produits sous-produit 1.0
# sous-titres sous-titre 61.0
# sous-vêtements sous-vêtement 11.0
# soviets soviet 1.0
# spams spam 44.0
# spiders spider 2.0
# spins spin 3.0
# spires spire 2.0
# spirituals spiritual 3.0
# sports sport 12.0
# spots spot 2.0
# standards standard 2.0
# stars star 18.0
# stations station 1.0
# steaks steak 8.0
# steppers stepper 5.0
# steps step 45.0
# sticks stick 9.0
# stores store 1.0
# strings string 2.0
# structures structure 1.0
# studios studio 6.0
# styles style 56.0
# substances substance 1.0
# suicides suicide 3.0
# suites suite 1.0
# superstars superstar 2.0
# sushis sushi 791.0
# sweepstakes sweepstake 1.0
# systèmes système 1.0
# séries série 1.0
# t-shirts t-shirt 7.0
# tables table 1.0
# tablettes tablette 1.0
# taches tache 1.0
# tacs tac 1.0
# tangos tango 1.0
# tanks tank 1.0
# tapettes tapette 1.0
# tapons tapon 1.0
# tatouages tatouage 2.0
# taxes taxe 2.0
# technologies technologie 12.0
# tenders tender 1.0
# terrasses terrasse 1.0
# terres terre 3.0
# textos texto 1300.0
# tibétains tibétain 1.0
# tiens tien 16.0
# tigres tigre 2.0
# tins tin 1.0
# tiques tique 1.0
# tires tire 8.0
# titres titre 1.0
# toasters toaster 2.0
# tocs toc 4.0
# toilettes toilette 3.0
# tomahawks tomahawk 1.0
# tombes tombe 1.0
# tops top 7.0
# tores tore 1.0
# tournois tournoi 22.0
# traces trace 2.0
# traders trader 3.0
# traducteurs traducteur 1.0
# traiteurs traiteur 1.0
# tramps tramp 7.0
# translations translation 3.0
# transplants transplant 1.0
# travelings traveling 1.0
# trentenaires trentenaire 5.0
# trials trial 3.0
# tricks trick 2.0
# trigrammes trigramme 2.0
# trips trip 1.0
# trolls troll 4.0
# trucks truck 10.0
# tunes tune 14.0
# téléconseillers téléconseiller 1.0
# tétons téton 1.0
# têtards têtard 2.0
# têtes tête 1.0
# unissons unisson 2.0
# vaccines vaccine 1.0
# valentins valentin 1.0
# valkyries valkyrie 4.0
# vampires vampire 2.0
# versions version 7.0
# vibrations vibration 3.0
# vidangeurs vidangeur 1.0
# vietnamiens vietnamien 2.0
# vins vin 2.0
# visions vision 3.0
# visites visite 1.0
# visons vison 1.0
# vitres vitre 2.0
# voiles voile 6.0
# voles vole 2.0
# volts volt 1.0
# voyages voyage 1.0
# vulcains vulcain 1.0
# watts watt 27.0
# week-ends week-end 3.0
# yards yard 11.0
# youpins youpin 72.0
# zarzuelas zarzuela 4.0
# zombies zombie 5.0
# élicitations élicitation 4.0
# épingles épingle 1.0
# éthiopiens éthiopien 3.0
# étoiles étoile 4.0
# êtas êta 1.0
# 138 780
# actinomètres, addicts, aidants, aides, aliens, altermondialistes, analystes, ancêtres, aveuglettes, baskets, bios, biostatistiques, blablas, blogs, bloomers, bogues, bottages, boursoufflures, braves, burqas, casses, cents, chines, clearings, colocataires, contracteurs, couples, cracs, crouilles, crêpes, disciples, divins, dribbleurs, droïdes, dyslexiques, déconnades, démos, encans, enchaînés, enchères, espars, extra-terrestres, fajitas, fans, fixes, flocs, folates, footballers, fors, goys, grinches, guides, gujaratis, hadjis, hardcores, holdings, hubs, infectiologues, insurgents, isomères, jockeys, kanas, kings, likes, lives, livres, macerons, macros, madrassas, mafiosos, manucures, mementos, milléniums, monos, mores, musts, mémérages, nanoparticules, neufs, ninjas, néos, outrepassements, ovoproduits, phtalates, pierrettes, pique-assiettes, plains, play-backs, plugins, pontes, portraits, postes, posts, prioritaires, pros, psychiatres, psychopathes, pétages, quantums, racers, raines, ramasses, raps, raveurs, reichsmarks, remonte-pentes, rems, rencarts, revivals, rockers, roses, rues, schizos, scratchs, selfies, shirts, shots, sigmas, smartphones, sommes, sopranos, souffre-douleurs, spams, spirituals, steps, sushis, tenders, textos, tournois, travelings, trentenaires, téléconseillers, unissons, vaccines, voiles, youpins, élicitations, êtas

# %%
fLexFilms4GB=fLexFilms4[:-4]+"-GB.csv"
df.to_csv(path_or_buf=fLexFilms4GB,sep="\t",encoding="utf8",index=False)

# %%
df=pd.read_csv(filepath_or_buffer=fLexFilms4GB,sep="\t",skip_blank_lines=True,encoding="utf8")
display(df.head())
condFormeNotLemme=df.graphie!=df.lemme
condLemmeNoSXZ=~df.lemme.str[-1].isin(["s","x","z"])
condN=df.cat=="NOM"
condA=df.cat=="ADJ"
condNA=df["cat"].isin(["NOM","ADJ"])
condNoNombreN=condN&(df.nombre.isnull())
condNoNombreA=condA&(df.nombre.isnull())
condNoNombreNA=condNA&(df["nombre"].isnull())
condGenreNombre=(df.genre.notnull())&(df.nombre.notnull())
# Out:
#   graphie lemme  cat infover genre nombre  occurrences
# 0       !     !  ADV     NaN   NaN    NaN         10.0
# 1       $     $  NOM     NaN     m    NaN      53370.0
# 2       $     $  NOM     NaN     m      p          1.0
# 3       %     %  NOM     NaN     m    NaN      29248.0
# 4       (     (  ADV     NaN   NaN    NaN          3.0

# %%
cumulerElements(condNoNombreN&~condFormeNotLemme&condLemmeNoSXZ,condN&condGenreNombre,"lemme")
# Out:
# $ $ 53370.0
# % % 29248.0
# 1er 1er 10.0
# 1re 1re 2.0
# 2e 2e 10.0
# 3e 3e 12.0
# 4e
# /Users/gilles/anaconda/lib/python2.7/site-packages/ipykernel_launcher.py:18: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
# 4e 8.0
# 4x4 4x4 15.0
# 5e 5e 1.0
# 6e 6e 3.0
# 7e 7e 4.0
# _ _ 4366.0
# a a 19905.0
# a priori a priori 104.0
# abaisse-langue abaisse-langue 25.0
# abat abat 1.0
# abat-jour abat-jour 112.0
# abat-vent abat-vent 3.0
# abattant abattant 1.0
# abc abc 37.0
# abdo abdo 65.0
# abimait abimait 1.0
# abime abime 79.0
# abiment abiment 13.0
# abimer abimer 105.0
# abimera abimera 7.0
# abimerai abimerai 2.0
# abimerait abimerait 2.0
# abimé abimé 190.0
# abimée abimée 85.0
# able able 4.0
# aboi aboi 1.0
# abracadabra abracadabra 4.0
# abri abri 1.0
# abriver abriver 1.0
# abrègerait abrègerait 3.0
# abrègeront abrègeront 1.0
# abrévier abrévier 1.0
# absolut absolut 9.0
# abu abu 19.0
# abusement abusement 1.0
# abusé abusé 1.0
# ac ac 1733.0
# académie académie 1.0
# accastilleur accastilleur 1.0
# acceptè acceptè 1.0
# accepté accepté 8.0
# acceptée acceptée 1.0
# accessoirisation accessoirisation 2.0
# accessoiriste accessoiriste 2.0
# accidentogène accidentogène 1.0
# accord accord 1.0
# accostement accostement 1.0
# accrobranche accrobranche 6.0
# accroche accroche 12.0
# accroche-coeur accroche-coeur 9.0
# accroissent accroissent 1.0
# accroit accroit 30.0
# accroitra accroitra 1.0
# accroitre accroitre 32.0
# accréditrice accréditrice 1.0
# accrû accrû 2.0
# accèdera accèdera 16.0
# accèderai accèderai 7.0
# accèderaient accèderaient 1.0
# accèderait accèderait 3.0
# accèderont accèderont 3.0
# accélèrera accélèrera 10.0
# accélèrerai accélèrerai 1.0
# accélèreraient accélèreraient 1.0
# accélèrerait accélèrerait 11.0
# accélèreront accélèreront 1.0
# ace ace 18.0
# achetè achetè 2.0
# achetée achetée 1.0
# achète achète 10.0
# aciclovir aciclovir 3.0
# acquitement acquitement 5.0
# acra acra 2.0
# acrotomophilie acrotomophilie 3.0
# acrylamide acrylamide 2.0
# acte acte 6.0
# acteur acteur 10.0
# acting acting 20.0
# action action 10.0
# activable activable 1.0
# active active 1.0
# actorat actorat 3.0
# actu actu 1.0
# acérola acérola 3.0
# acétaminophène acétaminophène 17.0
# acétylcystéine acétylcystéine 4.0
# ad ad 184.0
# adaptation adaptation 191.0
# add-on add-on 1.0
# addenda addenda 14.0
# addict addict 108.0
# addictif addictif 114.0
# addiction addiction 8.0
# addictive addictive 45.0
# addictologie addictologie 2.0
# addictologique addictologique 1.0
# addictologue addictologue 1.0
# adhèrera adhèrera 1.0
# adhèrerai adhèrerai 3.0
# adhèreraient adhèreraient 1.0
# adhèreront adhèreront 1.0
# adipose adipose 7.0
# adit adit 1.0
# adjoint adjoint 2.0
# adjudant-chef adjudant-chef 1.0
# adjudante adjudante 1.0
# admin admin 19.0
# administration administration 17.0
# admission admission 1.0
# ado ado 2.0
# adoption adoption 1.0
# adresse adresse 9.0
# adulescent adulescent 1.0
# adultèreront adultèreront 1.0
# affaire affaire 3.0
# affiche affiche 1.0
# affliction affliction 1.0
# affligement affligement 1.0
# affrété affrété 1.0
# affut affut 43.0
# affutage affutage 2.0
# affute affute 3.0
# affutent affutent 2.0
# affuter affuter 8.0
# affutera affutera 1.0
# affuterai affuterai 1.0
# affuteuse affuteuse 1.0
# affuté affuté 29.0
# affutée affutée 11.0
# afghano-pakistanaise afghano-pakistanaise 1.0
# aficionado aficionado 2.0
# afro-américain afro-américain 1.0
# afro-américaine afro-américaine 3.0
# afrobeat afrobeat 1.0
# afrocentrisme afrocentrisme 2.0
# after-shave after-shave 73.0
# aftershave aftershave 24.0
# ag ag 26.0
# agasse agasse 1.0
# age age 1.0
# agenda agenda 1.0
# agent agent 3.0
# aggravée aggravée 1.0
# agha agha 2.0
# agissant agissant 1.0
# agitation agitation 1.0
# agrandi agrandi 1.0
# agresseuse agresseuse 4.0
# agression agression 1.0
# agressive agressive 1.0
# agrocarburant agrocarburant 1.0
# agroécologie agroécologie 1.0
# agréement agréement 2.0
# agrégateur agrégateur 2.0
# ah ah 1.0
# ahan ahan 1.0
# ai ai 268.0
# aidant aidant 1.0
# aidante aidante 7.0
# aide aide 8.0
# aide-mémoire aide-mémoire 31.0
# aie aie 47.0
# aient aient 2.0
# aigüe aigüe 100.0
# aile aile 1.0
# ailière ailière 3.0
# aille aille 1.0
# aimè aimè 6.0
# ainesse ainesse 2.0
# ainé ainé 239.0
# ainée ainée 87.0
# air air 27.0
# ait ait 24.0
# aitre aitre 1.0
# ajoute ajoute 1.0
# akinétique akinétique 1.0
# albâtre albâtre 2.0
# alcool alcool 1.0
# aldicarbe aldicarbe 1.0
# ale ale 4.0
# aleph aleph 13.0
# alerte alerte 4.0
# algo algo 20.0
# algorithmie algorithmie 1.0
# alien alien 2181.0
# alkyde alkyde 1.0
# allant allant 1.0
# alleluia alleluia 14.0
# allemande allemande 1.0
# alliance alliance 2.0
# alligator alligator 1.0
# allodynie allodynie 1.0
# allonge allonge 3.0
# allotrope allotrope 3.0
# allume-feu allume-feu 15.0
# allègera allègera 9.0
# allègerai allègerai 2.0
# allègerait allègerait 2.0
# allègeront allègeront 3.0
# allélique allélique 3.0
# alm alm 1.0
# alpha alpha 1220.0
# alpiniste alpiniste 1.0
# alter alter 35.0
# alter ego alter ego 291.0
# altermondialiste altermondialiste 2.0
# alternaria alternaria 2.0
# alto alto 1.0
# altèrera altèrera 9.0
# altèrerait altèrerait 1.0
# altèreront altèreront 1.0
# alu alu 1.0
# alu alu 292.0
# aluminium aluminium 1.0
# am am 946.0
# amalgamée amalgamée 1.0
# amassage amassage 8.0
# amasseuse amasseuse 4.0
# amateure amateure 6.0
# ambigüe ambigüe 13.0
# ambigüité ambigüité 12.0
# ambulance ambulance 1.0
# amen amen 702.0
# amenage amenage 1.0
# ameutement ameutement 6.0
# amikacine amikacine 1.0
# amiral amiral 1.0
# amish amish 31.0
# amitriptyline amitriptyline 4.0
# ammonitrate ammonitrate 1.0
# amoncèlent amoncèlent 2.0
# amont amont 2.0
# amorcé amorcé 2.0
# amour amour 1.0
# amoxicilline amoxicilline 36.0
# amphibienne amphibienne 4.0
# amphète amphète 2.0
# ampliforme ampliforme 1.0
# ampèreheure ampèreheure 1.0
# amusant amusant 1.0
# amuse-bouche amuse-bouche 43.0
# amuse-gueule amuse-gueule 1.0
# amuse-gueule amuse-gueule 173.0
# amusement amusement 1.0
# amylasémie amylasémie 1.0
# amyotrophique amyotrophique 3.0
# amène amène 31.0
# américain américain 1.0
# américano-soviétique américano-soviétique 1.0
# an an 8.0
# ana ana 400.0
# anaconda anaconda 5.0
# analyse analyse 3.0
# anaphylactise anaphylactise 1.0
# anaphylactoïde anaphylactoïde 1.0
# anaplasique anaplasique 3.0
# andouillette andouillette 1.0
# angiosarcome angiosarcome 1.0
# angle angle 6.0
# anglo-russe anglo-russe 1.0
# anhydrase anhydrase 3.0
# anhédonie anhédonie 4.0
# aniline aniline 1.0
# animaliste animaliste 2.0
# animation animation 6.0
# animatique animatique 1.0
# animatronique animatronique 9.0
# anime anime 8.0
# anisakiase anisakiase 1.0
# annexe annexe 1.0
# annonce annonce 5.0
# annua annua 1.0
# annulateur annulateur 4.0
# annulement annulement 8.0
# anonymiser anonymiser 3.0
# anonymisé anonymisé 3.0
# anorectale anorectale 1.0
# antagonise antagonise 2.0
# anti-g anti-g 3.0
# anti-oxydant anti-oxydant 3.0
# anti-oxydante anti-oxydante 1.0
# anti-spam anti-spam 9.0
# anti-tabac anti-tabac 1.0
# antibiorésistante antibiorésistante 2.0
# antiboise antiboise 1.0
# antidépressif antidépressif 1.0
# antiqua antiqua 1.0
# antébrachiale antébrachiale 2.0
# antéro-postérieur antéro-postérieur 2.0
# anéchoïque anéchoïque 3.0
# aout aout 92.0
# août août 3127.0
# apnéiste apnéiste 1.0
# apocrine apocrine 1.0
# apoptotique apoptotique 1.0
# apparaitra apparaitra 58.0
# apparaitrai apparaitrai 3.0
# apparaitraient apparaitraient 2.0
# apparaitrait apparaitrait 22.0
# apparaitre apparaitre 251.0
# apparaitront apparaitront 13.0
# appart appart 1.0
# appeal appeal 10.0
# appelé appelé 3.0
# appendicectomie appendicectomie 1.0
# application application 1.0
# applique applique 2.0
# approche approche 5.0
# approximation approximation 1.0
# appuie-tête appuie-tête 22.0
# appâtage appâtage 1.0
# apriori apriori 2.0
# après-demain après-demain 2.0
# après-midi après-midi 15494.0
# aquaporine aquaporine 1.0
# arabo-musulmane arabo-musulmane 1.0
# arachidonique arachidonique 1.0
# arachnophobe arachnophobe 4.0
# arachnophobie arachnophobie 10.0
# arachnoïde arachnoïde 1.0
# aranéide aranéide 4.0
# arboretum arboretum 1.0
# arc-en-ciel arc-en-ciel 84.0
# archer archer 5.0
# architecture architecture 2.0
# argent argent 1612.0
# argh argh 36.0
# armada armada 2.0
# arme arme 4.0
# armurière armurière 2.0
# armée armée 6.0
# arnacher arnacher 2.0
# arnaché arnaché 1.0
# arnachée arnachée 1.0
# arnaque arnaque 5.0
# arnaqueur arnaqueur 1.0
# arpenteur arpenteur 1.0
# arrivant arrivant 2.0
# arrivè arrivè 22.0
# arrière-plan arrière-plan 2.0
# arsénopyrite arsénopyrite 1.0
# art art 16.0
# arthroscopique arthroscopique 5.0
# article article 1.0
# artériopathique artériopathique 2.0
# aryaniser aryaniser 1.0
# aryanisera aryanisera 1.0
# asap asap 8.0
# ashkenaze ashkenaze 2.0
# ashram ashram 1.0
# aspartate aspartate 3.0
# asperge asperge 1.0
# aspergillome aspergillome 2.0
# assaut assaut 1.0
# assemblée assemblée 1.0
# assertivité assertivité 1.0
# assistance assistance 1.0
# assistant assistant 61.0
# assit assit 1.0
# assiègeraient assiègeraient 1.0
# assiègeront assiègeront 3.0
# assoc assoc 15.0
# association association 33.0
# assoir assoir 1436.0
# assortissement assortissement 2.0
# assurance assurance 3.0
# assureuse assureuse 2.0
# assèchera assèchera 5.0
# assècherait assècherait 2.0
# assècheront assècheront 4.0
# asséchement asséchement 2.0
# aster aster 4.0
# asthmatiforme asthmatiforme 3.0
# astiquè astiquè 1.0
# astrobiologiste astrobiologiste 8.0
# astrocytome astrocytome 26.0
# astromobile astromobile 3.0
# astronaute astronaute 1.0
# athlé athlé 55.0
# atm atm 4.0
# atopique atopique 2.0
# atrioventriculaire atrioventriculaire 4.0
# attachage attachage 1.0
# attache attache 2.0
# attaque attaque 11.0
# atteint atteint 1.0
# attitude attitude 3.0
# attiéké attiéké 1.0
# attorney attorney 6.0
# attrape attrape 6.0
# attèle attèle 6.0
# au au 3.0
# au-delà au-delà 21.0
# au-delà au-delà 1159.0
# auberon auberon 1.0
# audimat audimat 313.0
# audioguide audioguide 1.0
# audiolivre audiolivre 1.0
# auditorium auditorium 6.0
# aujourd'hui aujourd'hui 224.0
# aura aura 17.0
# auraient auraient 1.0
# aurait aurait 5.0
# auteur auteur 1.0
# auteure auteure 1.0
# auto-immune auto-immune 1.0
# auto-stop auto-stop 1.0
# auto-école auto-école 1.0
# autoaccuser autoaccuser 1.0
# autoadministré autoadministré 1.0
# autoadministrée autoadministrée 1.0
# autocongratulant autocongratulant 2.0
# autocongratule autocongratule 1.0
# autocongratuler autocongratuler 1.0
# autoconsommer autoconsommer 1.0
# autodiscipliner autodiscipliner 1.0
# autoflageller autoflageller 5.0
# autogère autogère 1.0
# autojustifiée autojustifiée 1.0
# automation automation 1.0
# autoproduire autoproduire 1.0
# autopropulsent autopropulsent 1.0
# autopsie autopsie 1.0
# autoreproduire autoreproduire 1.0
# autoreproduit autoreproduit 1.0
# autorisation autorisation 1.0
# autosomal autosomal 1.0
# autosomale autosomale 1.0
# autostimuler autostimuler 1.0
# autosuffire autosuffire 1.0
# av av 134.0
# av. av. 1.0
# avaient avaient 5.0
# avait avait 14.0
# avalanche avalanche 1.0
# avalant avalant 1.0
# avale avale 8.0
# avance avance 6.0
# avant-dernier avant-dernier 1.0
# avant-garde avant-garde 2.0
# avant-gout avant-gout 15.0
# avant-hier avant-hier 1.0
# avant-midi avant-midi 17.0
# avant-poste avant-poste 4.0
# ave ave 7.0
# ave ave 724.0
# aventure aventure 4.0
# avenue avenue 85.0
# average average 5.0
# aveugle aveugle 10.0
# aveuglette aveuglette 12.0
# aviation aviation 5.0
# avionneuse avionneuse 1.0
# aviseur aviseur 1.0
# avocat avocat 4.0
# avr avr 4.0
# avril avril 3188.0
# avt avt 3.0
# avèrera avèrera 18.0
# avèreraient avèreraient 3.0
# avèrerait avèrerait 9.0
# avèreront avèreront 1.0
# avé avé 90.0
# award award 117.0
# axe axe 62.0
# axonal axonal 4.0
# axonale axonale 11.0
# ayahuasca ayahuasca 29.0
# aye aye 84.0
# ayurveda ayurveda 1.0
# ayurvéda ayurvéda 1.0
# ayé ayé 1.0
# azine azine 1.0
# azoth azoth 1.0
# azur azur 15.0
# aérobique aérobique 15.0
# aérodyne aérodyne 1.0
# aérofreinage aérofreinage 1.0
# aéroponie aéroponie 1.0
# aéroporter aéroporter 4.0
# aéroporté aéroporté 4.0
# aéroportée aéroportée 14.0
# aérosolisé aérosolisé 1.0
# aï aï 13.0
# b b 16746.0
# babine babine 1.0
# baby baby 46.0
# baby-foot baby-foot 160.0
# baby-sitter baby-sitter 2.0
# babyfoot babyfoot 30.0
# babysitteur babysitteur 37.0
# babysitteuse babysitteuse 6.0
# babysitting babysitting 263.0
# bac bac 8.0
# bachelor bachelor 38.0
# bacitracine bacitracine 9.0
# backdoor backdoor 24.0
# backup backup 28.0
# bactériémique bactériémique 2.0
# badge badge 5.0
# badminton badminton 1.0
# bafouille bafouille 1.0
# bafouillement bafouillement 3.0
# bagel bagel 527.0
# baggy baggy 45.0
# bagnarde bagnarde 5.0
# baguel baguel 2.0
# bahamien bahamien 4.0
# bahamienne bahamienne 2.0
# baht baht 1.0
# baignade baignade 1.0
# bain-marie bain-marie 1.0
# baisage baisage 6.0
# baise baise 17.0
# baiseur baiseur 3.0
# baissage baissage 2.0
# baissante baissante 2.0
# baisé baisé 1.0
# balado balado 3.0
# baladodiffusion baladodiffusion 1.0
# balalaïka balalaïka 3.0
# balancé balancé 1.0
# balayette balayette 2.0
# baleine baleine 3.0
# balise balise 4.0
# ball-trap ball-trap 1.0
# ballet ballet 9.0
# ballotage ballotage 1.0
# ballotent ballotent 2.0
# balloter balloter 2.0
# ballotine ballotine 2.0
# ballottè ballottè 1.0
# balloté balloté 9.0
# ballotée ballotée 5.0
# ballè ballè 1.0
# baltringue baltringue 66.0
# ban ban 4.0
# banane banane 9.0
# banche banche 3.0
# bandant bandant 1.0
# bande bande 3.0
# bande-annonce bande-annonce 3.0
# bande-son bande-son 1.0
# banjo banjo 1.0
# bankster bankster 1.0
# banon banon 2.0
# banque banque 14.0
# banquet banquet 2.0
# banquette banquette 1.0
# banquier banquier 1.0
# baque baque 4.0
# baquer baquer 3.0
# baqué baqué 1.0
# bar-mitzvah bar-mitzvah 48.0
# baraka baraka 2.0
# baraqué baraqué 1.0
# barbecue barbecue 9.0
# barbie barbie 45.0
# barda barda 2.0
# bariatrique bariatrique 2.0
# barista barista 60.0
# barmitsva barmitsva 2.0
# barn barn 89.0
# baroudage baroudage 1.0
# barracuda barracuda 6.0
# barrel barrel 53.0
# barrio barrio 51.0
# bas-culotte bas-culotte 1.0
# base base 27.0
# base-ball base-ball 32.0
# baseball baseball 16.0
# baseballeur baseballeur 17.0
# baseline baseline 2.0
# basket basket 1.0
# basket-ball basket-ball 1.0
# basketball basketball 405.0
# basocellulaire basocellulaire 1.0
# basse-cour basse-cour 2.0
# bassecour bassecour 2.0
# bassidji bassidji 3.0
# bassiste bassiste 1.0
# battant battant 1.0
# batte batte 2.0
# batteur batteur 1.0
# bau bau 5.0
# bavante bavante 1.0
# bavement bavement 2.0
# baxter baxter 1.0
# bay bay 46.0
# bayou bayou 7.0
# bazooka bazooka 2.0
# bazou bazou 17.0
# baîlle baîlle 2.0
# baîllonner baîllonner 1.0
# baîllonné baîllonné 1.0
# bcp bcp 19.0
# bd bd 87.0
# be be 4569.0
# be-bop be-bop 6.0
# be-bop be-bop 51.0
# beach-volley beach-volley 1.0
# beachvolley beachvolley 1.0
# beauferie beauferie 1.0
# beaufitude beaufitude 1.0
# bebop bebop 7.0
# because because 1.0
# beefsteak beefsteak 4.0
# belladonne belladonne 1.0
# belle-fille belle-fille 1.0
# belle-soeur belle-soeur 8.0
# benchmarking benchmarking 1.0
# bene bene 74.0
# bento bento 26.0
# benzaldéhyde benzaldéhyde 2.0
# benzalkonium benzalkonium 1.0
# benzopyrène benzopyrène 1.0
# ber ber 3.0
# berimbau berimbau 2.0
# berlingot berlingot 1.0
# bernache bernache 1.0
# bernacle bernacle 1.0
# bernard-l'ermite bernard-l'ermite 13.0
# besant besant 6.0
# best-seller best-seller 5.0
# bestseller bestseller 39.0
# bey bey 27.0
# bibendum bibendum 1.0
# bibl bibl 5.0
# bible bible 1.0
# bibli bibli 35.0
# biblio biblio 67.0
# bicarbonate bicarbonate 2.0
# bidé bidé 2.0
# bien-pensance bien-pensance 2.0
# bien-être bien-être 1678.0
# bienaimée bienaimée 3.0
# bienfondé bienfondé 1.0
# bienêtre bienêtre 5.0
# bifurcation bifurcation 1.0
# big-bang big-bang 46.0
# bihari bihari 2.0
# biker biker 63.0
# bikeuse bikeuse 5.0
# bile bile 1.0
# billa billa 1.0
# bimbo bimbo 264.0
# binard binard 1.0
# bindi bindi 13.0
# bingo bingo 12.0
# binouze binouze 25.0
# biodiésel biodiésel 1.0
# biodynamie biodynamie 2.0
# biofeedback biofeedback 7.0
# biofilm biofilm 14.0
# bioinformaticien bioinformaticien 3.0
# bioinformaticienne bioinformaticienne 2.0
# biolubrifiant biolubrifiant 1.0
# biomagnification biomagnification 2.0
# biomimétisme biomimétisme 1.0
# biopic biopic 26.0
# biopiratage biopiratage 1.0
# biopolymère biopolymère 3.0
# biopsier biopsier 14.0
# biopsiera biopsiera 1.0
# biopsié biopsié 5.0
# bioréacteur bioréacteur 6.0
# biostase biostase 1.0
# biostimulant biostimulant 2.0
# biotech biotech 23.0
# biotechno biotechno 2.0
# bioterroriste bioterroriste 20.0
# bioéthique bioéthique 1.0
# biplane biplane 1.0
# bippait bippait 1.0
# bippant bippant 1.0
# bippe bippe 54.0
# bippent bippent 5.0
# bipper bipper 96.0
# bippé bippé 51.0
# bippée bippée 9.0
# bique bique 1.0
# birdie birdie 51.0
# bisbille bisbille 1.0
# biscuit biscuit 4.0
# bison bison 3.0
# bisou bisou 1.0
# bissel bissel 2.0
# bissextil bissextil 1.0
# bissexuel bissexuel 6.0
# bistro bistro 6.0
# bitcoin bitcoin 48.0
# bite bite 26.0
# bizarre bizarre 1.0
# bizut bizut 1.0
# bière bière 1.0
# bla-bla bla-bla 2.0
# bla-bla bla-bla 272.0
# bla-bla-bla bla-bla-bla 154.0
# blabla blabla 550.0
# blablabla blablabla 302.0
# blablatage blablatage 2.0
# black-out black-out 1.0
# black-out black-out 237.0
# blackjack blackjack 222.0
# blackliste blackliste 1.0
# blacklister blacklister 4.0
# blacklisté blacklisté 22.0
# blacklistée blacklistée 4.0
# blackout blackout 154.0
# blanc-bec blanc-bec 1.0
# blanchon blanchon 1.0
# blaster blaster 48.0
# blastocyste blastocyste 2.0
# blastée blastée 1.0
# blazer blazer 4.0
# blender blender 36.0
# blessè blessè 1.0
# blinde blinde 1.0
# bling-bling bling-bling 51.0
# blini blini 1.0
# blitzkrieg blitzkrieg 3.0
# blizzard blizzard 5.0
# blob blob 10.0
# blockbuster blockbuster 44.0
# blog blog 1599.0
# blogosphère blogosphère 28.0
# bloguait bloguait 1.0
# blogue blogue 68.0
# bloguent bloguent 7.0
# bloguer bloguer 17.0
# blogueur blogueur 97.0
# blogueuse blogueuse 54.0
# blogué blogué 8.0
# blond blond 24.0
# bloomer bloomer 4.0
# bloquage bloquage 12.0
# bloquant bloquant 1.0
# bloquè bloquè 1.0
# bluetooth bluetooth 48.0
# bluff bluff 7.0
# bluffante bluffante 7.0
# blush blush 2.0
# blépharospasme blépharospasme 1.0
# boa boa 1.0
# board board 64.0
# boat boat 88.0
# boat-people boat-people 1.0
# bobologie bobologie 2.0
# bodega bodega 3.0
# body body 12.0
# bodéga bodéga 1.0
# boeuf boeuf 8.0
# boggie boggie 11.0
# bogie bogie 3.0
# boiler boiler 3.0
# boit-sans-soif boit-sans-soif 4.0
# boite boite 73.0
# boitier boitier 80.0
# bol bol 1.0
# bolchévik bolchévik 1.0
# bolchévique bolchévique 22.0
# bolchévisme bolchévisme 5.0
# bolchéviste bolchéviste 2.0
# bolduc bolduc 4.0
# bolivar bolivar 5.0
# bolivarienne bolivarienne 1.0
# bollywoodien bollywoodien 2.0
# bollywoodienne bollywoodienne 2.0
# bombarde bombarde 3.0
# bombe bombe 5.0
# bombé bombé 7.0
# bonbec bonbec 26.0
# bondage bondage 1.0
# bonjour bonjour 4.0
# boogie boogie 198.0
# book book 26.0
# bookmakeur bookmakeur 1.0
# boom boom 21.0
# boomer boomer 18.0
# boomerang boomerang 4.0
# boot boot 30.0
# bop bop 5.0
# bordel bordel 1.0
# borin borin 1.0
# borne borne 2.0
# borough borough 15.0
# bort bort 1.0
# boré boré 1.0
# bossanova bossanova 1.0
# botnet botnet 13.0
# botoxé botoxé 3.0
# botoxée botoxée 3.0
# bottage bottage 52.0
# botte botte 1.0
# botteur botteur 1.0
# botteuse botteuse 11.0
# bottier bottier 1.0
# bouche bouche 7.0
# bouche-à-bouche bouche-à-bouche 222.0
# boucle boucle 7.0
# bouge bouge 17.0
# bougeote bougeote 1.0
# bouh bouh 66.0
# bouillonnant bouillonnant 1.0
# boulette boulette 1.0
# boulevard boulevard 6.0
# boulghour boulghour 1.0
# boulier boulier 1.0
# boulonneuse boulonneuse 1.0
# boulote boulote 1.0
# bourgmestre bourgmestre 1.0
# bourrache bourrache 2.0
# bourre bourre 2.0
# bourricot bourricot 5.0
# bourrique bourrique 1.0
# boursoufflé boursoufflé 4.0
# boursoufflée boursoufflée 2.0
# bouse bouse 1.0
# bout bout 16.0
# boute-en-train boute-en-train 119.0
# boutentrain boutentrain 1.0
# boutique boutique 11.0
# boutisme boutisme 1.0
# bouton bouton 1.0
# boutonnier boutonnier 2.0
# bouvet bouvet 3.0
# bouzin bouzin 4.0
# bouzouki bouzouki 2.0
# bowling bowling 9.0
# box-office box-office 2.0
# boxe boxe 1.0
# boxeuse boxeuse 4.0
# boy boy 151.0
# boyscout boyscout 18.0
# brachydactylie brachydactylie 1.0
# bran bran 7.0
# branche branche 1.0
# branchitude branchitude 4.0
# brandy brandy 2.0
# branlage branlage 5.0
# branle branle 1.0
# branlette branlette 1.0
# branleur branleur 2.0
# branquignole branquignole 4.0
# brassage brassage 1.0
# brasse brasse 1.0
# braséro braséro 6.0
# brave brave 13.0
# break break 12.0
# breakdance breakdance 5.0
# breakfast breakfast 40.0
# breffage breffage 2.0
# bren bren 2.0
# brevète brevète 1.0
# bric bric 24.0
# bric-à-brac bric-à-brac 125.0
# brick brick 17.0
# bricole bricole 1.0
# bricolo bricolo 2.0
# bride bride 78.0
# bridge bridge 338.0
# brigade brigade 17.0
# brigadeiro brigadeiro 1.0
# brigadière brigadière 3.0
# brillant brillant 1.0
# bringue bringue 1.0
# brisage brisage 3.0
# brise brise 17.0
# brise-fer brise-fer 9.0
# brise-glace brise-glace 56.0
# brise-jet brise-jet 1.0
# brise-soleil brise-soleil 1.0
# brise-tout brise-tout 6.0
# brise-vent brise-vent 3.0
# brisé brisé 1.0
# brochant brochant 1.0
# brocoli brocoli 3.0
# brodage brodage 1.0
# brodeur brodeur 2.0
# broker broker 2.0
# bronchodilatateur bronchodilatateur 8.0
# bronchopulmonaire bronchopulmonaire 1.0
# bronzage bronzage 3.0
# bronze bronze 3.0
# bronzette bronzette 1.0
# brosseuse brosseuse 1.0
# brouilleuse brouilleuse 1.0
# broussard broussard 1.0
# brownie brownie 268.0
# brula brula 5.0
# brulage brulage 4.0
# brulaient brulaient 13.0
# brulait brulait 43.0
# brulant brulant 108.0
# brulante brulante 31.0
# brule brule 308.0
# brulent brulent 53.0
# bruler bruler 408.0
# brulera brulera 43.0
# brulerai brulerai 14.0
# bruleraient bruleraient 1.0
# brulerait brulerait 10.0
# bruleront bruleront 14.0
# bruleur bruleur 5.0
# brulure brulure 72.0
# brulèrent brulèrent 3.0
# brulé brulé 594.0
# brulée brulée 196.0
# brume brume 1.0
# brumiser brumiser 1.0
# brunch brunch 7.0
# brunchant brunchant 1.0
# brunche brunche 7.0
# brunchent brunchent 1.0
# bruncher bruncher 77.0
# brunchera brunchera 1.0
# brunché brunché 5.0
# brusque brusque 2.0
# brutalisation brutalisation 3.0
# bruxisme bruxisme 10.0
# brûlant brûlant 2.0
# brûle-parfum brûle-parfum 5.0
# bu bu 1.0
# buche buche 33.0
# bucher bucher 15.0
# bucheron bucheron 31.0
# bucheur bucheur 2.0
# bucheuse bucheuse 1.0
# buché buché 5.0
# buffalo buffalo 9.0
# bug bug 13.0
# buggy buggy 7.0
# buggé buggé 23.0
# buggée buggée 1.0
# bugle bugle 23.0
# buguent buguent 2.0
# buguer buguer 3.0
# buguera buguera 1.0
# buguerait buguerait 1.0
# bugué bugué 13.0
# build build 74.0
# building building 60.0
# bulldog bulldog 3.0
# bulldozer bulldozer 1.0
# bungalow bungalow 2.0
# bunker bunker 13.0
# bunsen bunsen 20.0
# buprénorphine buprénorphine 7.0
# burka burka 46.0
# burkinabè burkinabè 1.0
# burkini burkini 2.0
# burn-out burn-out 30.0
# burne burne 3.0
# burnout burnout 25.0
# burqa burqa 31.0
# burrata burrata 11.0
# burrito burrito 594.0
# bushido bushido 1.0
# businessman businessman 2.0
# buteuse buteuse 2.0
# butte butte 16.0
# buté buté 1.0
# buzza buzza 1.0
# buzzant buzzant 2.0
# buzze buzze 7.0
# buzzent buzzent 3.0
# buzzer buzzer 2.0
# buzzer buzzer 197.0
# buzzera buzzera 1.0
# buzzé buzzé 17.0
# bye bye 6.0
# byebye byebye 2.0
# bâclè bâclè 1.0
# bâtiment bâtiment 2.0
# bécarre bécarre 1.0
# bédéiste bédéiste 2.0
# bégale bégale 1.0
# béni-oui-oui béni-oui-oui 39.0
# bénit bénit 1.0
# bénéf bénéf 9.0
# bétaïne bétaïne 3.0
# bêbête bêbête 13.0
# bêta-test bêta-test 1.0
# bêtification bêtification 1.0
# bô bô 7.0
# c c 2629.0
# c c 6092.0
# cab cab 17.0
# caballero caballero 7.0
# cabernet cabernet 5.0
# cabri cabri 1.0
# cachaça cachaça 24.0
# cache cache 3.0
# cache-cache cache-cache 942.0
# cache-col cache-col 6.0
# cache-flamme cache-flamme 1.0
# cache-misère cache-misère 5.0
# cache-poussière cache-poussière 6.0
# cache-sexe cache-sexe 24.0
# cache-tampon cache-tampon 2.0
# cachecache cachecache 1.0
# cacheton cacheton 1.0
# cachoterie cachoterie 2.0
# cachotier cachotier 26.0
# cachotière cachotière 16.0
# cachète cachète 8.0
# cachètent cachètent 1.0
# caché caché 1.0
# cacou cacou 1.0
# cadenassage cadenassage 1.0
# cadence cadence 1.0
# cadogan cadogan 3.0
# cador cador 3.0
# cadreur cadreur 1.0
# cafeteria cafeteria 1.0
# cafette cafette 4.0
# cafète cafète 30.0
# caféiné caféiné 18.0
# caféinée caféinée 5.0
# cage cage 2.0
# cagole cagole 2.0
# cahotique cahotique 11.0
# caille caille 2.0
# cairn cairn 6.0
# cake cake 14.0
# cal cal 2.0
# calamine calamine 4.0
# calcitriol calcitriol 1.0
# caleur caleur 2.0
# calf calf 15.0
# call call 504.0
# call-girl call-girl 1.0
# calla calla 1.0
# callgirl callgirl 5.0
# calligraphie calligraphie 2.0
# calme calme 13.0
# calo calo 3.0
# calopsitte calopsitte 2.0
# calumet calumet 1.0
# calzone calzone 77.0
# camarade camarade 1.0
# cambriole cambriole 1.0
# cambrioleur cambrioleur 1.0
# came came 15.0
# cameraman cameraman 1.0
# camerlingue camerlingue 1.0
# camionnage camionnage 4.0
# camionneur camionneur 1.0
# camionneuse camionneuse 29.0
# camouflante camouflante 1.0
# camouflement camouflement 1.0
# camp camp 7.0
# campanile campanile 1.0
# camping-caravaning camping-caravaning 1.0
# campo campo 17.0
# camée camée 1.0
# caméra caméra 2.0
# caméraman caméraman 5.0
# canal canal 7.0
# canalaire canalaire 6.0
# canardage canardage 4.0
# cancanement cancanement 1.0
# candidater candidater 14.0
# candidaté candidaté 9.0
# cane cane 55.0
# canine canine 1.0
# canne canne 10.0
# canoé canoé 20.0
# canoë-kayak canoë-kayak 1.0
# canter canter 18.0
# canto-pop canto-pop 1.0
# canyon canyon 90.0
# canyoning canyoning 3.0
# cap cap 2.0
# cape cape 47.0
# capella capella 5.0
# capillotracté capillotracté 1.0
# capital capital 1.0
# capoeira capoeira 68.0
# caporal caporal 3.0
# caporale caporale 11.0
# capot capot 13.0
# cappa cappa 2.0
# cappella cappella 10.0
# cappuccino cappuccino 5.0
# capron capron 1.0
# capsaïcine capsaïcine 6.0
# capsicum capsicum 11.0
# capsule capsule 2.0
# capture capture 3.0
# capturé capturé 2.0
# caquète caquète 5.0
# caquètent caquètent 7.0
# caquèterait caquèterait 1.0
# car-jacking car-jacking 42.0
# caravaning caravaning 1.0
# carbonara carbonara 71.0
# cardamone cardamone 6.0
# cardigan cardigan 41.0
# cardio cardio 489.0
# cardiofréquencemètre cardiofréquencemètre 1.0
# cardiogénique cardiogénique 24.0
# cardiopulmonaire cardiopulmonaire 11.0
# cardiotoxique cardiotoxique 2.0
# cardiotraining cardiotraining 1.0
# cardère cardère 1.0
# caressant caressant 2.0
# caresse caresse 5.0
# cargo cargo 3.0
# carjacking carjacking 72.0
# carlin carlin 9.0
# carnage carnage 3.0
# carne carne 7.0
# carnisme carnisme 5.0
# carre carre 3.0
# carreauté carreauté 1.0
# carreautée carreautée 1.0
# carrement carrement 47.0
# carry carry 8.0
# carré carré 1.0
# cart cart 20.0
# carte carte 3.0
# cartel cartel 2.0
# cartomancie cartomancie 1.0
# cartoon cartoon 3.0
# cartoucher cartoucher 1.0
# cascade cascade 7.0
# case case 87.0
# cash cash 334.0
# casino casino 21.0
# cassave cassave 1.0
# casse-cou casse-cou 150.0
# casse-croute casse-croute 33.0
# casse-croûte casse-croûte 335.0
# casse-cul casse-cul 1.0
# casse-dalle casse-dalle 45.0
# casse-graine casse-graine 7.0
# casse-gueule casse-gueule 1.0
# casse-gueule casse-gueule 8.0
# casse-pipe casse-pipe 1.0
# casse-tout casse-tout 1.0
# casse-tête casse-tête 394.0
# casse-vitesse casse-vitesse 11.0
# cassè cassè 1.0
# castine castine 1.0
# casting casting 3.0
# castrat castrat 1.0
# castratrice castratrice 1.0
# casus belli casus belli 9.0
# catamaran catamaran 4.0
# catch catch 9.0
# cathéter cathéter 1.0
# cathétérisation cathétérisation 8.0
# cathétérise cathétérise 1.0
# cathétériser cathétériser 9.0
# cathétérisé cathétérisé 1.0
# catimini catimini 3.0
# catiner catiner 2.0
# cause cause 98.0
# caution caution 2.0
# cave cave 5.0
# cavet cavet 1.0
# cavite cavite 2.0
# caïman caïman 5.0
# caïpirinha caïpirinha 2.0
# cañon cañon 1.0
# cd cd 136.0
# cella cella 2.0
# celle-ci celle-ci 1.0
# celle-là celle-là 1.0
# celles-ci celles-ci 1.0
# cellophané cellophané 1.0
# cellular cellular 5.0
# celui-ci celui-ci 1.0
# celui-là celui-là 7.0
# censuré censuré 8.0
# cent cent 3050.0
# cent-millionième cent-millionième 2.0
# centa centa 1.0
# cente cente 4.0
# center center 79.0
# central central 85.0
# centre-ville centre-ville 12.0
# centurion centurion 1.0
# cercle cercle 2.0
# cerf-volant cerf-volant 2.0
# cerveau cerveau 22490.0
# cesse cesse 1.0
# cessez-le-feu cessez-le-feu 2.0
# cessez-le-feu cessez-le-feu 370.0
# cessè cessè 1.0
# cetera cetera 1.0
# ceux-là ceux-là 1.0
# ceviche ceviche 21.0
# ch ch 134.0
# chachacha chachacha 1.0
# chadouf chadouf 1.0
# chaebol chaebol 14.0
# chagrin chagrin 2.0
# chahut chahut 2.0
# chahutage chahutage 6.0
# chai chai 9.0
# chaine chaine 1019.0
# chainette chainette 1.0
# chainon chainon 5.0
# chainée chainée 1.0
# chakra chakra 107.0
# challenge challenge 27.0
# chaloupage chaloupage 1.0
# chamaille chamaille 1.0
# chaman chaman 1.0
# chambard chambard 2.0
# chambrage chambrage 2.0
# chambre chambre 6.0
# chameau chameau 1.0
# champignon champignon 1.0
# chancèle chancèle 9.0
# change change 18.0
# changè changè 10.0
# chant chant 1.0
# chantant chantant 3.0
# chanterelle chanterelle 1.0
# chanteur chanteur 1.0
# chantè chantè 2.0
# chap chap 22.0
# chapelle chapelle 18.0
# chapitre chapitre 13.0
# chaque chaque 5.0
# charcle charcle 1.0
# charcler charcler 5.0
# chardonnay chardonnay 2.0
# charge charge 12.0
# chargeur chargeur 1.0
# charlata charlata 1.0
# charlatant charlatant 10.0
# charlatent charlatent 1.0
# charmant charmant 164.0
# charognarde charognarde 7.0
# charretier charretier 3.0
# charriot charriot 100.0
# chasse chasse 20.0
# chasse-neige chasse-neige 2.0
# chasse-neige chasse-neige 133.0
# chat chat 1.0
# chaton chaton 1.0
# chatouille chatouille 2.0
# chatte chatte 5.0
# chatteur chatteur 1.0
# chatteuse chatteuse 1.0
# chaudasse chaudasse 187.0
# chauffe-eau chauffe-eau 224.0
# chauffement chauffement 1.0
# chausse chausse 1.0
# chausseuse chausseuse 1.0
# chaîne chaîne 3.0
# check-point check-point 15.0
# check-up check-up 224.0
# checklist checklist 22.0
# checkup checkup 28.0
# cheddar cheddar 1.0
# cheeseburger cheeseburger 6.0
# cheesecake cheesecake 155.0
# chef chef 2.0
# chef-d'oeuvre chef-d'oeuvre 1.0
# cheffe cheffe 50.0
# cheloue cheloue 6.0
# cheminot cheminot 2.0
# cheminée cheminée 1.0
# chemise chemise 3.0
# chenillard chenillard 1.0
# cherche cherche 32.0
# cherchè cherchè 4.0
# cherra cherra 2.0
# chevau chevau 1.0
# chevauchage chevauchage 1.0
# chevaucheuse chevaucheuse 6.0
# chevillard chevillard 1.0
# chevillère chevillère 1.0
# chewing-gum chewing-gum 11.0
# cheyenne cheyenne 2.0
# chez-moi chez-moi 1.0
# chez-soi chez-soi 146.0
# chia chia 6.0
# chialage chialage 1.0
# chichon chichon 10.0
# chicon chicon 2.0
# chien-loup chien-loup 2.0
# chienne chienne 1.0
# chieur chieur 1.0
# chiffonnade chiffonnade 3.0
# chikungunya chikungunya 2.0
# chime chime 5.0
# chimio chimio 1361.0
# chimiotaxie chimiotaxie 1.0
# chimiothérapeutique chimiothérapeutique 2.0
# chimérisme chimérisme 2.0
# chinchard chinchard 1.0
# chinook chinook 2.0
# chipiron chipiron 2.0
# chiquette chiquette 1.0
# chiropractrice chiropractrice 7.0
# chiropraticien chiropraticien 1.0
# chirurgien-dentiste chirurgien-dentiste 1.0
# chitinase chitinase 2.0
# chlamydiose chlamydiose 29.0
# chleu chleu 2.0
# chloroforme chloroforme 1.0
# chlorométhane chlorométhane 3.0
# chocolate chocolate 67.0
# chocotte chocotte 5.0
# choeur choeur 4.0
# cholangite cholangite 5.0
# cholestéatome cholestéatome 1.0
# chopage chopage 2.0
# choppe choppe 1.0
# chorioméningite chorioméningite 1.0
# chorégraphe chorégraphe 1.0
# chorégraphie chorégraphie 1.0
# chott chott 2.0
# chou chou 3.0
# chou-fleur chou-fleur 1.0
# chouineur chouineur 6.0
# chouineuse chouineuse 4.0
# choupinet choupinet 19.0
# choupinette choupinette 34.0
# chow chow 81.0
# chrome chrome 4.0
# chronotrope chronotrope 1.0
# chti chti 3.0
# chuchotant chuchotant 2.0
# chum chum 1.0
# chunk chunk 2.0
# chunky chunky 6.0
# chut chut 2.0
# chute chute 4.0
# chutney chutney 2.0
# chèvrerie chèvrerie 1.0
# chélaté chélaté 1.0
# chérimole chérimole 1.0
# chérimolier chérimolier 2.0
# ci ci 57.0
# ci-devant ci-devant 11.0
# ci-git ci-git 2.0
# ci-joint ci-joint 1.0
# ciabatta ciabatta 17.0
# cicadelle cicadelle 9.0
# cichlidé cichlidé 1.0
# cigarette cigarette 1.0
# cigüe cigüe 10.0
# cimetière cimetière 1.0
# cimétidine cimétidine 5.0
# cingulaire cingulaire 23.0
# cinq cinq 6817.0
# cinquante cinquante 563.0
# cinégénique cinégénique 1.0
# cinéma cinéma 1.0
# cinématographie cinématographie 1.0
# cirage cirage 1.0
# circ circ 1.0
# circonciseur circonciseur 16.0
# circuitant circuitant 1.0
# circuiter circuiter 3.0
# circuité circuité 5.0
# circumnavigatrice circumnavigatrice 2.0
# cisailleur cisailleur 1.0
# cisplatine cisplatine 2.0
# civil civil 3.0
# civilisationnelle civilisationnelle 1.0
# cl cl 90.0
# clairage clairage 3.0
# clairvoyant clairvoyant 1.0
# clam clam 10.0
# clamp clamp 13.0
# clan clan 10.0
# clap clap 1.0
# claque claque 3.0
# claquette claquette 1.0
# clash clash 6.0
# clashe clashe 1.0
# clasher clasher 5.0
# clashé clashé 6.0
# classe classe 52.0
# classifieur classifieur 3.0
# classifié classifié 1.0
# claustro claustro 61.0
# clavardage clavardage 4.0
# clavardé clavardé 1.0
# claviériste claviériste 1.0
# claymore claymore 13.0
# clean clean 1.0
# clearing clearing 5.0
# clef clef 1.0
# clic clic 38.0
# cliche cliche 1.0
# click click 2.0
# cliffhanger cliffhanger 10.0
# cligno cligno 6.0
# clim clim 468.0
# clinquement clinquement 1.0
# clippant clippant 1.0
# clippe clippe 1.0
# clippent clippent 1.0
# clipper clipper 5.0
# clippeur clippeur 1.0
# clippé clippé 10.0
# clippée clippée 9.0
# clipse clipse 5.0
# clipsent clipsent 1.0
# clipser clipser 4.0
# clipsé clipsé 2.0
# clique clique 1.0
# cliquement cliquement 4.0
# cliquotent cliquotent 1.0
# cliquète cliquète 4.0
# cliquètent cliquètent 6.0
# clito clito 2.0
# clivante clivante 1.0
# clm clm 2.0
# clochard clochard 1.0
# clodo clodo 1.0
# cloisonnette cloisonnette 1.0
# cloitre cloitre 4.0
# cloitrer cloitrer 2.0
# cloitré cloitré 18.0
# cloitrée cloitrée 14.0
# clomiphène clomiphène 2.0
# clonazépam clonazépam 18.0
# clone clone 26.0
# clonidine clonidine 14.0
# clopinette clopinette 1.0
# cloque cloque 2.0
# closet closet 16.0
# closing closing 19.0
# cloutier cloutier 7.0
# club club 134.0
# clubber clubber 13.0
# clubbeur clubbeur 1.0
# clubbeuse clubbeuse 2.0
# clubbing clubbing 7.0
# clubhouse clubhouse 2.0
# cluster cluster 8.0
# cm cm 5.0
# cm cm 3831.0
# coach coach 3.0
# coaching coaching 102.0
# coagulopathie coagulopathie 20.0
# coanimatrice coanimatrice 3.0
# coat coat 38.0
# coauteur coauteur 4.0
# coauteure coauteure 2.0
# cobra cobra 15.0
# cocci cocci 7.0
# coccinelle coccinelle 3.0
# cochampion cochampion 1.0
# coche coche 1.0
# cockney cockney 1.0
# cocréateur cocréateur 3.0
# coda coda 2.0
# code code 106.0
# codec codec 9.0
# codet codet 5.0
# codirecteur codirecteur 1.0
# codéine codéine 1.0
# coffin coffin 24.0
# coffre coffre 1.0
# coffre-fort coffre-fort 1.0
# cogneur cogneur 3.0
# cohomologie cohomologie 1.0
# coiffe coiffe 2.0
# coincidaient coincidaient 1.0
# coincidait coincidait 4.0
# coincidant coincidant 1.0
# coincide coincide 31.0
# coincident coincident 14.0
# coincider coincider 13.0
# coincidera coincidera 1.0
# coincideraient coincideraient 1.0
# coincideront coincideront 1.0
# coincidé coincidé 1.0
# coincoin coincoin 4.0
# colauréate colauréate 1.0
# colbac colbac 2.0
# coleslaw coleslaw 31.0
# colinot colinot 1.0
# coll coll 3.0
# collant collant 1.0
# collection collection 1.0
# collectionneur collectionneur 2.0
# collective collective 2.0
# collector collector 2.0
# colletailler colletailler 1.0
# colley colley 11.0
# collier collier 2.0
# collision collision 1.0
# collisionneur collisionneur 6.0
# collusion collusion 1.0
# collège collège 1.0
# colo colo 2.0
# coloc coloc 1503.0
# colonel colonel 1.0
# coloration coloration 1.0
# coloriste coloriste 1.0
# coltan coltan 51.0
# comatait comatait 2.0
# comate comate 11.0
# comatent comatent 2.0
# comater comater 8.0
# comaté comaté 18.0
# combat combat 17.0
# combattivité combattivité 1.0
# combava combava 2.0
# combine combine 1.0
# combo combo 3.0
# combustion combustion 3.0
# come-back come-back 219.0
# comeback comeback 98.0
# coming-out coming-out 277.0
# commandant commandant 371.0
# commande commande 3.0
# commanditée commanditée 1.0
# commencè commencè 7.0
# comment comment 5.0
# commentateur commentateur 3.0
# commerce commerce 7.0
# commercial commercial 1.0
# commission commission 1.0
# commit commit 1.0
# commité commité 40.0
# commodore commodore 1.0
# commotion commotion 1.0
# communication communication 1.0
# comorbidité comorbidité 4.0
# compacteuse compacteuse 2.0
# compactification compactification 2.0
# compactifier compactifier 1.0
# comparaitra comparaitra 2.0
# comparaitrai comparaitrai 2.0
# comparaitrait comparaitrait 1.0
# comparaitre comparaitre 112.0
# complaisant complaisant 1.0
# complait complait 7.0
# compliance compliance 1.0
# comploterie comploterie 1.0
# complotiste complotiste 4.0
# complue complue 1.0
# complètera complètera 14.0
# complèterai complèterai 6.0
# complèterait complèterait 1.0
# complèteront complèteront 1.0
# complétement complétement 1370.0
# composant composant 2.0
# compositeur compositeur 2.0
# compost compost 1.0
# composè composè 2.0
# composé composé 1.0
# compotée compotée 2.0
# compte compte 8.0
# compteuse compteuse 3.0
# compulsivité compulsivité 1.0
# computationnel computationnel 1.0
# computationnelle computationnelle 3.0
# compétitionne compétitionne 2.0
# compétitionner compétitionner 4.0
# con con 1.0
# concepteur concepteur 1.0
# concernant concernant 2.0
# concernement concernement 2.0
# concerto concerto 4.0
# concoction concoction 1.0
# concèderai concèderai 2.0
# condensat condensat 14.0
# conditionnè conditionnè 1.0
# condor condor 1.0
# conduit conduit 2.0
# conf conf 50.0
# config config 5.0
# confiteor confiteor 2.0
# confiturer confiturer 1.0
# confituré confituré 2.0
# confèrera confèrera 2.0
# confèrerai confèrerai 1.0
# conga conga 2.0
# congoliser congoliser 1.0
# congélo congélo 211.0
# connaissent connaissent 5.0
# connait connait 7392.0
# connaitra connaitra 104.0
# connaitrai connaitrai 39.0
# connaitraient connaitraient 9.0
# connaitrait connaitrait 46.0
# connaitre connaitre 3868.0
# connaitront connaitront 31.0
# connection connection 539.0
# connecté connecté 5.0
# connu connu 1.0
# conquistador conquistador 6.0
# conseil conseil 1.0
# conserve conserve 1.0
# considèrera considèrera 17.0
# considèrerai considèrerai 28.0
# considèreraient considèreraient 3.0
# considèrerait considèrerait 11.0
# considèreront considèreront 5.0
# consigne consigne 1.0
# consol consol 1.0
# consolidation consolidation 1.0
# consonnance consonnance 2.0
# consortium consortium 4.0
# conspirationniste conspirationniste 25.0
# constellation constellation 1.0
# constructeur constructeur 1.0
# construction construction 2.0
# construit construit 6.0
# consul consul 1.0
# consultant consultant 2.0
# consulte consulte 1.0
# consume consume 4.0
# container container 1.0
# contamination contamination 2.0
# contaminé contaminé 1.0
# contaminée contaminée 1.0
# contemplation contemplation 1.0
# contenant contenant 1.0
# content content 5.0
# contente contente 4.0
# contigüe contigüe 4.0
# continue continue 37.0
# continument continument 1.0
# contorsionniste contorsionniste 1.0
# contracteur contracteur 19.0
# contraction contraction 1.0
# contrario contrario 9.0
# contrattaquaient contrattaquaient 1.0
# contrattaquait contrattaquait 1.0
# contrattaquer contrattaquer 1.0
# contrattaqué contrattaqué 1.0
# contre contre 2.0
# contre-attaque contre-attaque 10.0
# contre-espionnage contre-espionnage 2.0
# contre-indiquè contre-indiquè 1.0
# contre-ré contre-ré 5.0
# contre-torpilleur contre-torpilleur 1.0
# contre-ut contre-ut 8.0
# contrecoeur contrecoeur 1.0
# contremaitre contremaitre 44.0
# contremaître contremaître 1.0
# contrespionnage contrespionnage 9.0
# contrindication contrindication 1.0
# contrintuitif contrintuitif 1.0
# contrôle contrôle 36.0
# convergence convergence 1.0
# converse converse 6.0
# convolutif convolutif 1.0
# cookie cookie 27.0
# coolitude coolitude 36.0
# coop coop 15.0
# coopèrera coopèrera 3.0
# coopèrerai coopèrerai 3.0
# coopèrerait coopèrerait 2.0
# coopèreront coopèreront 1.0
# coorbital coorbital 1.0
# coordonnance coordonnance 1.0
# coparrainer coparrainer 1.0
# copie copie 16.0
# copiloter copiloter 2.0
# copiloté copiloté 1.0
# copolymérisé copolymérisé 1.0
# coproducteur coproducteur 8.0
# coproscopie coproscopie 1.0
# coprésenter coprésenter 1.0
# copyleft copyleft 7.0
# copyright copyright 1.0
# coquelet coquelet 3.0
# coquin coquin 2.0
# corbac corbac 2.0
# corbin corbin 7.0
# corde corde 2.0
# cordelle cordelle 1.0
# coriace coriace 2.0
# corium corium 25.0
# cormier cormier 1.0
# corn-flake corn-flake 4.0
# corne corne 2.0
# corned-beef corned-beef 115.0
# corporate corporate 19.0
# corral corral 3.0
# correction correction 29.0
# corridor corridor 3.0
# corrosion corrosion 1.0
# corso corso 12.0
# corvette corvette 3.0
# coréalisateur coréalisateur 2.0
# coréen coréen 2.0
# cosignature cosignature 1.0
# cosplay cosplay 39.0
# cosplayeuse cosplayeuse 2.0
# cosse cosse 3.0
# cossette cossette 1.0
# costeau costeau 1.0
# costume costume 4.0
# costumè costumè 1.0
# cotage cotage 1.0
# cote cote 3.0
# cottage cottage 17.0
# cotè cotè 5.0
# couchant couchant 3.0
# couche couche 9.0
# couche-tard couche-tard 23.0
# couche-tôt couche-tôt 11.0
# coucougnette coucougnette 2.0
# cougar cougar 163.0
# couillent couillent 1.0
# couiller couiller 1.0
# couillu couillu 1.0
# couillue couillue 20.0
# couillé couillé 4.0
# coulant coulant 1.0
# coule coule 2.0
# coulevrine coulevrine 1.0
# country country 800.0
# coup coup 4.0
# coupe coupe 16.0
# coupe-coupe coupe-coupe 28.0
# coupe-faim coupe-faim 1.0
# coupe-gorge coupe-gorge 62.0
# coupe-papier coupe-papier 136.0
# couple couple 7.0
# coupon coupon 1.0
# couponing couponing 2.0
# courage courage 5.0
# courant courant 7.0
# courbaturè courbaturè 1.0
# courbe courbe 2.0
# courier courier 23.0
# courrielleur courrielleur 5.0
# course course 13.0
# court court 281.0
# court-circuit court-circuit 1.0
# court-métrage court-métrage 2.0
# courtage courtage 1.0
# cousinade cousinade 3.0
# cousu cousu 1.0
# cout cout 34.0
# couta couta 3.0
# coutaient coutaient 7.0
# coutait coutait 31.0
# coutant coutant 7.0
# coutent coutent 65.0
# couter couter 281.0
# coutera coutera 114.0
# couterai couterai 1.0
# couteraient couteraient 1.0
# couterait couterait 48.0
# couteront couteront 5.0
# couteuse couteuse 21.0
# coutèrent coutèrent 2.0
# coutée coutée 4.0
# couverture couverture 1.0
# couvre-feu couvre-feu 2.0
# couvre-théière couvre-théière 15.0
# covoitureuse covoitureuse 1.0
# cow-boy cow-boy 9.0
# cowboy cowboy 1089.0
# coyer coyer 1.0
# coyote coyote 16.0
# coévolution coévolution 1.0
# crachage crachage 2.0
# cracheur cracheur 1.0
# crack crack 2.0
# cracker cracker 9.0
# crackeur crackeur 5.0
# crado crado 1.0
# craint craint 8.0
# cramoisi cramoisi 10.0
# crampon crampon 1.0
# cranberry cranberry 53.0
# craniofaciale craniofaciale 3.0
# craquette craquette 1.0
# craquèle craquèle 1.0
# craquèlent craquèlent 1.0
# crash crash 4.0
# crasse crasse 1.0
# crawl crawl 29.0
# credo credo 1.0
# credo credo 245.0
# creek creek 1142.0
# crevasse crevasse 1.0
# crevette crevette 81.0
# criblè criblè 1.0
# cricket cricket 25.0
# crime crime 2.0
# criquet criquet 6.0
# crissante crissante 1.0
# critique critique 4.0
# crocidolite crocidolite 2.0
# crocodile crocodile 2.0
# croissanterie croissanterie 3.0
# croitre croitre 18.0
# croitront croitront 1.0
# crooner crooner 2.0
# crooneur crooneur 2.0
# croquant croquant 1.0
# croque-mitaine croque-mitaine 1.0
# croque-monsieur croque-monsieur 110.0
# croque-mort croque-mort 2.0
# croquemort croquemort 1.0
# croquette croquette 3.0
# cross-country cross-country 1.0
# cross-over cross-over 9.0
# crossage crossage 1.0
# crosse crosse 2.0
# crossette crossette 3.0
# crotte crotte 1.0
# crouille crouille 3.0
# croup croup 1.0
# croupion croupion 1.0
# croustillement croustillement 1.0
# croute croute 92.0
# crouter crouter 2.0
# crouteuse crouteuse 1.0
# crouton crouton 37.0
# croyant croyant 2.0
# crudivorisme crudivorisme 4.0
# cruiser cruiser 62.0
# cruiseur cruiseur 2.0
# crumble crumble 1.0
# crument crument 2.0
# cruzeiro cruzeiro 2.0
# cryoglobulinémie cryoglobulinémie 6.0
# cryogénisé cryogénisé 28.0
# cryogénisée cryogénisée 12.0
# cryopréservation cryopréservation 2.0
# cryosphère cryosphère 1.0
# cryptanalyste cryptanalyste 10.0
# cryptand cryptand 1.0
# cryptococcose cryptococcose 1.0
# cryptologue cryptologue 14.0
# cryptomnésie cryptomnésie 2.0
# cryptosporidiose cryptosporidiose 2.0
# crèmerie crèmerie 32.0
# crève crève 2.0
# crève-la-faim crève-la-faim 53.0
# créateur créateur 3.0
# créditation créditation 1.0
# crédo crédo 29.0
# crématorium crématorium 1.0
# crémerie crémerie 1.0
# crêpe crêpe 3.0
# crûe crûe 5.0
# cube cube 86.0
# cubicule cubicule 6.0
# cuesta cuesta 2.0
# cui-cui cui-cui 60.0
# cuicui cuicui 1.0
# cuiseuse cuiseuse 1.0
# cuisine cuisine 6.0
# cuite cuite 1.0
# cul cul 1.0
# cul-de-sac cul-de-sac 1.0
# culotte culotte 2.0
# cultivation cultivation 2.0
# culè culè 1.0
# cupcake cupcake 390.0
# curriculum vitae curriculum vitae 70.0
# curé curé 1.0
# custom custom 6.0
# cuter cuter 5.0
# cutter cutter 9.0
# cuvée cuvée 2.0
# cyanate cyanate 2.0
# cyber-harcèlement cyber-harcèlement 13.0
# cyberattaque cyberattaque 6.0
# cybercaméra cybercaméra 3.0
# cybercrime cybercrime 18.0
# cybercriminalité cybercriminalité 34.0
# cybercriminel cybercriminel 3.0
# cybercriminelle cybercriminelle 2.0
# cyberdéfense cyberdéfense 2.0
# cyberespionnage cyberespionnage 6.0
# cyberguerre cyberguerre 9.0
# cyberpolice cyberpolice 4.0
# cybersexe cybersexe 10.0
# cybersquattage cybersquattage 1.0
# cybersécurité cybersécurité 20.0
# cyberterrorisme cyberterrorisme 13.0
# cyborg cyborg 385.0
# cyclage cyclage 1.0
# cycle cycle 6.0
# cyclo-pousse cyclo-pousse 13.0
# cyclohexanone cyclohexanone 1.0
# cyclomatique cyclomatique 1.0
# cyperméthrine cyperméthrine 3.0
# cytidine cytidine 1.0
# cytomètre cytomètre 1.0
# cytométrique cytométrique 3.0
# càd càd 5.0
# câble câble 1.0
# cèdera cèdera 70.0
# cèderai cèderai 37.0
# cèderaient cèderaient 1.0
# cèderait cèderait 10.0
# cèderont cèderont 17.0
# céliochirurgie céliochirurgie 1.0
# célèbre célèbre 4.0
# célèbrera célèbrera 16.0
# célèbrerai célèbrerai 4.0
# célèbrerait célèbrerait 3.0
# cératopsien cératopsien 1.0
# cérébrovasculaire cérébrovasculaire 11.0
# cétoacidose cétoacidose 3.0
# cétylique cétylique 2.0
# côté côté 2.0
# d d 2442.0
# d d 1204.0
# dada dada 2.0
# dag dag 12.0
# dal dal 30.0
# dalmatien dalmatien 1.0
# damage damage 4.0
# dame dame 233.0
# dancing dancing 61.0
# dandy dandy 2.0
# danger danger 2.0
# danse danse 25.0
# darjeeling darjeeling 4.0
# dark dark 247.0
# darknet darknet 30.0
# data data 299.0
# date date 431.0
# dcd dcd 15.0
# de de 45.0
# deal deal 6.0
# dealeur dealeur 138.0
# dealeuse dealeuse 93.0
# debriefing debriefing 83.0
# debrouille debrouille 25.0
# dei dei 67.0
# dej dej 172.0
# delphinium delphinium 2.0
# delta delta 20.0
# demande demande 15.0
# demandè demandè 29.0
# demeurant demeurant 1.0
# demeure demeure 2.0
# demi-finale demi-finale 2.0
# demi-quart demi-quart 1.0
# demi-sel demi-sel 18.0
# demi-tarif demi-tarif 1.0
# demi-tour demi-tour 7.0
# dendrobate dendrobate 1.0
# denim denim 9.0
# densitométrie densitométrie 1.0
# dent dent 2.0
# dentelière dentelière 1.0
# dentier dentier 1.0
# dentiste dentiste 1.0
# dermabrasion dermabrasion 14.0
# dermato dermato 107.0
# dermatologie dermatologie 1.0
# dermatome dermatome 4.0
# dermatophytose dermatophytose 1.0
# derme derme 1.0
# derrick derrick 2.0
# desiderata desiderata 16.0
# design design 17.0
# designeur designeur 5.0
# designeuse designeuse 2.0
# desperado desperado 1.0
# despérado despérado 1.0
# desquamation desquamation 2.0
# dessert dessert 1.0
# dessication dessication 1.0
# dessoufflé dessoufflé 1.0
# dessous-de-plat dessous-de-plat 7.0
# dessous-de-table dessous-de-table 20.0
# dessus-de-lit dessus-de-lit 22.0
# dessèchera dessèchera 1.0
# dessècherait dessècherait 1.0
# dessècheront dessècheront 1.0
# destinataire destinataire 2.0
# destroyer destroyer 3.0
# destroyeur destroyeur 2.0
# destruction destruction 1.0
# deus ex machina deus ex machina 21.0
# deux-huit deux-huit 5.0
# deux-quatre deux-quatre 3.0
# devant devant 3.0
# deviseuse deviseuse 1.0
# dextrométhorphane dextrométhorphane 1.0
# dey dey 1.0
# dg dg 2.0
# dhamma dhamma 4.0
# dharma dharma 3.0
# diabolo diabolo 4.0
# diagnostique diagnostique 1.0
# diamine diamine 1.0
# dianétique dianétique 5.0
# diazote diazote 4.0
# dichlorométhane dichlorométhane 1.0
# dichlorure dichlorure 2.0
# dicté dicté 1.0
# didgeridoo didgeridoo 25.0
# dieu dieu 10.0
# diffuse diffuse 1.0
# diffusion diffusion 3.0
# diffèrera diffèrera 1.0
# difféomorphe difféomorphe 1.0
# digest digest 82.0
# digipuncture digipuncture 1.0
# digèrera digèrera 2.0
# digèrerai digèrerai 2.0
# dihydrogène dihydrogène 1.0
# dilapidé dilapidé 1.0
# dime dime 42.0
# diméthylmercure diméthylmercure 15.0
# dimétrodon dimétrodon 1.0
# dinai dinai 1.0
# dinaient dinaient 3.0
# dinait dinait 33.0
# dinatoire dinatoire 4.0
# dinent dinent 12.0
# diner diner 5132.0
# dinera dinera 18.0
# dinerai dinerai 12.0
# dinerait dinerait 5.0
# dineront dineront 3.0
# dinette dinette 22.0
# ding ding 1.0
# diné diné 137.0
# dinée dinée 1.0
# diorama diorama 1.0
# diot diot 3.0
# dioxygène dioxygène 6.0
# diphonique diphonique 2.0
# dircom dircom 13.0
# directorat directorat 3.0
# dirigeant dirigeant 1.0
# disc-jockey disc-jockey 1.0
# discount discount 5.0
# disgrace disgrace 20.0
# dismutase dismutase 2.0
# disodique disodique 5.0
# disomie disomie 1.0
# disparaisse disparaisse 2.0
# disparaissent disparaissent 3.0
# disparait disparait 542.0
# disparaitra disparaitra 118.0
# disparaitrai disparaitrai 16.0
# disparaitraient disparaitraient 7.0
# disparaitrait disparaitrait 28.0
# disparaitre disparaitre 1276.0
# disparaitront disparaitront 46.0
# disparut disparut 1.0
# dispatcheur dispatcheur 20.0
# dispatcheuse dispatcheuse 1.0
# dispose dispose 1.0
# disquaire disquaire 1.0
# disqueuse disqueuse 11.0
# disruptée disruptée 1.0
# dissection dissection 1.0
# dissert dissert 111.0
# dissipation dissipation 1.0
# dissociation dissociation 2.0
# dissèquera dissèquera 1.0
# dissèqueraient dissèqueraient 1.0
# distance distance 4.0
# distribution distribution 4.0
# district district 2.0
# disulfure disulfure 5.0
# div div 3.0
# diva diva 50.0
# diverticulite diverticulite 18.0
# divise divise 1.0
# division division 1.0
# divorce divorce 3.0
# dix-huit dix-huit 145.0
# dix-neuf dix-neuf 111.0
# dix-sept dix-sept 162.0
# dièse dièse 2.0
# diégèse diégèse 1.0
# diésel diésel 1.0
# diéthylstilbestrol diéthylstilbestrol 1.0
# djembe djembe 4.0
# djihad djihad 1.0
# djihadisme djihadisme 2.0
# djihadiste djihadiste 45.0
# dl dl 8.0
# dm dm 8.0
# do do 4462.0
# doberman doberman 2.0
# dobutamine dobutamine 19.0
# doc doc 1.0
# dock dock 4.0
# docteure docteure 62.0
# docu docu 78.0
# ...
# troupe troupe 1.0
# troutrou troutrou 16.0
# trouveur trouveur 2.0
# trouvè trouvè 42.0
# truble truble 2.0
# truc truc 1.0
# trucage trucage 1.0
# truck truck 46.0
# trucmuche trucmuche 8.0
# trust trust 49.0
# truste truste 1.0
# trépanage trépanage 1.0
# tsar tsar 1.0
# tsotsi tsotsi 3.0
# tsunami tsunami 4.0
# tsé-tsé tsé-tsé 55.0
# tsétsé tsétsé 3.0
# tt tt 12.0
# tte tte 29.0
# tuant tuant 1.0
# tub tub 3.0
# tube tube 32.0
# tue tue 44.0
# tue-loup tue-loup 1.0
# tumorectomie tumorectomie 12.0
# tune tune 4.0
# tuning tuning 24.0
# tunnel tunnel 2.0
# tupperware tupperware 47.0
# turbin turbin 1.0
# turbine turbine 5.0
# turbo turbo 8.0
# turbulence turbulence 1.0
# turco turco 1.0
# turnover turnover 2.0
# tuto tuto 7.0
# tutora tutora 1.0
# tutorer tutorer 2.0
# tutoré tutoré 4.0
# tutorée tutorée 1.0
# tutti tutti 25.0
# tweet tweet 345.0
# tweeta tweeta 1.0
# tweetait tweetait 2.0
# tweetant tweetant 4.0
# tweete tweete 60.0
# tweetent tweetent 20.0
# tweeter tweeter 1.0
# tweetera tweetera 2.0
# tweeterai tweeterai 4.0
# tweeterait tweeterait 4.0
# tweetè tweetè 1.0
# tweeté tweeté 150.0
# tweetée tweetée 3.0
# twerk twerk 24.0
# twerkaient twerkaient 1.0
# twerke twerke 2.0
# twerkent twerkent 2.0
# twerker twerker 20.0
# twerké twerké 1.0
# twirling twirling 4.0
# twittait twittait 3.0
# twittant twittant 1.0
# twitte twitte 17.0
# twittent twittent 6.0
# twitter twitter 183.0
# twittera twittera 1.0
# twitterai twitterai 4.0
# twitteront twitteront 3.0
# twitté twitté 39.0
# twittée twittée 1.0
# type type 23.0
# tyran tyran 1.0
# tyrannosaure tyrannosaure 1.0
# tzatziki tzatziki 19.0
# tètera tètera 2.0
# tèterai tèterai 1.0
# tél tél 27.0
# télomérase télomérase 4.0
# télé-achat télé-achat 2.0
# télé-réalité télé-réalité 1.0
# télécom télécom 13.0
# téléjournal téléjournal 9.0
# télékinésie télékinésie 1.0
# télékinétique télékinétique 31.0
# télénovela télénovela 34.0
# téléphage téléphage 2.0
# téléphone téléphone 9.0
# téléporta téléporta 1.0
# téléportait téléportait 12.0
# téléportant téléportant 14.0
# téléporte téléporte 133.0
# téléportent téléportent 12.0
# téléporter téléporter 987.0
# téléportera téléportera 31.0
# téléporterai téléporterai 15.0
# téléporteraient téléporteraient 1.0
# téléporterait téléporterait 3.0
# téléporteront téléporteront 4.0
# téléporté téléporté 266.0
# téléportée téléportée 88.0
# téléprospectrice téléprospectrice 1.0
# télépéage télépéage 17.0
# téléréalité téléréalité 121.0
# téléscope téléscope 66.0
# télésécurité télésécurité 2.0
# téléthon téléthon 56.0
# télétravaille télétravaille 1.0
# télévente télévente 2.0
# téléverser téléverser 2.0
# téléversé téléversé 1.0
# téléversée téléversée 2.0
# témoin témoin 3.0
# téméraire téméraire 2.0
# ténorino ténorino 1.0
# téquila téquila 146.0
# téra téra 5.0
# téravolt téravolt 1.0
# térawattheure térawattheure 1.0
# tétrahydrocannabinol tétrahydrocannabinol 6.0
# tétramorphe tétramorphe 1.0
# tête tête 4.0
# tête-bêche tête-bêche 15.0
# tête-de-mort tête-de-mort 6.0
# tête-à-queue tête-à-queue 30.0
# tête-à-tête tête-à-tête 714.0
# u u 3252.0
# ua ua 7.0
# ubiquinone ubiquinone 2.0
# uchronique uchronique 1.0
# ud ud 11.0
# ulcère ulcère 1.0
# ultra-sensible ultra-sensible 1.0
# ultrarésistant ultrarésistant 1.0
# ultraviolent ultraviolent 2.0
# ultraviolente ultraviolente 1.0
# umami umami 12.0
# underground underground 58.0
# underscore underscore 2.0
# unidose unidose 1.0
# unif unif 39.0
# union union 5.0
# unité unité 1.0
# univ univ 10.0
# universal universal 22.0
# université université 1.0
# ununoctium ununoctium 2.0
# ununpentium ununpentium 1.0
# ununseptium ununseptium 1.0
# upsilon upsilon 8.0
# urgentiste urgentiste 1.0
# urgentologue urgentologue 7.0
# urinage urinage 1.0
# urine urine 2.0
# urticaire urticaire 1.0
# usite usite 1.0
# usiter usiter 1.0
# ut ut 69.0
# utero utero 1.0
# utilisè utilisè 3.0
# utéro utéro 4.0
# v v 1341.0
# v v 2365.0
# v. v. 204.0
# va-et-vient va-et-vient 263.0
# va-tout va-tout 34.0
# vacation vacation 1.0
# vacuum vacuum 1.0
# vad vad 1.0
# vade vade 1.0
# vade-mecum vade-mecum 1.0
# vaginoplastie vaginoplastie 13.0
# vaginose vaginose 3.0
# vahiné vahiné 1.0
# vajrayana vajrayana 1.0
# valse valse 2.0
# valvulopathie valvulopathie 6.0
# vamp vamp 2.0
# vampire vampire 5.0
# vampirisation vampirisation 4.0
# vancomycine vancomycine 21.0
# vandalisation vandalisation 1.0
# vape vape 1.0
# vapotage vapotage 1.0
# vapoteuse vapoteuse 4.0
# varia varia 1.0
# variant variant 2.0
# variolée variolée 2.0
# vasculariser vasculariser 1.0
# vaseline vaseline 1.0
# vasogénique vasogénique 3.0
# vasospasme vasospasme 10.0
# vassal vassal 1.0
# vautrement vautrement 1.0
# vectoriser vectoriser 1.0
# velcro velcro 1.0
# veld veld 1.0
# vengè vengè 2.0
# vent vent 2.0
# ventilation ventilation 1.0
# venu venu 9.0
# ver ver 37.0
# verbatim verbatim 2.0
# verdin verdin 3.0
# vergea vergea 1.0
# verité verité 228.0
# vermine vermine 1.0
# verse verse 1.0
# version version 5.0
# vert vert 1.0
# verticalisateur verticalisateur 1.0
# vertigo vertigo 8.0
# vertébrer vertébrer 1.0
# vestigial vestigial 7.0
# vestigiale vestigiale 5.0
# veto veto 441.0
# veuillé veuillé 1.0
# vexille vexille 1.0
# vi vi 98.0
# via via 28.0
# viande viande 1.0
# vibro vibro 83.0
# vice vice 1.0
# vice-amiral vice-amiral 1.0
# vice-consule vice-consule 4.0
# vice-président vice-président 13.0
# victimisme victimisme 1.0
# vidangeur vidangeur 1.0
# vide vide 1.0
# vidéoprojecteur vidéoprojecteur 3.0
# vie vie 5.0
# vigilantisme vigilantisme 6.0
# viguier viguier 2.0
# vilain vilain 3.0
# village village 6.0
# ville ville 2.0
# vilénie vilénie 12.0
# vina vina 23.0
# vinaigrette vinaigrette 1.0
# vingt vingt 795.0
# vingt-cinq vingt-cinq 1.0
# vingt-et-un vingt-et-un 1.0
# vingt-et-un vingt-et-un 83.0
# vingt-neuf vingt-neuf 4.0
# vingt-quatre vingt-quatre 71.0
# vintage vintage 11.0
# vinyl vinyl 39.0
# violence violence 1.0
# violent violent 4.0
# violoneuse violoneuse 1.0
# violée violée 2.0
# virelangue virelangue 2.0
# virgine virgine 1.0
# visa visa 1.0
# visage visage 1.0
# visio visio 15.0
# vision vision 1.0
# visite visite 4.0
# vison vison 2.0
# visu visu 35.0
# visualiseur visualiseur 2.0
# visuo-spatial visuo-spatial 1.0
# vitae vitae 13.0
# vitam vitam 34.0
# vitro vitro 4.0
# vitruvien vitruvien 1.0
# vitæ vitæ 1.0
# vivarium vivarium 1.0
# vivendi vivendi 2.0
# vivo vivo 8.0
# vlog vlog 42.0
# vodka vodka 1.0
# voeu voeu 3.0
# vogue vogue 12.0
# voici voici 2.0
# voie voie 1.0
# voile voile 1.0
# voili voili 5.0
# voilou voilou 12.0
# voilà voilà 34.0
# vol-au-vent vol-au-vent 26.0
# volant volant 8.0
# volatilisé volatilisé 1.0
# vole vole 60.0
# volley volley 4.0
# volley-ball volley-ball 3.0
# volleyball volleyball 85.0
# voltage voltage 5.0
# volte-face volte-face 112.0
# voltige voltige 3.0
# voltigeuse voltigeuse 2.0
# volumateur volumateur 5.0
# volume volume 1.0
# volè volè 14.0
# volètent volètent 3.0
# vombrissement vombrissement 2.0
# vote vote 3.0
# voui voui 12.0
# voulu voulu 1.0
# voute voute 54.0
# vouté vouté 9.0
# voutée voutée 2.0
# vox populi vox populi 8.0
# voyage voyage 21.0
# voyant voyant 1.0
# vraiment vraiment 1.0
# vu vu 1.0
# vuvuzela vuvuzela 4.0
# vécu vécu 1.0
# végan végan 16.0
# végane végane 7.0
# véganisme véganisme 8.0
# végètera végètera 1.0
# végèterait végèterait 1.0
# vélociraptor vélociraptor 20.0
# vénèrera vénèrera 1.0
# vénèrerai vénèrerai 8.0
# vénèreraient vénèreraient 2.0
# vénèrerait vénèrerait 2.0
# vénèreront vénèreront 4.0
# vénérée vénérée 1.0
# véto véto 620.0
# vétérane vétérane 4.0
# vévé vévé 1.0
# w w 1283.0
# wah-wah wah-wah 15.0
# wai wai 21.0
# waka waka 16.0
# wakizashi wakizashi 3.0
# walk walk 350.0
# walk-over walk-over 3.0
# walkie walkie 53.0
# waouh waouh 248.0
# warning warning 9.0
# warrant warrant 1.0
# wasabi wasabi 102.0
# water water 136.0
# water-polo water-polo 1.0
# waterpolo waterpolo 12.0
# webdesign webdesign 1.0
# websérie websérie 3.0
# webzine webzine 1.0
# weed weed 227.0
# week-end week-end 15.0
# weekend weekend 1912.0
# welter welter 7.0
# western western 11.0
# wharf wharf 50.0
# whisky whisky 1.0
# wicca wicca 16.0
# wiccan wiccan 19.0
# wiccane wiccane 6.0
# widget widget 9.0
# wifi wifi 205.0
# wigwam wigwam 12.0
# wiki wiki 23.0
# winch winch 14.0
# window window 75.0
# wishbone wishbone 2.0
# wok wok 79.0
# wombat wombat 3.0
# won won 378.0
# woogie woogie 7.0
# workshop workshop 9.0
# wu wu 93.0
# wushu wushu 12.0
# xanthium xanthium 4.0
# xi xi 19.0
# xi xi 119.0
# xiang xiang 12.0
# xml xml 2.0
# xylitol xylitol 4.0
# xénodiagnostic xénodiagnostic 1.0
# xénolithe xénolithe 2.0
# xénomorphe xénomorphe 1.0
# xénotransplantation xénotransplantation 1.0
# y y 11431.0
# yacht yacht 2.0
# yack yack 1.0
# yak yak 6.0
# yakuza yakuza 9.0
# yang yang 43.0
# yankee yankee 3.0
# yaoi yaoi 4.0
# yard yard 35.0
# yearling yearling 8.0
# yen yen 12.0
# yeoman yeoman 2.0
# yeomanry yeomanry 2.0
# yersinia yersinia 3.0
# yeti yeti 1.0
# yiddish yiddish 144.0
# yin yin 15.0
# yl yl 1.0
# ylang ylang 1.0
# yo-yo yo-yo 1.0
# yo-yo yo-yo 295.0
# yod yod 15.0
# yoga yoga 1.0
# yogi yogi 6.0
# yorkaise yorkaise 16.0
# youpie youpie 6.0
# youtubeur youtubeur 2.0
# yoyotte yoyotte 4.0
# yuzu yuzu 4.0
# yé-yé yé-yé 4.0
# zaibatsu zaibatsu 2.0
# zakouski zakouski 42.0
# zakât zakât 1.0
# zani zani 2.0
# zanzi zanzi 1.0
# zappette zappette 11.0
# zarbi zarbi 1.0
# zeitgeist zeitgeist 7.0
# zettajoule zettajoule 1.0
# zettaoctet zettaoctet 1.0
# zeugma zeugma 3.0
# zibe zibe 1.0
# zibeline zibeline 2.0
# zigonner zigonner 2.0
# zigouigoui zigouigoui 10.0
# ziguer ziguer 2.0
# zigué zigué 4.0
# zingara zingara 4.0
# zl zl 4.0
# zob zob 6.0
# zombie zombie 7.0
# zombiesque zombiesque 1.0
# zombifié zombifié 15.0
# zombifiée zombifiée 4.0
# zone zone 157.0
# zoo zoo 3.0
# zoothérapeute zoothérapeute 1.0
# zouk zouk 1.0
# zouker zouker 2.0
# zugzwang zugzwang 7.0
# zyva zyva 3.0
# zénitude zénitude 10.0
# zêta zêta 34.0
# ° ° 1157.0
# à-pic à-pic 13.0
# à-valoir à-valoir 8.0
# âge âge 1.0
# æ æ 9.0
# æ æ 7.0
# æternam æternam 5.0
# çuilà çuilà 1.0
# éboueuse éboueuse 7.0
# ébrècherai ébrècherai 1.0
# ébène ébène 31.0
# échange échange 1.0
# échec échec 1.0
# échoendoscopie échoendoscopie 1.0
# écholocalise écholocalise 1.0
# écholocalisent écholocalisent 1.0
# échèle échèle 2.0
# éclair éclair 157.0
# éclairage éclairage 5.0
# éclairagiste éclairagiste 2.0
# éclaire éclaire 1.0
# éclateuse éclateuse 1.0
# éclipse éclipse 1.0
# éclipsé éclipsé 1.0
# éclôt éclôt 14.0
# éco éco 242.0
# écoblanchiment écoblanchiment 1.0
# écoeurante écoeurante 1.0
# écoeure écoeure 1.0
# économiciste économiciste 1.0
# écorcheur écorcheur 4.0
# écoterrorisme écoterrorisme 5.0
# écoterroriste écoterroriste 12.0
# écoute écoute 8.0
# écouté écouté 1.0
# écrevisse écrevisse 3.0
# écrivaine écrivaine 1.0
# écrouter écrouter 1.0
# écrêteur écrêteur 1.0
# édit édit 6.0
# égo égo 598.0
# éjectrice éjectrice 1.0
# éjecté éjecté 1.0
# élagueuse élagueuse 1.0
# élastiqué élastiqué 1.0
# électricien électricien 1.0
# électro électro 157.0
# électro-encéphalographe électro-encéphalographe 1.0
# électro-oculogramme électro-oculogramme 1.0
# électrokinésie électrokinésie 1.0
# électronisée électronisée 1.0
# électrophotographie électrophotographie 2.0
# électrophotographique électrophotographique 1.0
# électroporation électroporation 6.0
# électrosensible électrosensible 3.0
# électrostimulation électrostimulation 5.0
# élicitation élicitation 1.0
# élingage élingage 2.0
# élèvement élèvement 1.0
# élégamment élégamment 1.0
# émancipateur émancipateur 1.0
# émasculateur émasculateur 2.0
# émiettage émiettage 2.0
# éminçage éminçage 2.0
# émoji émoji 7.0
# émoticône émoticône 40.0
# émotivement émotivement 13.0
# émulsification émulsification 1.0
# énormissime énormissime 12.0
# épandage épandage 2.0
# épargne épargne 1.0
# éperonnage éperonnage 7.0
# épeule épeule 1.0
# épeulent épeulent 1.0
# épic épic 14.0
# épichlorhydrine épichlorhydrine 7.0
# épilatrice épilatrice 2.0
# épilement épilement 1.0
# épinéphrine épinéphrine 226.0
# épisode épisode 15.0
# épissage épissage 7.0
# épithélialisée épithélialisée 1.0
# épitre épitre 2.0
# épivardant épivardant 1.0
# épivarder épivarder 1.0
# épivardée épivardée 1.0
# épongement épongement 1.0
# époque époque 1.0
# épouilleuse épouilleuse 1.0
# époumonner époumonner 1.0
# épousaille épousaille 1.0
# épouse épouse 15.0
# époussète époussète 1.0
# époussètent époussètent 1.0
# épuisé épuisé 2.0
# épèle épèle 21.0
# épèlement épèlement 1.0
# épèlent épèlent 3.0
# épèleront épèleront 1.0
# épépineur épépineur 1.0
# équitation équitation 1.0
# érythroblastopénie érythroblastopénie 9.0
# érythropoïétique érythropoïétique 1.0
# étage étage 3.0
# était était 32.0
# étale étale 2.0
# étant étant 1.0
# état-major état-major 2.0
# éthanolate éthanolate 1.0
# éthyl éthyl 6.0
# étincèlent étincèlent 1.0
# étiquète étiquète 2.0
# étonnant étonnant 1.0
# étouffe-chrétien étouffe-chrétien 5.0
# étreinte étreinte 3.0
# étudiant étudiant 1.0
# êta êta 3.0
# ô ô 236.0
# 5094 7683
# %, 1er, 1re, 2e, 3e, 4e, 4x4, 5e, 6e, 7e, _, a, a priori, abaisse-langue, abat-jour, abat-vent, abc, abdo, abimait, abime, abiment, abimer, abimera, abimerai, abimerait, abimé, abimée, abriver, abrègerait, abrègeront, abrévier, absolut, abu, abusement, abusé, ac, accastilleur, acceptè, accepté, acceptée, accessoirisation, accessoiriste, accidentogène, accostement, accrobranche, accroissent, accroit, accroitra, accroitre, accréditrice, accrû, accèdera, accèderai, accèderaient, accèderait, accèderont, accélèrera, accélèrerai, accélèreraient, accélèrerait, accélèreront, achetè, achetée, achète, aciclovir, acquitement, acrotomophilie, acrylamide, acting, activable, active, actorat, acérola, acétaminophène, acétylcystéine, ad, add-on, addenda, addict, addictif, addictive, addictologie, addictologique, addictologue, adhèrera, adhèrerai, adhèreraient, adhèreront, adit, adjudante, ado, adulescent, adultèreront, affligement, affrété, affut, affutage, affute, affutent, affuter, affutera, affuterai, affuteuse, affuté, affutée, afghano-pakistanaise, afro-américaine, afrobeat, afrocentrisme, after-shave, aftershave, ag, agissant, agrandi, agresseuse, agressive, agrocarburant, agroécologie, agréement, agrégateur, ah, ai, aidant, aidante, aide, aide-mémoire, aie, aient, aigüe, ailière, aille, aimè, ainesse, ainé, ainée, ait, aitre, akinétique, aldicarbe, aleph, algo, algorithmie, alien, alkyde, alleluia, allemande, allodynie, allotrope, allume-feu, allègera, allègerai, allègerait, allègeront, allélique, alm, alpha, alpiniste, alter, alter ego, altermondialiste, alternaria, alto, altèrera, altèrerait, altèreront, alu, alu, am, amalgamée, amassage, amasseuse, amateure, ambigüe, ambigüité, amen, amenage, ameutement, amikacine, amish, amitriptyline, ammonitrate, amoncèlent, amorcé, amoxicilline, amphibienne, amphète, ampliforme, ampèreheure, amusant, amuse-bouche, amuse-gueule, amuse-gueule, amylasémie, amyotrophique, amène, américano-soviétique, ana, anaphylactise, anaphylactoïde, anaplasique, angiosarcome, anglo-russe, anhydrase, anhédonie, animaliste, animatique, animatronique, anime, anisakiase, annua, annulateur, annulement, anonymiser, anonymisé, anorectale, antagonise, anti-g, anti-oxydant, anti-oxydante, anti-spam, anti-tabac, antibiorésistante, antiboise, antidépressif, antiqua, antébrachiale, antéro-postérieur, anéchoïque, aout, août, apnéiste, apocrine, apoptotique, apparaitra, apparaitrai, apparaitraient, apparaitrait, apparaitre, apparaitront, appeal, appuie-tête, appâtage, apriori, après-demain, après-midi, aquaporine, arabo-musulmane, arachidonique, arachnophobe, arachnophobie, arc-en-ciel, argent, argh, armurière, arnacher, arnaché, arnachée, arrivè, arsénopyrite, arthroscopique, artériopathique, aryaniser, aryanisera, asap, ashkenaze, aspartate, aspergillome, assertivité, assit, assiègeraient, assiègeront, assoc, assoir, assortissement, assureuse, assèchera, assècherait, assècheront, asséchement, asthmatiforme, astiquè, astrobiologiste, astrocytome, astromobile, astronaute, athlé, atm, atopique, atrioventriculaire, attachage, atteint, attiéké, attèle, au, au-delà, au-delà, auberon, audimat, audioguide, audiolivre, aujourd'hui, auraient, aurait, auteure, auto-immune, autoaccuser, autoadministré, autoadministrée, autocongratulant, autocongratule, autocongratuler, autoconsommer, autodiscipliner, autoflageller, autogère, autojustifiée, autoproduire, autopropulsent, autoreproduire, autoreproduit, autorisation, autosomal, autosomale, autostimuler, autosuffire, av, av., avaient, avait, avalant, avale, avant-gout, avant-hier, avant-midi, ave, ave, average, aveugle, aveuglette, avionneuse, aviseur, avr, avril, avt, avèrera, avèreraient, avèrerait, avèreront, avé, award, axonal, axonale, ayahuasca, aye, ayurveda, ayurvéda, ayé, azine, azoth, azur, aérobique, aérofreinage, aéroponie, aéroporter, aéroporté, aéroportée, aérosolisé, b, baby-foot, babyfoot, babysitteur, babysitteuse, babysitting, bachelor, bacitracine, backdoor, backup, bactér ...

# %%
fLexFilms4GB2=fLexFilms4GB.replace("GB.csv","GB2.csv")

# %%
df.to_csv(path_or_buf=fLexFilms4GB2,sep="\t",encoding="utf8",index=False)

# %%
df=pd.read_csv(filepath_or_buffer=fLexFilms4GB2,sep="\t",skip_blank_lines=True,encoding="utf8")
display(df.head())
print len(df)
condFormeNotLemme=df.graphie!=df.lemme
condLemmeNoSXZ=~df.lemme.str[-1].isin(["s","x","z"])
condN=df.cat=="NOM"
condA=df.cat=="ADJ"
condNA=df["cat"].isin(["NOM","ADJ"])
condNoNombreN=condN&(df.nombre.isnull())
condNoNombreA=condA&(df.nombre.isnull())
condNoNombreNA=condNA&(df["nombre"].isnull())
condGenreNombre=(df.genre.notnull())&(df.nombre.notnull())
# Out:
#   graphie lemme  cat infover genre nombre  occurrences
# 0       !     !  ADV     NaN   NaN    NaN         10.0
# 1       $     $  NOM     NaN     m      p      53371.0
# 2       %     %  NOM     NaN     m    NaN      29248.0
# 3       (     (  ADV     NaN   NaN    NaN          3.0
# 4       )     )  ADV     NaN   NaN    NaN          7.0
# 215563

# %%
nbGraphieLemme=0
nbChoixGraphieLemme=0
formesChoix=[]
indexDrops=[]
localDF=df[condNoNombreN&condFormeNotLemme&df.lemme.notnull()]
for index,row in localDF.iterrows():
    mauvaisesOccurrences=row.occurrences
    graphie=row.graphie
    lemme=row.lemme
    if  graphie==lemme+"s":
        print graphie,lemme,mauvaisesOccurrences
        dfGraphieLemme=getFormeLemme(row.graphie,row.lemme)
        dfChoix=dfGraphieLemme[condN&condGenreNombre]
        if len(dfChoix)==1:
            occurrencesChoix=dfChoix.occurrences.values[0]
            ixChoix=dfChoix.index[0]
            if debug: print ixChoix,occurrencesChoix,occurrencesChoix+mauvaisesOccurrences
            df.loc[df.index==ixChoix,"occurrences"]=occurrencesChoix+mauvaisesOccurrences
            if debug: print df.occurrences.iloc[ixChoix]
            indexDrops.append(index)
            display(df[df.graphie==graphie])
        else:
            display(dfChoix)
            nbChoixGraphieLemme+=1
            formesChoix.append(graphie)
        nbGraphieLemme+=1
df.drop(indexDrops,inplace=True)
print nbChoixGraphieLemme,nbGraphieLemme
print ", ".join(formesChoix)

# %%
bilanDF(df[condNoNombreN&~condFormeNotLemme&~(df.lemme.str[-1].isin(["s","x","z"]))],"Noms nombre NaN")

# %% [markdown]
# #### Pluriels non marqués par s/x/z

# %%
condNomPl=(df["cat"].isin(["NOM"]))&(~df["graphie"].str[-1:].isin([u"s",u"x",u"z"]))&(df["nombre"].isin(["p"]))
bilanDF(df[condNomPl],"Noms p",lines=1)

# %% [markdown]
# ## Contrôles de cohérence pour les verbes
# D'après la nomenclature, tous les verbes devraient avoir un champ ***infover*** renseigné et les autres catégories ne devraient pas avoir d'information dans ce champ.
#
# Les premiers tests concernent les infover qui ne sont pas reliés à un verbe.
#
# Les suivants concernent la cohérence des infover avec les formes verbales auxquels ils sont reliés.

# %% [markdown]
# ### participes présent
# Dans la première version reçue, il y avait un problème avec l'étiquette par:pre :
# - l'étiquetage des participes présent n'était pas conforme à la nomenclature par:pre (3634 formes)
#  - le découpage avait donné infover=par:p et le re s'est retrouvé découpé entre nombre et genre
#
# La seconde version ne pose plus ce problème

# %%
condParPre=(df["infover"]=="par:p")
bilanDF(df[condParPre],"infover=par:p")

# %% [markdown]
# ### Infover sans verbe
# - infover ne devait pas être présent en dehors des formes verbales
#  - pour les adjectifs, il faudrait sans doute prendre une décision pour ceux qui ressemblent à des participes passés
#  - pour les noms, il faudrait probablement corriger

# %%
condVER=(df.cat.isin(["VER","AUX"]))
condInfover=(df.infover.notnull())
bilanDF(df[~condVER&condInfover],"infover hors formes verbales",lines=1)

# %% [markdown]
# ### Infover hors verbes
# Pour chaque élément incohérent, on cherche les éléments correspondants pour la même graphie et le même lemme.
# - si il n'y a qu'une seule correspondance, on ajoute les occurrences incohérentes à la correspondance en question et on supprime l'entrée incohérente
# - si il y a plusieurs correspondances, il faut en choisir une
# - si il n'y a pas de correspondances, il faut décider de la valeur à assigner pour genre et nombre

# %%
nbGraphieLemme=0
nbChoixGraphieLemme=0
formesChoix=[]
for index,row in df[~condVER&condInfover].iterrows():
    mauvaisesOccurrences=row.occurrences
    graphie=row.graphie
    print graphie,mauvaisesOccurrences
    dfGraphieLemme=getFormeLemme(row.graphie,row.lemme)
    condNoInfover=(dfGraphieLemme.infover.isnull())
    dfChoix=dfGraphieLemme[condNoInfover].sort_values("occurrences",ascending=False)
    if len(dfChoix)==1:
        occurrencesChoix=dfChoix.occurrences.values[0]
        ixChoix=dfChoix.index[0]
        print ixChoix,occurrencesChoix,occurrencesChoix+mauvaisesOccurrences
        df.occurrences.iloc[ixChoix]=occurrencesChoix+mauvaisesOccurrences
        df.drop(index,inplace=True)
        display(df[df.graphie==graphie])
    else:
        display(dfChoix)
        nbChoixGraphieLemme+=1
        formesChoix.append(graphie)
    nbGraphieLemme+=1
print nbChoixGraphieLemme,nbGraphieLemme
print ", ".join(formesChoix)

# %% [markdown]
# ### Verbe sans infover
# Toutes les formes verbales devraient avoir un infover mais 2328 formes n'ont aucune information associée

# %%
condVerInfover=(df["cat"].isin(["VER","AUX"]))&(df["infover"].isnull())
bilanDF(df[condVerInfover],"formes verbales sans infover",lines=True)

# %% [markdown]
# ### Cohérence des formes graphiques
# Il y a des contraintes de correspondance entre graphie et infover
# 1. Tester la plausibilité de infover en fonction de la graphie
#    - "er" n'est compatible qu'avec inf
# 1. Tester la graphie en fonction de infover
#    - ind:fut
#        - 1SG => rai
#        - 2SG => ras
#        - 3SG => ra
#        - 1PL => rons
#        - 2PL => rez
#        - 3PL => ront
#    - cond:pre
#        - 1SG, 2SG => rais
#        - 3SG => rait
#        - 1PL => rions
#        - 2PL => riez
#        - 3PL => raient
#    - ind:imp
#        - 1SG, 2SG => ais
#        - 3SG => ait
#        - 1PL => ions
#        - 2PL => iez
#        - 3PL => aient
#    - ind:pas
#        - 1PL => mes
#        - 2PL => tes
#        - 3PL => rent
#    - autres
#        - 1PL => ons (sauf passé simple)
#        - 2PL => ez (sauf passé simple)
#        - 3PL => ent

# %% [markdown]
# **⚠️ Problème avec la comparaison de chaine utf8, la condition d'égalité donne un message d'erreur à propos de l'encodage.**
# ```
# condPP=(df["cat"].isin(["VER","AUX"]))&(df["graphie"].str[-1:]==u"é")
# ```
# **La comparaison avec une liste fonctionne...**

# %%
condFut=(df.infover.isin(["ind:fut:%d"%(i+1) for i in range(3)]))
condCond=(df.infover.isin(["cnd:pre:%d"%(i+1) for i in range(3)]))
condPers1=(condInfover&(df.infover.str.endswith("1")))
condPers2=(condInfover&(df.infover.str.endswith("2")))
condPers3=(condInfover&(df.infover.str.endswith("3")))
condPers12=(condInfover&(df.infover.str[-1].isin(["1","2"])))
condPersSG=(condInfover&(df.nombre=="s"))
condPersPL=(condInfover&(df.nombre=="p"))
df[condCond&condPersSG&condPers12]

# %% [markdown]
# ### Infinitif
# - la forme en -er doit être associée à inf

# %%
condInf=(condVER
         &(df["graphie"].str[-2:]=="er")
         &(~df["infover"].isin(["inf","inf;"]))&df["infover"].notnull())
bilanDF(df[condInf],"infinitifs hors inf",lines=True)

# %% [markdown]
# Les 1201 formes en -er précédentes sont classés comme des formes finies.

# %% [markdown]
# ### Participes passé
# - les formes en -é.e.s doivent être associées à par:pas:
#  - sauf exception pour les verbes en -éer

# %%
condNotPP=((df["cat"].isin(["VER","AUX"]))
           &(~df["infover"].isin(["par:pas:"])
           &(df["infover"].notnull())))

condFinPP=((df["graphie"].str[-1:].isin([u"é"]))
           |(df["graphie"].str[-2:].isin([u"ée",u"és"]))
           |(df["graphie"].str[-3:].isin([u"ées"])))
condLemmeEER=(df["lemme"].str[-3:].isin([u"éer"]))
display(bilanDF(df[condNotPP&condFinPP&~condLemmeEER],"formes en é.e.s hors participes passé, hors verbes en -éer"))
bilanDF(df[condNotPP&condFinPP&condLemmeEER],"formes en é.e.s hors participes passé pour les verbes en -éer")

# %% [markdown]
# Sur les 48 formes repérées pour les verbes en -éer, certaines peuvent être incorrectes.

# %% [markdown]
# ### 2PL et -ez
# Pour les formes 2PL, la finale doit être -ez sauf pour le passé simple
# - sauf êtes, dites, faites (non traitées)

# %%
cond2P=((df["cat"].isin(["VER","AUX"]))
        &(df["infover"].str.contains("2"))
        &(~df["infover"].str.contains("ind:pas", na=False))
        &(df["nombre"]=="p"))

condFin2P=(~df["graphie"].str[-2:].isin([u"ez"]))
bilanDF(df[cond2P&condFin2P],u"2PL hors -ez")

# %% [markdown]
# ### 1PL et -ons
# Pour les formes 1PL, la finale doit être -ons sauf pour le passé simple
#  - exception sommes (non traitée)

# %%
cond1P=((df["cat"].isin(["VER","AUX"]))
        &(df["infover"].str.contains("1"))
        &(~df["infover"].str.contains("ind:pas", na=False))
        &(df["nombre"]=="p"))

condFin1P=(~df["graphie"].str[-3:].isin([u"ons"]))
bilanDF(df[cond1P&condFin1P],"1PL hors -ons")
