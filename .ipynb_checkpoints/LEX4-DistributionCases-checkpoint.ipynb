# %% [markdown]
# # Étude de la distribution des formes verbales dans les paradigmes pour Lexique4
#
# ## Préparation des données
# - lecture du fichier TSV
# - préparation des graphiques Seaborn
# - filtrage des éléments incohérents
# - regroupement des doublons
# - ajout d'une colonne pour les cases du paradigme (infover2Case)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.transforms as transforms
from IPython.display import display
import pyperclip
import EspacesThematiques as ET
from EspacesThematiques import *

# %%
# %matplotlib inline

# %%
import seaborn as sns
sns.set_style("darkgrid")
sns.set_context("paper", font_scale=1.5, rc={"lines.linewidth": 2.5})
sns.set_palette("hls")
sns.set_color_codes("muted")
#sns.palplot(sns.color_palette("hls", 8))
#sns.palplot(sns.color_palette("husl", 8))

# %%
rep="/Users/gilles/Downloads/"
fLexFilms4=rep+"Lexique4_min+filtr+cat+separ+corr4.tsv"
df=pd.read_csv(filepath_or_buffer=fLexFilms4,sep="\t",header=None,skip_blank_lines=True,encoding="utf8")
df.columns="graphie lexeme cat infover genre nombre occurrences".split(" ")
print len(df)
df.head()
# Out:
# 225133
#         graphie       lexeme  cat    infover genre nombre  occurrences
# 0      fossiles      fossile  ADJ        NaN   NaN      p         41.0
# 1        clopes       cloper  VER  sub:pre:2   NaN      s          1.0
# 2       ardeurs       ardeur  NOM        NaN     f      p        143.0
# 3  translations  translation  NOM        NaN   NaN    NaN          3.0
# 4    antidrogue   antidrogue  ADJ        NaN     m      s         36.0

# %% [markdown]
# ### Duplicates
# On utilise *groupby* pour cumuler les occurrences. Comme la méthode *groupby* exclue les éléments contenant des NaN, on fait un remplacement avant et après le regroupement.
# 1. on remplace les NaN par des "NaN" pour les inclure dans les groupes
# 1. on cumule les occurrences
# 1. on remplace les "NaN" par les NaN d'origine

# %%
df=df.fillna("NaN").groupby("graphie lexeme cat infover genre nombre".split()).sum().reset_index()
df=df.replace(ur"^NaN$",np.nan,regex=True)
print len(df)
# Out:
# 218831

# %% [markdown]
# # Statistiques sur les verbes
# - on crée une structure lexicale limitée aux verbes

# %%
dfV=df[(df.cat.isin(["VER","AUX"]))&(df.infover.notnull())]
print len(dfV)
# Out:
# 106745

# %%
ax=dfV.groupby("lexeme")["occurrences"].sum().sort_values(ascending=False)[:].plot()
ax.set_yscale('log')
# Out:
# /Users/gilles/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %% [markdown]
# # Statistiques sur les cases du paradigme morphosyntaxique

# %% [markdown]
# ## Filtrer les scories de Lexique4
# - quelques formes fléchies sont notées avec des lexèmes qui ne correspondent pas à un verbe
# - quelques formes ne sont pas identifiées : infover = NaN
# - une forme est indiquée comme impératif 3S
#
# Dans tous les cas, on remplace l'étiquette de Lexique.org par l'étiquette Grace

# %%
dfV.infover.unique()
# Out:
# array([u'par:pas:', u'ind:pre:3', u'ind:pas:3', u'ind:imp:3',
#        u'ind:imp:1', u'ind:imp:2', u'par:pre', u'imp:pre:2', u'ind:pre:1',
#        u'inf', u'ind:fut:3', u'ind:fut:1', u'cnd:pre:3', u'cnd:pre:1',
#        u'cnd:pre:2', u'ind:fut:2', u'ind:pre:2', u'imp:pre:1',
#        u'ind:pas:2', u'ind:pas:1', u'sub:pre:1', u'sub:pre:3',
#        u'sub:pre:2', u'sub:imp:3', u'inf;', u'sub:imp:1', u'sub:imp:2',
#        u'ind:pas:3s;', u'imp:pre:1p;ind:pre:1p;',
#        u'imp:pre:2p;ind:pre:2p;par:pas;', u'imp:pre:3',
#        u'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;'], dtype=object)

# %%
def infover2Case(lRow):
    result=""
    lInfover=lRow["infover"]
    lNombre=lRow["nombre"]
    if isinstance(lInfover,unicode):
        if lInfover in [u'imp:pre:2p;ind:pre:2p;par:pas;',
       u'imp:pre:2s;ind:pre:1s;ind:pre:3s;sub:pre:3s;',
       u'imp:pre:1p;ind:pre:1p;']:
            print lRow["graphie"],lRow["lexeme"]
        else:
            if lInfover[:3]==u"inf":
                result=u"inf"
            elif lInfover==u"par:pre":
                result="pP"
            elif lInfover[:8]==u"par:pas:":
                if lNombre in ["s","p"]:
                    lNombre=lNombre.upper()
                else:
                    print lRow
                lGenre=lRow["genre"]
                if lGenre in ["m","f"]:
                    lGenre=lGenre.upper()
                else:
                    print lRow
                result="pp"+lGenre+lNombre
            else:
                if lNombre in ["s","p"]:
                    lNombre=lNombre.upper()
                    if lInfover[:8]==u"ind:pre:":
                        result="pi"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:imp:":
                        result="ii"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:fut:":
                        result="fi"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"ind:pas:":
                        result="ai"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"imp:pre:":
                        result="pI"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"sub:pre:":
                        result="ps"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"sub:imp:":
                        result="is"+lInfover[8]+lNombre
                    elif  lInfover[:8]==u"cnd:pre:":
                        result="pc"+lInfover[8]+lNombre
                else:
                    print lRow               
    return result

# %% [markdown]
# Suite aux groupby avec des agg multiples, les DataFrames *df* ont des colonnes MultiIndex.
# - df.columns est le MultiIndex
# - df.columns.to_series() : on simplifie la structure des colonnes en exportant le MultiIndex sous forme d'une liste de tuples
# - on fait une compréhension de la liste des tuples pour extraire la série de tuple[1] sinon tuple[0]

# %%
def multi2simple(lDF):
    lDF.columns=[c if c else sc for sc,c in lDF.columns.to_series().tolist()]
    lDF.reset_index(inplace=True)
    return

# %%
print "Problèmes de lexème"
dfV["case"]=dfV.apply(infover2Case,axis=1)
condNotInvalidCell=(dfV.case!="")&(dfV.case!="pI3S")
dfV=dfV[condNotInvalidCell]
display(dfV.head())
print len(dfV)
# Out:
# Problèmes de lexème
# excitons exciton
# faîtes faîte
# monte monte
# monte monte
# partons parton
# transposons transposon
# /Users/gilles/anaconda/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#     graphie  lexeme  cat    infover genre nombre  occurrences  case
# 78      -tu   taire  VER   par:pas:     m      s          8.0  ppMS
# 116       =  égaler  VER  ind:pre:3   NaN      s       4218.0  pi3S
# 127       a   avoir  AUX  ind:pre:3   NaN      s    2139655.0  pi3S
# 128       a   avoir  VER  ind:pre:3   NaN      s    1528403.0  pi3S
# 129       a   avoir  VER   par:pas:     m      s          1.0  ppMS
# 106738

# %%
etCols=[c for et in etCells for c in et]
dfCasesTokens=dfV.groupby(["case"])[["occurrences"]].sum().sort_values("occurrences",ascending=False)
tokenCols=dfCasesTokens.index.tolist()
dfCasesTypes=dfV.groupby(["case"])[["occurrences"]].count().sort_values("occurrences",ascending=False)
typeCols=dfCasesTypes.index.tolist()

# %%
len(dfV[dfV.lexeme=="prendre"])
# Out:
# 50

# %%
ax=dfCasesTokens.plot(kind="bar",figsize=(20,5))
#ax.set_yscale('log')

# %%
ax=dfCasesTypes.plot(kind="bar",figsize=(20,5))
#ax.set_yscale('log')

# %%
dfV.groupby("case")[["occurrences"]].quantile(q=0.5).sort_values("occurrences",ascending=False).plot(kind="bar",figsize=(20,5))

# %%
dfV.groupby("case")[["occurrences"]].quantile(q=0.75).sort_values("occurrences",ascending=False).plot(kind="bar",figsize=(20,5))

# %% [markdown]
# # Statistiques sur les lexèmes

# %%
dfCells=dfV[dfV.occurrences>0].groupby(["lexeme","case"]).agg({"occurrences":[("tokens","sum"),("abondance","count")],"graphie":[("graphies",", ".join)]}).reset_index()

# %%
multi2simple(dfCells)
dfCells
# Out:
#          index    lexeme  case  tokens  abondance       graphies
# 0            0  abaisser  ai2P     1.0          1     abaissâtes
# 1            1  abaisser  ai3S     5.0          1        abaissa
# 2            2  abaisser  fi1P     3.0          1    abaisserons
# 3            3  abaisser  fi1S    69.0          1     abaisserai
# 4            4  abaisser  fi2P     3.0          1     abaisserez
# 5            5  abaisser  fi2S     4.0          1     abaisseras
# 6            6  abaisser  fi3P     8.0          1    abaisseront
# 7            7  abaisser  fi3S    30.0          1      abaissera
# 8            8  abaisser  ii1P     1.0          1     abaissions
# 9            9  abaisser  ii1S     4.0          1      abaissais
# 10          10  abaisser  ii2P     2.0          1      abaissiez
# 11          11  abaisser  ii2S     3.0          1      abaissais
# 12          12  abaisser  ii3P     3.0          1    abaissaient
# 13          13  abaisser  ii3S     6.0          1      abaissait
# 14          14  abaisser   inf   510.0          1       abaisser
# 15          15  abaisser  pI1P    15.0          1      abaissons
# 16          16  abaisser  pI2P   209.0          1       abaissez
# 17          17  abaisser  pI2S   155.0          1        abaisse
# 18          18  abaisser    pP    25.0          1      abaissant
# 19          19  abaisser  pc1S    31.0          1    abaisserais
# 20          20  abaisser  pc2P     7.0          1    abaisseriez
# 21          21  abaisser  pc2S    11.0          1    abaisserais
# 22          22  abaisser  pc3P     1.0          1  abaisseraient
# 23          23  abaisser  pc3S    28.0          1    abaisserait
# 24          24  abaisser  pi1P     7.0          1      abaissons
# 25          25  abaisser  pi1S    56.0          1        abaisse
# 26          26  abaisser  pi2P    21.0          1       abaissez
# 27          27  abaisser  pi2S    49.0          1       abaisses
# 28          28  abaisser  pi3P    36.0          1      abaissent
# 29          29  abaisser  pi3S   172.0          1        abaisse
# ...        ...       ...   ...     ...        ...            ...
# 103989  103989      ôter  fi1S    38.0          1         ôterai
# 103990  103990      ôter  fi2P    17.0          1         ôterez
# 103991  103991      ôter  fi2S    17.0          1         ôteras
# 103992  103992      ôter  fi3P     8.0          1        ôteront
# 103993  103993      ôter  fi3S    71.0          1          ôtera
# 103994  103994      ôter  ii1P     2.0          1         ôtions
# 103995  103995      ôter  ii1S     9.0          1          ôtais
# 103996  103996      ôter  ii2P    21.0          1          ôtiez
# 103997  103997      ôter  ii2S     4.0          1          ôtais
# 103998  103998      ôter  ii3P     6.0          1        ôtaient
# 103999  103999      ôter  ii3S    32.0          1          ôtait
# 104000  104000      ôter   inf  1403.0          2     ôter, ôter
# 104001  104001      ôter  pI1P     9.0          1          ôtons
# 104002  104002      ôter  pI2P   570.0          1           ôtez
# 104003  104003      ôter  pI2S   593.0          1            ôte
# 104004  104004      ôter    pP    59.0          1          ôtant
# 104005  104005      ôter  pc1S    11.0          1        ôterais
# 104006  104006      ôter  pc2P     1.0          1        ôteriez
# 104007  104007      ôter  pc3S    18.0          1        ôterait
# 104008  104008      ôter  pi1P    11.0          1          ôtons
# 104009  104009      ôter  pi1S   119.0          1            ôte
# 104010  104010      ôter  pi2P    80.0          1           ôtez
# 104011  104011      ôter  pi2S   105.0          1           ôtes
# 104012  104012      ôter  pi3P    47.0          1          ôtent
# 104013  104013      ôter  pi3S   276.0          1            ôte
# 104014  104014      ôter  ppFP    22.0          1          ôtées
# 104015  104015      ôter  ppFS    51.0          1           ôtée
# 104016  104016      ôter  ppMP    20.0          1           ôtés
# 104017  104017      ôter  ppMS   642.0          1            ôté
# 104018  104018      ôter  ps2S     4.0          1           ôtes
#
# [104019 rows x 6 columns]

# %%
dfCells[dfCells.abondance>1]
# Out:
#          index       lexeme  case     tokens  abondance  \
# 50          50   abandonner  ii3P       37.0          2
# 51          51   abandonner  ii3S      187.0          2
# 54          54   abandonner  pI2P     1304.0          2
# 65          65   abandonner  pi2P      755.0          2
# 115        115      abattre  pi2P       75.0          2
# 264        264      aborder  ii3P       10.0          2
# 345        345       aboyer  pi2P       16.0          2
# 394        394      abriter   inf      567.0          2
# 518        518     absorber  ii3P       11.0          2
# 551        551     absoudre  pi2P        2.0          2
# 615        615       abuser  ii3P       18.0          2
# 616        616       abuser  ii3S      150.0          2
# 630        630       abuser  pi2P      150.0          2
# 688        688     accabler  ii3P       10.0          2
# 715        715    accaparer  ii3S        9.0          2
# 747        747    accentuer  pi2P        3.0          2
# 769        769     accepter  ii3P       96.0          3
# 770        770     accepter  ii3S      386.0          2
# 774        774     accepter  pI2P     1857.0          2
# 785        785     accepter  pi2P     2022.0          2
# 919        919  accompagner   inf     6858.0          2
# 956        956    accomplir  ii3S       37.0          2
# 999        999     accorder  ii3S      141.0          2
# 1011      1011     accorder  pi1P      144.0          2
# 1016      1016     accorder  pi3S     1420.0          2
# 1123      1123    accoupler  pi2P       11.0          2
# 1202      1202    accrocher  ii3P       47.0          2
# 1206      1206    accrocher  pI2P     2444.0          2
# 1217      1217    accrocher  pi2P      288.0          2
# 1396      1396      accuser  ii3P       56.0          2
# ...        ...          ...   ...        ...        ...
# 103956  103956         être  is1P       15.0          2
# 103957  103957         être  is1S       56.0          2
# 103958  103958         être  is2P       35.0          2
# 103959  103959         être  is2S       14.0          2
# 103960  103960         être  is3P       68.0          2
# 103961  103961         être  is3S     1475.0          2
# 103962  103962         être  pI1P     5370.0          4
# 103963  103963         être  pI2P    26675.0          5
# 103964  103964         être  pI2S    46901.0          4
# 103965  103965         être    pP    15671.0          2
# 103966  103966         être  pc1P     3384.0          3
# 103967  103967         être  pc1S    33697.0          2
# 103968  103968         être  pc2P     9344.0          4
# 103969  103969         être  pc2S    13300.0          2
# 103970  103970         être  pc3P     8902.0          2
# 103971  103971         être  pc3S   128260.0          2
# 103972  103972         être  pi1P   133922.0          2
# 103973  103973         être  pi1S   461329.0          2
# 103974  103974         être  pi2P   420689.0          4
# 103975  103975         être  pi2S   701663.0          3
# 103976  103976         être  pi3P   612443.0          2
# 103977  103977         être  pi3S  7111273.0          2
# 103978  103978         être  ppMS   411016.0          2
# 103979  103979         être  ps1P     2783.0          2
# 103980  103980         être  ps1S    15031.0          2
# 103981  103981         être  ps2P    12045.0          2
# 103982  103982         être  ps2S    23996.0          4
# 103983  103983         être  ps3P    17210.0          3
# 103984  103984         être  ps3S   159569.0          2
# 104000  104000         ôter   inf     1403.0          2
#
#                                graphies
# 50             abandonnaient, abandonné
# 51               abandonnait, abandonné
# 54               abandonner, abandonnez
# 65               abandonner, abandonnez
# 115                    abattez, abattre
# 264                  abordaient, abordé
# 345                      aboyer, aboyez
# 394                    abriter, abriter
# 518                absorbaient, absorbé
# 551                  absolvez, absoudre
# 615                    abusaient, abusé
# 616                      abusait, abusé
# 630                      abuser, abusez
# 688                accablaient, accablé
# 715                accaparait, accaparé
# 747                accentuer, accentuez
# 769     acceptaient, accepté, acceptées
# 770                  acceptait, accepté
# 774                  accepter, acceptez
# 785                  accepter, acceptez
# 919            accompagner, accompagner
# 956            accomplir, accomplissait
# 999                  accordait, accordé
# 1011                accordes, accordons
# 1016                   accorde, accordé
# 1123               accoupler, accouplez
# 1202            accrochaient, accrochés
# 1206               accrocher, accrochez
# 1217               accrocher, accrochez
# 1396                 accusaient, accusé
# ...                                 ...
# 103956               fussions, fussions
# 103957                     fusse, fusse
# 103958                 fussiez, fussiez
# 103959                   fusses, fusses
# 103960                 fussent, fussent
# 103961                         fût, fût
# 103962   sommes, sommes, soyons, soyons
# 103963   soyez, soyez, êtes, êtes, être
# 103964           sois, sois, suis, suis
# 103965                     étant, étant
# 103966         serais, serions, serions
# 103967                   serais, serais
# 103968   serais, serais, seriez, seriez
# 103969                   serais, serais
# 103970               seraient, seraient
# 103971                   serait, serait
# 103972                   sommes, sommes
# 103973                       suis, suis
# 103974         sommes, êtes, êtes, être
# 103975                     es, es, suis
# 103976                       sont, sont
# 103977                         est, est
# 103978                         été, été
# 103979                   soyons, soyons
# 103980                       sois, sois
# 103981                     soyez, soyez
# 103982       sois, sois, sommes, sommes
# 103983          soient, soient, étaient
# 103984                       soit, soit
# 104000                       ôter, ôter
#
# [2392 rows x 6 columns]

# %%
dfVerbes=dfCells.groupby("lexeme").agg({"tokens":[('nbCases', 'count'), ('nbTokens', 'sum')],"case":[("cases",", ".join)]})#.sort_values("occurrences",ascending=False).reset_index()
multi2simple(dfVerbes)
dfVerbes.head()
# Out:
#        lexeme  nbCases  nbTokens  \
# 0    abaisser       34    1663.0
# 1  abandonner       43   42772.0
# 2  abasourdir       10     249.0
# 3     abattre       40   11857.0
# 4     abcéder        2       2.0
#
#                                                cases
# 0  ai2P, ai3S, fi1P, fi1S, fi2P, fi2S, fi3P, fi3S...
# 1  ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...
# 2  fi1S, inf, pI2P, pi2S, pi3S, ppFP, ppFS, ppMP,...
# 3  ai2S, ai3P, ai3S, fi1P, fi1S, fi2P, fi2S, fi3P...
# 4                                         ppMP, ppMS

# %%
dfDistCases=dfVerbes.groupby("cases").agg({"lexeme":[("nbLexemes","count"),("listLexemes",",".join)],"nbCases":[("nbCells","first")]})
dfDistCases.columns=[c for sc,c in dfDistCases.columns.to_series().tolist()]
dfDistCases=dfDistCases.reset_index().sort_values(["nbCells","nbLexemes"],ascending=False)

# %%
dfDistCases#[dfDistCases.nbLexemes>1]
# Out:
#                                                   cases  nbLexemes  \
# 0     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 3     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 30    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 4     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 31    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 1     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 6     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 2     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 5     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 8     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 10    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 12    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 34    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 219   ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 233   ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P, fi2S...          1
# 38    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          2
# 7     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 9     ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 14    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 36    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 221   ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 17    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          3
# 52    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          3
# 13    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 15    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 16    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 21    ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...          1
# 25    ai1P, ai1S, ai2P, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 32    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# 44    ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...          1
# ...                                                 ...        ...
# 4890                                         ppFP, ppMP          1
# 4250                                                inf        225
# 4901                                               ppMS        104
# 4865                                               pi3S         97
# 4893                                               ppFS         42
# 4737                                               pI2S         29
# 1521                                               ai3S         24
# 4815                                               pi1S         20
# 4855                                               pi3P         19
# 4841                                               pi2S         18
# 4899                                               ppMP         18
# 4786                                                 pP         16
# 4715                                               pI2P         13
# 4885                                               ppFP         12
# 4076                                               ii3S          5
# 4905                                               ps3S          4
# 744                                                ai2S          3
# 4835                                               pi2P          3
# 2737                                               fi1S          2
# 3800                                               ii1S          2
# 3986                                               ii3P          2
# 4903                                               ps2S          2
# 733                                                ai2P          1
# 3349                                               fi3P          1
# 3478                                               fi3S          1
# 3771                                               ii1P          1
# 4710                                               is1S          1
# 4712                                               pI1P          1
# 4811                                               pi1P          1
# 4904                                               ps3P          1
#
#                                             listLexemes  nbCells
# 0                                                 avoir       51
# 3                                                 faire       50
# 30                                               devoir       50
# 4                                                mettre       49
# 31                                               savoir       49
# 1                                                  être       48
# 6                                               prendre       48
# 2                                               pouvoir       47
# 5                                                 aller       47
# 8                                               devenir       47
# 10                                                 voir       47
# 12                                             entendre       47
# 34                                            connaître       47
# 219                                                dire       47
# 233                                               venir       47
# 38                                       croire,trouver       46
# 7                                                rester       46
# 9                                               envoyer       46
# 14                                              laisser       46
# 36                                              vouloir       46
# 221                                              donner       46
# 17                         apprendre,arriver,poursuivre       45
# 52                           comprendre,demander,parler       45
# 13                                                 tuer       45
# 15                                               partir       45
# 16                                               passer       45
# 21                                               penser       45
# 25                                              manquer       45
# 32                                             remettre       45
# 44                                             répondre       45
# ...                                                 ...      ...
# 4890                                  départementaliser        2
# 4250  accroire,aicher,ambler,anatomiser,angéliser,ap...        1
# 4901  aluminer,anamorphoser,annualiser,autoalimenter...        1
# 4865  adsorber,affriander,agrainer,ajointer,anglaise...        1
# 4893  animaliser,assis,attriquer,bigarrer,billonner,...        1
# 4737  anneler,bouliner,contrebraquer,doguer,décapele...        1
# 1521  agneler,berdeller,bilaner,bistrer,capeler,clav...        1
# 4815  apiquer,contrevérifier,débonder,débraguetter,d...        1
# 4855  antiqualifier,antivitaminer,aoûter,arianiser,c...        1
# 4841  adjectiver,aspecter,berlurer,breller,cagner,ca...        1
# 4899  ambuler,aposter,bluter,brillantiner,claustrer,...        1
# 4786  afférer,alkyler,antinoter,autodéterminer,brési...        1
# 4715  abricoter,alentir,débâcher,décarpiller,délabyr...        1
# 4885  bémoliser,chantourner,délustrer,démasculiniser...        1
# 4076  crachiner,défertiliser,pitancher,pétarder,teiller        1
# 4905           antivêtir,faignanter,hongrer,surinvestir        1
# 744                        duplicater,maximer,pistacher        1
# 4835                       grasseyer,prédécéder,pétuner        1
# 2737                                 remouler,réenfiler        1
# 3800                              défocaliser,rencogner        1
# 3986                                pignocher,redéfiler        1
# 4903                               antiparasiter,copter        1
# 733                                            sulfoner        1
# 3349                                        entrégorger        1
# 3478                                           démerger        1
# 3771                                             écurer        1
# 4710                                         feignanter        1
# 4712                                         branlocher        1
# 4811                                      boustifailler        1
# 4904                                           permaner        1
#
# [4906 rows x 4 columns]

# %% [markdown]
# ## Nombre de lexèmes et de formes par lexème
# - dfVerbes compte un élément par lexème
# - nbCases compte le nombre de cases remplies pour chaque lexème

# %%
nbLexemes=len(dfVerbes)
numMedian=nbLexemes/2
print u"Nombre de lexèmes : %d"%nbLexemes
print u"Numéro du lexème médian : %d"%numMedian
print u"Nombre de formes médian par lexème : %d"%dfVerbes.nbCases.median()
print u"Nombre de formes moyen par lexème : %0.1f"%dfVerbes.nbCases.mean()
# Out:
# Nombre de lexèmes : 6548
# Numéro du lexème médian : 3274
# Nombre de formes médian par lexème : 13
# Nombre de formes moyen par lexème : 15.9

# %% [markdown]
# Le nombre moyen de formes par lexème est légèrement supérieur à celui calculé par Bonami & Beniamine mais du même ordre de grandeur.

# %% [markdown]
# ### Distribution du nombre de formes par lexème
# - on compte le nombre de lexèmes qui ont *n* cases remplies dans Lexique4

# %%
dfVerbesDistCases=dfVerbes.groupby("nbCases").agg({"cases":[("nbVerbes","count")],"nbTokens":[("tokens","sum")]})
dfVerbesDistCases[("cases","nbVerbes")].plot(kind='bar',figsize=(20,5))

# %%
lDefectifs=[u"abstraire", u"accroire", u"adirer", u"advenir", u"apparoir", u"assavoir", u"avenir", u"becter", u"béer", u"bienvenir", u"braire", u"bruire", u"chaloir", u"choir", u"clore", u"comparoir", u"contrefoutre", u"courre", u"déchoir", u"déclore", u"dépourvoir", u"discontinuer", u"dissoudre", u"distraire", u"douer", u"échoir", u"éclore", u"enclore", u"endêver", u"ensuivre", u"ester", u"extraire", u"faillir", u"férir", u"forclore", u"forfaire", u"foutre", u"frire", u"gésir", u"huir", u"impartir", u"issir", u"malfaire", u"méfaire", u"messeoir", u"moufeter", u"moufter", u"mourir", u"oindre", u"ouïr", u"paître", u"parfaire", u"poindre", u"quérir", u"raire", u"rassir", u"ravoir", u"reclure", u"revaloir", u"saillir", u"seoir", u"sourdre", u"soustraire", u"stupéfaire", u"surfaire", u"titre", u"traire", u"urger"]
dfVerbes[dfVerbes.lexeme.isin(lDefectifs)]
# Out:
#             lexeme  nbCases  nbTokens  \
# 29       abstraire        6     121.0
# 59        accroire        1      64.0
# 109        advenir       16    1503.0
# 460         avenir        1      72.0
# 552         becter        8      32.0
# 686         braire        2      43.0
# 736         bruire        2      85.0
# 923        chaloir        1      18.0
# 992          choir       14     845.0
# 1075         clore       16    2704.0
# 1141     comparoir        1       1.0
# 1273  contrefoutre        5     182.0
# 1349        courre        1     148.0
# 1535  discontinuer        4      32.0
# 1564     dissoudre       28    1308.0
# 1574     distraire       35    5562.0
# 1609         douer       10    9514.0
# 2443       enclore        4      12.0
# 2566      ensuivre       16     405.0
# 2670         ester        1       4.0
# 2737      extraire       30    3060.0
# 2758       faillir       17   13601.0
# 2882      forfaire        1     346.0
# 2912        foutre       36   91979.0
# 2941         frire       13    2429.0
# 3281      impartir        4      50.0
# 3637      malfaire        1       3.0
# 3734      messeoir        1       1.0
# 3820      moufeter        1       3.0
# 3821       moufter       14      80.0
# 3825        mourir       44  262804.0
# 3993        oindre       22     194.0
# 4099      parfaire       10   23870.0
# 4294       poindre        8    1904.0
# 4601         raire        4      69.0
# 4649        rassir        1       4.0
# 4677        ravoir        1     529.0
# 5145      revaloir       16    1031.0
# 5483       saillir       12      39.0
# 5562         seoir        6     381.0
# 5653       sourdre        6      42.0
# 5673    soustraire       20     476.0
# 5793      surfaire        4      72.0
# 6019        traire       26     674.0
# 6152         urger       10     238.0
#
#                                                   cases
# 29                    inf, pi3S, ppFP, ppFS, ppMP, ppMS
# 59                                                  inf
# 109   ai3S, fi3P, fi3S, ii3S, inf, pP, pc3P, pc3S, p...
# 460                                                 inf
# 552         inf, pP, pi1S, pi3P, pi3S, ppFP, ppFS, ppMS
# 686                                           inf, pi3S
# 736                                           inf, pi3S
# 923                                                 inf
# 992   ai1S, ai3S, fi1S, fi2P, inf, is3S, pI2S, pi1S,...
# 1075  fi1P, fi3P, fi3S, inf, pI2S, pc3S, pi1S, pi3P,...
# 1141                                                inf
# 1273                        inf, pi1S, pi2S, pi3P, pi3S
# 1349                                                inf
# 1535                              inf, pi3S, ppMP, ppMS
# 1564  fi1P, fi1S, fi2S, fi3P, fi3S, ii1P, ii1S, ii3P...
# 1574  fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii1P, ii1S...
# 1609  ii3P, ii3S, inf, is3S, pI2S, pi3S, ppFP, ppFS,...
# 2443                              inf, pi3S, ppFS, ppMS
# 2566  ai3P, ai3S, fi3P, fi3S, ii3P, ii3S, inf, is3S,...
# 2670                                                inf
# 2737  fi1P, fi1S, fi2P, fi3P, fi3S, ii1P, ii1S, ii2P...
# 2758  ai1P, ai1S, ai2S, ai3P, ai3S, fi1P, fi1S, fi2P...
# 2882                                                inf
# 2912  fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii1P, ii1S...
# 2941  fi1P, fi1S, fi2S, fi3S, inf, pI2S, pc2S, pc3S,...
# 3281                              inf, ppFP, ppFS, ppMS
# 3637                                                inf
# 3734                                               pi3S
# 3820                                                inf
# 3821  fi3P, fi3S, ii3P, inf, pI2P, pI2S, pc1S, pc3S,...
# 3825  ai1P, ai1S, ai2P, ai2S, ai3P, ai3S, fi1P, fi1S...
# 3993  ai3S, fi1P, fi1S, fi3S, ii1P, ii3P, ii3S, inf,...
# 4099  ai1S, fi2P, inf, pI2S, pi1S, pi3S, ppFP, ppFS,...
# 4294        fi3S, ii3S, inf, pI2S, pP, pi1S, pi3P, pi3S
# 4601                              fi3S, inf, pi3S, ppMS
# 4649                                                inf
# 4677                                                inf
# 5145  fi1P, fi1S, fi2P, fi2S, fi3P, fi3S, ii2S, inf,...
# 5483  ai3S, fi3P, ii3S, inf, is3P, pI2S, pP, pi2S, p...
# 5562                 fi3S, ii3S, pc3P, pc3S, pi3P, pi3S
# 5653                  inf, pI2S, pi1S, pi3S, ps2S, ps3S
# 5673  fi1S, fi3S, ii3P, inf, pI2P, pI2S, pP, pc3S, p...
# 5793                              inf, ppFP, ppFS, ppMP
# 6019  fi1S, fi2S, fi3P, fi3S, ii1P, ii1S, ii2S, ii3P...
# 6152  ii3S, inf, pI2S, pP, pi1S, pi2S, pi3P, pi3S, p...

# %% [markdown]
# # Vecteurs de distribution des formes

# %% [markdown]
# ## Vecteurs de distribution des tokens entre formes

# %% [markdown]
# Ajouter de la couleur dans les tables Pandas

# %%
cmap = cmap=sns.diverging_palette(0, 250,n=10, as_cmap=True)

from IPython.display import HTML

def hover(hover_color="#ffff99"):
    return dict(selector="tr:hover",
                props=[("background-color", "%s" % hover_color)])
def magnify():
    return [dict(selector="th",
                 props=[("font-size", "4pt")]),
            dict(selector="td",
                 props=[('padding', "0em 0em")]),
            dict(selector="th:hover",
                 props=[("font-size", "12pt")]),
            dict(selector="tr:hover td:hover",
                 props=[('max-width', '200px'),
                        ('font-size', '12pt')])
]

# %%
dfParTokens=dfV.pivot_table(index=["lexeme"],values="occurrences",columns=["case"]).reset_index()
dfParTokens=dfParTokens[["lexeme"]+etCols]
dfParTokens
# Out:
# case       lexeme      ii1S     ii2S      ii3S     ii1P     ii2P     ii3P  \
# 0        abaisser       4.0      3.0       6.0      1.0      2.0      3.0
# 1      abandonner      99.0     34.0      93.5     31.0     92.0     18.5
# 2      abasourdir       NaN      NaN       NaN      NaN      NaN      NaN
# 3         abattre      10.0      5.0      52.0      6.0     23.0     28.0
# 4         abcéder       NaN      NaN       NaN      NaN      NaN      NaN
# 5        abdiquer       NaN      NaN       1.0      1.0      1.0      1.0
# 6         aberrer       NaN      NaN       NaN      NaN      NaN      NaN
# 7        abhorrer       1.0      NaN       4.0      NaN      1.0      1.0
# 8         abjurer       1.0      NaN       NaN      NaN      NaN      NaN
# 9          abolir       NaN      NaN       1.0      1.0      NaN      NaN
# 10       abominer       NaN      NaN       NaN      NaN      NaN      NaN
# 11        abonder       1.0      NaN      11.0      NaN      NaN     16.0
# 12        abonner       NaN      NaN       2.0      NaN      NaN      NaN
# 13        aborder       7.0      2.0      45.0     12.0      9.0      5.0
# 14       aboucher       NaN      NaN       NaN      NaN      NaN      NaN
# 15        abouler       NaN      NaN       NaN      NaN      NaN      NaN
# 16        aboutir       1.0      NaN      19.0      1.0      1.0      8.0
# 17         aboyer      12.0      3.0     111.0      NaN      NaN     33.0
# 18        abraser       NaN      NaN       NaN      NaN      NaN      NaN
# 19       abreuver       1.0      1.0      11.0      1.0      1.0      NaN
# 20      abricoter       NaN      NaN       NaN      NaN      NaN      NaN
# 21        abriter       6.0      3.0     105.0      3.0      4.0     17.0
# 22        abroger       NaN      NaN       1.0      NaN      2.0      NaN
# 23        abrutir       1.0      NaN       7.0      NaN      1.0      1.0
# 24        abréger       NaN      1.0       2.0      1.0      1.0      NaN
# 25       absenter       6.0      5.0      37.0      1.0      2.0      3.0
# 26       absorber       6.0      1.0      33.0      NaN      3.0      5.5
# 27       absoudre       NaN      NaN       1.0      NaN      NaN      NaN
# 28       abstenir       3.0      2.0       3.0      NaN      9.0      2.0
# 29      abstraire       NaN      NaN       NaN      NaN      NaN      NaN
# ...           ...       ...      ...       ...      ...      ...      ...
# 6518     étourdir       2.0      NaN       1.0      1.0      NaN      1.0
# 6519    étrangler      20.0      8.0      89.0      NaN      5.0      9.0
# 6520    étreindre       3.0      1.0      21.0      1.0      2.0      8.0
# 6521     étrenner       1.0      NaN       1.0      NaN      NaN      NaN
# 6522     étriller       1.0      NaN       NaN      NaN      NaN      NaN
# 6523  étripailler       NaN      NaN       NaN      NaN      NaN      NaN
# 6524      étriper       1.0      2.0       4.0      NaN      5.0      NaN
# 6525     étriquer       NaN      NaN       NaN      NaN      NaN      NaN
# 6526      étudier     389.0     92.0     254.0     13.0     33.0     31.5
# 6527       étuver       NaN      NaN       NaN      NaN      NaN      NaN
# 6528       étêter       NaN      NaN       NaN      NaN      NaN      NaN
# 6529      évacuer      10.0      1.0      15.5      1.0      7.0      5.0
# 6530       évader      14.0      1.0      18.0      3.0      5.0     10.0
# 6531      évaluer      11.0      3.0      12.5      1.0      8.0      6.0
# 6532  évangéliser       NaN      NaN       NaN      1.0      NaN      1.0
# 6533     évanouir      10.0      6.0      27.0      NaN      7.0     13.0
# 6534     évaporer       2.0      NaN       6.0      NaN      NaN      5.0
# 6535       évaser       NaN      NaN       NaN      NaN      NaN      NaN
# 6536     éveiller      15.0      2.0      39.0      NaN      NaN      5.0
# 6537      éventer       1.0      1.0       2.0      NaN      NaN      4.0
# 6538     éventrer       1.0      NaN       7.0      NaN      NaN      4.0
# 6539     évertuer       5.0      1.0       4.0      NaN      NaN      3.0
# 6540       évider       NaN      NaN       NaN      NaN      NaN      1.0
# 6541      évincer       NaN      1.0       3.0      NaN      1.0      NaN
# 6542    éviscérer       2.0      NaN       3.5      NaN      NaN      NaN
# 6543       éviter     176.0    114.0     232.0     19.0     89.0     31.0
# 6544      évoluer       9.0      2.0      62.0      3.0      1.0     20.0
# 6545      évoquer      38.0      6.0      97.0     12.0     21.0     26.0
# 6546         être  110877.0  30353.5  491074.0  10647.0  27188.5  41664.5
# 6547         ôter       9.0      4.0      32.0      2.0     21.0      6.0
#
# case     pi1P       pi2P      pi3P  ...  is1S  is2S   is3S  is1P  is2P  is3P  \
# 0         7.0      21.00      36.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 1       193.0     377.50     661.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 2         NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 3        12.0      37.50     188.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 4         NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 5         1.0       8.00       1.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6         NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 7         2.0       4.00       8.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 8         NaN       6.00       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 9         4.0       3.00       4.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 10        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 11        NaN       1.00      96.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 12        NaN       6.00       2.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 13       46.0      46.00      73.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 14        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 15        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 16        2.0       2.00      80.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 17        4.0       8.00     211.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 18        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 19        1.0        NaN      18.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 20        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 21       14.0      47.00      98.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 22        NaN       2.00       3.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 23        NaN       3.00      12.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 24        1.0       5.00       9.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 25        4.0      19.00      14.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 26        7.0      18.00     166.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 27        NaN       1.00       1.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 28        3.0      44.00      24.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 29        NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# ...       ...        ...       ...  ...   ...   ...    ...   ...   ...   ...
# 6518      1.0       6.00       5.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6519      1.0      42.00      49.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6520      6.0       4.00      36.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6521      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6522      NaN       1.00       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6523      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6524      1.0       3.00      23.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6525      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6526    246.0     210.50     353.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6527      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6528      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6529     52.0      44.00     156.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6530      6.0       7.00      57.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6531     42.0      27.00      66.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6532      1.0        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6533      1.0      25.00     110.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 6534      NaN       1.00      71.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6535      NaN        NaN       NaN  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6536      5.0      10.50      62.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 6537      NaN       2.00       4.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6538      NaN       1.00       6.0  ...   NaN   NaN    1.0   NaN   NaN   NaN
# 6539      1.0       3.00      10.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6540      NaN       1.00      37.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6541      1.0      11.00       2.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6542      NaN        NaN       4.0  ...   NaN   NaN    NaN   1.0   NaN   NaN
# 6543     61.0     309.00     357.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6544     34.0      23.00     371.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6545     22.0      63.00     169.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
# 6546  66961.0  105172.25  306221.5  ...  28.0   7.0  737.5   7.5  17.5  34.0
# 6547     11.0      80.00      47.0  ...   NaN   NaN    NaN   NaN   NaN   NaN
#
# case      ppMS    ppMP    ppFS   ppFP
# 0        122.0    17.0    40.0    9.0
# 1       9855.0  1127.0  2533.0  604.0
# 2        155.0    30.0    47.0    2.0
# 3       3702.0   612.0   541.0   76.0
# 4          1.0     1.0     NaN    NaN
# 5         45.0     1.0     NaN    NaN
# 6          3.0     NaN     NaN    NaN
# 7          9.0     NaN     NaN    NaN
# 8         13.0     NaN     1.0    1.0
# 9        138.0    10.0    65.0   12.0
# 10         NaN     NaN     NaN    NaN
# 11         5.0     NaN     NaN    NaN
# 12       151.0    38.0    58.0    4.0
# 13       622.0    94.0   142.0   23.0
# 14         1.0     NaN     NaN    NaN
# 15         NaN     NaN     NaN    NaN
# 16       418.0    15.0    19.0    9.0
# 17       131.0     2.0     NaN    NaN
# 18         3.0     NaN     5.0    NaN
# 19        27.0    16.0     6.0    NaN
# 20         NaN     NaN     NaN    NaN
# 21        89.0    22.0    21.0    6.0
# 22        28.0     3.0    20.0    1.0
# 23       398.0    71.0    39.0    5.0
# 24        75.0     3.0    19.0    5.0
# 25       253.0    17.0   115.0    3.0
# 26       622.0    83.0   179.0   38.0
# 27        56.0    16.0     9.0    1.0
# 28        49.0    13.0    16.0    1.0
# 29        83.0    12.0     8.0   10.0
# ...        ...     ...     ...    ...
# 6518     216.0    18.0   129.0    1.0
# 6519     935.0    51.0   846.0   61.0
# 6520      69.0    11.0    27.0    4.0
# 6521      11.0     1.0     3.0    NaN
# 6522       9.0     NaN     1.0    NaN
# 6523       NaN     NaN     NaN    NaN
# 6524      75.0    21.0    19.0    NaN
# 6525      15.0     5.0    16.0    2.0
# 6526    4811.0   154.0   151.0   76.0
# 6527       3.0     4.0     NaN    NaN
# 6528       2.0     2.0     2.0    NaN
# 6529     684.0   263.0   180.0   54.0
# 6530     828.0   148.0    89.0    7.0
# 6531     424.0    67.0   106.0   28.0
# 6532       2.0     1.0     NaN    NaN
# 6533    1699.0   101.0  1461.0   32.0
# 6534     194.0    62.0     NaN    NaN
# 6535       6.0     NaN     2.0    1.0
# 6536    1706.0   258.0   805.0   31.0
# 6537      55.0     3.0    14.0    2.0
# 6538     127.0    16.0    63.0   13.0
# 6539      15.0     5.0     2.0    NaN
# 6540       8.0     2.0     3.0    3.0
# 6541     203.0    26.0    37.0    5.0
# 6542      70.0    12.0    20.0    2.0
# 6543    1995.0   100.0   267.0   56.0
# 6544    1084.0    44.0    36.0    9.0
# 6545     756.0    38.0    61.0   24.0
# 6546  205508.0     NaN     NaN    NaN
# 6547     642.0    20.0    51.0   22.0
#
# [6548 rows x 52 columns]

# %%
dfParTokens[dfParTokens.lexeme.isin(lDefectifs)][["lexeme"]+etCols].style.background_gradient(cmap, axis=1)\
    .set_properties(**{'max-width': '80px', 'font-size': '1pt'})\
    .set_caption("Hover to magnify")\
    .set_table_styles(magnify())
# Out:
# /Users/gilles/anaconda/envs/py27/lib/python2.7/site-packages/matplotlib/colors.py:504: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1
# <style  type="text/css" >
#     #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914 th {
#           font-size: 4pt;
#     }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914 td {
#           padding: 0em 0em;
#     }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914 th:hover {
#           font-size: 12pt;
#     }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914 tr:hover td:hover {
#           max-width: 200px;
#           font-size: 12pt;
#     }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col0 {
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col1 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col2 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col3 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col4 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col5 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col6 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col7 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col8 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col9 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col10 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col11 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col12 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col13 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col14 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col15 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col16 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col17 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col18 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col19 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col20 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col21 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col22 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col23 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col24 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col25 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col26 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col27 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col28 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col29 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col30 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col31 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col32 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col33 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col34 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col35 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col36 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col37 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col38 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px;
#             font-size:  1pt;
#         }    #T_61d57ae8_abf0_11ea_8fc8_a8be27cec914row0_col39 {
#             background-color:  #d53d69;
#             color:  #f1f1f1;
#             max-width:  80px

# %% [markdown]
# #### Déclaration d'un style pour une table
# les informations de style sont stockées dans une liste. Chaque élément est déclaré avec un dict qui contient le sélecteur d'un côté et les propriétés de l'autre.

# %%
styles = [
    dict(selector="thead th", props=[("text-align", "center")]),
    dict(selector="tbody td.col0", props=[("background-color", "AntiqueWhite"),("text-align", "right")]),
#     dict(selector="thead th.col1", props=[("background-color", "AntiqueWhite")]),
    dict(selector="thead th.col1", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col2", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col3", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col4", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col5", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col6", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col7", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col8", props=[("background-color", "#ff8000")]),
    dict(selector="thead th.col9", props=[("background-color", "#dfbf9f")]),
    dict(selector="thead th.col10", props=[("background-color", "#bf8040")]),
    dict(selector="thead th.col11", props=[("background-color", "#bf8040")]),
    dict(selector="thead th.col12", props=[("background-color", "#bf8040")]),
    dict(selector="thead th.col13", props=[("background-color", "#e5e5ff")]),
    dict(selector="thead th.col14", props=[("background-color", "#ffff80")]),
    dict(selector="thead th.col15", props=[("background-color", "#bfbfff")]),
    dict(selector="thead th.col16", props=[("background-color", "#bfbfff")]),
    dict(selector="thead th.col17", props=[("background-color", "#80bfbf")]),
    dict(selector="thead th.col18", props=[("background-color", "#80bfbf")]),
    dict(selector="thead th.col19", props=[("background-color", "#80bfbf")]),
    dict(selector="thead th.col20", props=[("background-color", "#80bfbf")]),
    dict(selector="thead th.col21", props=[("background-color", "#8080ff")]),
    dict(selector="thead th.col22", props=[("background-color", "#8080ff")]),
    dict(selector="thead th.col23", props=[("background-color", "#80ffff")]),
    dict(selector="thead th.col24", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col25", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col26", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col27", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col28", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col29", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col30", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col31", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col32", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col33", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col34", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col35", props=[("background-color", "#bfff00")]),
    dict(selector="thead th.col36", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col37", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col38", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col39", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col40", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col41", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col42", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col43", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col44", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col45", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col46", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col47", props=[("background-color", "#ffbfbf")]),
    dict(selector="thead th.col48", props=[("background-color", "#ff80ff")]),
    dict(selector="thead th.col49", props=[("background-color", "#ff80ff")]),
    dict(selector="thead th.col50", props=[("background-color", "#ff80ff")]),
    dict(selector="thead th.col51", props=[("background-color", "#ff80ff")]),
    dict(selector="caption", props=[("caption-side", "bottom")])
]

# %% [markdown]
# #### Correspondance des couleurs avec les cases de l'espace thématique

# %% [raw]
# etColoursHTML={
#                 "orange":0xFF8000,
#                 "brown!50":0xdfbf9f,
#                 "brown":0xbf8040,
#                 "blue!10":0xe5e5ff,
#                 "yellow!50":0xffff80,
#                 "blue!25":0xbfbfff,
#                 "teal!50":0x80bfbf,
#                 "blue!50":0x8080ff,
#                 "cyan!50":0x80ffff,
#                 "lime":0xbfff00,
#                 "pink":0xffbfbf,
#                 "magenta!50":0xff80ff,
# }
# # for col in etColours:
# #     print ur'"%s":0x,'%col

# %% [raw]
# for nCol,col in enumerate(etCols):
#     print 'dict(selector="thead th.col%d", props=[("background-color", "#%x")]),'%((nCol+1), etColoursHTML[dictEtColours[col]])

# %% [raw]
# etCells

# %% [markdown]
# #### Formatage des cellules d'après leur valeur
# - si la cellule contient une chaîne unicode, on ne fait rien
# - si la cellule est un NaN, on met le texte en blanc sur fond blanc
# - si la cellule a une valeur numérique
#     - LightCoral pour les valeurs jusqu'à 5
#     - Chartreuse pour les valeurs à partir de 100

# %%
def _color_red_or_green(val):
    result=""
    if isinstance(val,unicode):
        color="white"
    elif pd.isna(val):
        result="color:white"
    else:
        if val<=5:
            result='background-color:LightCoral'
        elif val>=100:
            result = 'background-color:Chartreuse'
    return result

# %%
dfParTokens[dfParTokens.lexeme.isin(lDefectifs)].style.set_table_styles(styles).applymap(_color_red_or_green)
# Out:
# <style  type="text/css" >
#     #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th {
#           text-align: center;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 tbody td.col0 {
#           background-color: AntiqueWhite;
#           text-align: right;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col1 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col2 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col3 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col4 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col5 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col6 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col7 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col8 {
#           background-color: #ff8000;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col9 {
#           background-color: #dfbf9f;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col10 {
#           background-color: #bf8040;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col11 {
#           background-color: #bf8040;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col12 {
#           background-color: #bf8040;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col13 {
#           background-color: #e5e5ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col14 {
#           background-color: #ffff80;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col15 {
#           background-color: #bfbfff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col16 {
#           background-color: #bfbfff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col17 {
#           background-color: #80bfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col18 {
#           background-color: #80bfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col19 {
#           background-color: #80bfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col20 {
#           background-color: #80bfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col21 {
#           background-color: #8080ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col22 {
#           background-color: #8080ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col23 {
#           background-color: #80ffff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col24 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col25 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col26 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col27 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col28 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col29 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col30 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col31 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col32 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col33 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col34 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col35 {
#           background-color: #bfff00;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col36 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col37 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col38 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col39 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col40 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col41 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col42 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col43 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col44 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col45 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col46 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col47 {
#           background-color: #ffbfbf;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col48 {
#           background-color: #ff80ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col49 {
#           background-color: #ff80ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col50 {
#           background-color: #ff80ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 thead th.col51 {
#           background-color: #ff80ff;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914 caption {
#           caption-side: bottom;
#     }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col1 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col2 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col3 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col4 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col5 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col6 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col7 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col8 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col9 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col10 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col11 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col12 {
#             background-color: LightCoral;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col13 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col14 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col15 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col16 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col17 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col18 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col19 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col20 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col21 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col22 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col23 {
#             background-color: LightCoral;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col24 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col25 {
#             color: white;
#         }    #T_85d143bd_ac09_11ea_b92b_a8be27cec914row0_col26 {
#             color: white;
#         }    #T_85d143bd_ac09_11e

# %%
pyperclip.copy(makeTabularParadigmeDF("dire",dfParTokens,dictEtColours,title="",coulLim=False, cat="V",dictMorphomes={},ipa=False))

# %% [markdown]
# # Évolution du nombre de lexèmes/formes en fonction de la fréquence
